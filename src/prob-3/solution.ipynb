# %%
import pandas as pd
import numpy as np
import datetime
from planning import planning

stats_2023 = pd.read_csv("../../data/preprocess/pre-processed.csv")
stats_2023.dtypes
# Out:
# Field ID           int64
# Field Name        object
# Crop ID            int64
# Crop Name         object
# Crop Type         object
# Planting Area    float64
# Season ID          int64
# Season            object
# Field Type        object
# Field Area       float64
# Per Yield        float64
# Per Cost         float64
# Per Price        float64
# Yield            float64
# Cost             float64
# Selling          float64
# Revenue          float64
# Profit           float64
# dtype: object

# %%
fields_id = list(map(int, stats_2023["Field ID"].unique()))  # 所有的地块
crops_id = list(map(int, stats_2023["Crop ID"].unique()))  # 所有的作物
seasons_id = list(map(int, stats_2023["Season ID"].unique()))  # 所有的时节
fields_id.sort()
crops_id.sort()
seasons_id.sort()
years = range(2023, 2031)  # 要优化的年份


def pop_ndarray(arr, element_to_pop):
    index = np.where(arr == element_to_pop)[0]
    if index.size > 0:
        arr = np.delete(arr, index)
    return arr


# A类粮食作物的集合
grains_A = stats_2023[
    (stats_2023["Crop Type"] == "粮食") | (stats_2023["Crop Type"] == "粮食（豆类）")
]["Crop ID"].unique()
grains_A = pop_ndarray(grains_A, 16)
grains_A.sort()

# B类粮食作物的集合
grains_B = np.array([16])

# A类蔬菜作物的集合
vege_A = stats_2023[
    (stats_2023["Crop Type"] == "蔬菜") | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
for i in range(3):
    vege_A = pop_ndarray(vege_A, 35 + i)
vege_A.sort()

# B类蔬菜作物的集合
vege_B = np.array([35, 36, 37])

# 食用菌作物的集合
mush = stats_2023[stats_2023["Crop Type"] == "食用菌"]["Crop ID"].unique()
mush.sort()

# 豆类作物的集合
beans = stats_2023[
    (stats_2023["Crop Type"] == "粮食（豆类）")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
beans.sort()

# 第 i 个地块的类型（如平旱地、梯田、山坡地、智能大棚、普通大棚、水浇地）
t_i = {
    i: stats_2023[stats_2023["Field ID"] == i]["Field Type"].values[0]
    for i in fields_id
}

# 第 i 个地块在第 s 季可种植的作物集合
T_hat_i_s: dict[tuple : np.ndarray] = {}


for i in fields_id:
    if t_i[i] in ["平旱地", "梯田", "山坡地"]:
        T_hat_i_s[i, 1] = grains_A
        T_hat_i_s[i, 2] = np.array([])
    elif t_i[i] in ["水浇地"]:
        T_hat_i_s[i, 1] = np.concatenate([grains_B, vege_A])
        T_hat_i_s[i, 2] = vege_B
    elif t_i[i] in ["普通大棚"]:
        T_hat_i_s[i, 1] = vege_A
        T_hat_i_s[i, 2] = mush
    elif t_i[i] in ["智慧大棚"]:
        T_hat_i_s[i, 1] = vege_A
        T_hat_i_s[i, 2] = vege_A

# 市场互替性系数
R_ij = {}  # 作物 i 对作物 j 在市场上的互替性系数

# 将所有作物对初始化为 0
for i in crops_id:
    for j in crops_id:
        if i != j:
            R_ij[i, j] = 0


# 对于同类型的作物，其市场价格接近，互替性系数越高
# 定义一个函数来计算互替性系数
def calculate_substitutability(price_i, price_j):
    # 计算价格差距的百分比
    price_diff_percentage = abs(price_i - price_j) / ((price_i + price_j) / 2)
    # 使用一个简单的公式来量化互替性系数
    # 这里假设价格差距越小，互替性越高
    substitutability = max(0, 1 - price_diff_percentage)
    return substitutability


# 计算同类型作物之间的互替性系数
def calculate_R_ij_for_type(crop_ids):
    for i in crop_ids:
        for j in crop_ids:
            if i != j:
                price_i = stats_2023[stats_2023["Crop ID"] == i]["Per Price"].values[0]
                price_j = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
                if price_i is not None and price_j is not None:
                    R_ij[i, j] = calculate_substitutability(price_i, price_j)


# 假设 grains_A 是同类型作物的集合
calculate_R_ij_for_type(grains_A)
calculate_R_ij_for_type(grains_B)
calculate_R_ij_for_type(vege_A)
calculate_R_ij_for_type(vege_B)
calculate_R_ij_for_type(mush)
calculate_R_ij_for_type(beans)

print(R_ij)
# Out:
# {(1, 2): np.float64(0.2093023255813954), (1, 3): np.float64(0.13043478260869568), (1, 4): np.float64(0.2682926829268293), (1, 5): np.float64(0.30000000000000004), (1, 6): np.float64(0.9259259259259259), (1, 7): np.float64(0.92), (1, 8): np.float64(0.30000000000000004), (1, 9): np.float64(0.4054054054054054), (1, 10): np.float64(0.2093023255813954), (1, 11): 0, (1, 12): np.float64(0.26315789473684215), (1, 13): np.float64(1.0), (1, 14): np.float64(0.48571428571428577), (1, 15): np.float64(0.9259259259259259), (1, 16): 0, (1, 17): np.float64(0.15555555555555556), (1, 18): np.float64(0.30000000000000004), (1, 19): np.float64(0.33333333333333337), (1, 20): 0, (1, 21): 0, (1, 22): 0, (1, 23): 0, (1, 24): 0, (1, 25): 0, (1, 26): 0, (1, 27): 0, (1, 28): 0, (1, 29): 0, (1, 30): 0, (1, 31): 0, (1, 32): 0, (1, 33): 0, (1, 34): 0, (1, 35): 0, (1, 36): 0, (1, 37): 0, (1, 38): 0, (1, 39): 0, (1, 40): 0, (1, 41): 0, (2, 1): np.float64(0.2093023255813954), (2, 3): np.float64(0.9047619047619048), (2, 4): np.float64(0.9310344827586207), (2, 5): np.float64(0.8947368421052632), (2, 6): np.float64(0.2727272727272727), (2, 7): np.float64(0.1428571428571429), (2, 8): np.float64(0.8947368421052632), (2, 9): np.float64(0.7777777777777778), (2, 10): np.float64(1.0), (2, 11): 0, (2, 12): 0, (2, 13): np.float64(0.2093023255813954), (2, 14): np.float64(0.6923076923076923), (2, 15): np.float64(0.2727272727272727), (2, 16): 0, (2, 17): np.float64(0.935483870967742), (2, 18): np.float64(0.8947368421052632), (2, 19): np.float64(0.8571428571428572), (2, 20): 0, (2, 21): 0, (2, 22): 0, (2, 23): 0, (2, 24): 0, (2, 25): 0, (2, 26): 0, (2, 27): 0, (2, 28): 0, (2, 29): 0, (2, 30): 0, (2, 31): 0, (2, 32): 0, (2, 33): 0, (2, 34): 0, (2, 35): 0, (2, 36): 0, (2, 37): 0, (2, 38): 0, (2, 39): 0, (2, 40): 0, (2, 41): 0, (3, 1): np.float64(0.13043478260869568), (3, 2): np.float64(0.9047619047619048), (3, 4): np.float64(0.8360655737704918), (3, 5): np.float64(0.8), (3, 6): np.float64(0.19148936170212771), (3, 7): np.float64(0.06666666666666665), (3, 8): np.float64(0.8), (3, 9): np.float64(0.6842105263157895), (3, 10): np.float64(0.9047619047619048), (3, 11): 0, (3, 12): 0, (3, 13): np.float64(0.13043478260869568), (3, 14): np.float64(0.6), (3, 15): np.float64(0.19148936170212771), (3, 16): 0, (3, 17): np.float64(0.9692307692307692), (3, 18): np.float64(0.8), (3, 19): np.float64(0.7627118644067796), (3, 20): 0, (3, 21): 0, (3, 22): 0, (3, 23): 0, (3, 24): 0, (3, 25): 0, (3, 26): 0, (3, 27): 0, (3, 28): 0, (3, 29): 0, (3, 30): 0, (3, 31): 0, (3, 32): 0, (3, 33): 0, (3, 34): 0, (3, 35): 0, (3, 36): 0, (3, 37): 0, (3, 38): 0, (3, 39): 0, (3, 40): 0, (3, 41): 0, (4, 1): np.float64(0.2682926829268293), (4, 2): np.float64(0.9310344827586207), (4, 3): np.float64(0.8360655737704918), (4, 5): np.float64(0.9636363636363636), (4, 6): np.float64(0.33333333333333337), (4, 7): np.float64(0.19999999999999996), (4, 8): np.float64(0.9636363636363636), (4, 9): np.float64(0.8461538461538461), (4, 10): np.float64(0.9310344827586207), (4, 11): 0, (4, 12): 0, (4, 13): np.float64(0.2682926829268293), (4, 14): np.float64(0.76), (4, 15): np.float64(0.33333333333333337), (4, 16): 0, (4, 17): np.float64(0.8666666666666667), (4, 18): np.float64(0.9636363636363636), (4, 19): np.float64(0.9259259259259259), (4, 20): 0, (4, 21): 0, (4, 22): 0, (4, 23): 0, (4, 24): 0, (4, 25): 0, (4, 26): 0, (4, 27): 0, (4, 28): 0, (4, 29): 0, (4, 30): 0, (4, 31): 0, (4, 32): 0, (4, 33): 0, (4, 34): 0, (4, 35): 0, (4, 36): 0, (4, 37): 0, (4, 38): 0, (4, 39): 0, (4, 40): 0, (4, 41): 0, (5, 1): np.float64(0.30000000000000004), (5, 2): np.float64(0.8947368421052632), (5, 3): np.float64(0.8), (5, 4): np.float64(0.9636363636363636), (5, 6): np.float64(0.36585365853658536), (5, 7): np.float64(0.23076923076923073), (5, 8): np.float64(1.0), (5, 9): np.float64(0.8823529411764706), (5, 10): np.float64(0.8947368421052632), (5, 11): 0, (5, 12): 0, (5, 13): np.float64(0.30000000000000004), (5, 14): np.float64(0.7959183673469388), (5,  ...

# %%
dfs = []
times = 30  # 重复次数


def expected_selling(percost, price):
    return 8122.041 + 1.385 * percost - 1.2894625 * price


for i in range(times):
    # 使用当前时间作为随机数种子
    np.random.seed(datetime.datetime.now().second)

    S = {}  # 期望产量
    Y = {}  # 单位面积产量
    P = {}  # 售价
    C = {}  # 单位面积成本

    for j in crops_id:
        Y[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Yield"].values[0]
        P[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
        C[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Cost"].values[0]
        S[j, 2023] = expected_selling(C[j, 2023], P[j, 2023])

    for j in crops_id:
        # 小麦和玉米的预期销售量有平均5%-10%的年增长
        for k in years:

            # 农作物亩产量可能有±10%的变化.
            increment = np.random.uniform(-0.1, 0.1)
            Y[j, k + 1] = Y[j, k] * np.random.normal(1 + increment, 0.01)

            # 种植成本每年增长约5%。
            increment = 0.05
            C[j, k + 1] = C[j, k] * np.random.normal(1 + increment, 0.01)

            # 蔬菜类作物价格每年增长约5%。
            if j in vege_A or j in vege_B:
                increment = 0.05
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 食用菌价格每年下降1%-5%。
            if j in mush:
                increment = np.random.uniform(-0.05, -0.01)
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 羊肚菌的销售价格每年下降幅5%
            if j == 41:
                increment = -0.05
                P[j, k + 1] = P[j, k] * (1 + increment)
            else:
                P[j, k + 1] = P[j, k]

            S[j, k + 1] = expected_selling(C[j, k + 1], P[j, k + 1])

            if j in [6, 7]:
                increment = np.random.uniform(0.05, 0.1)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 其他作物的预期销售量变化约±5%。
            else:
                increment = np.random.uniform(-0.05, 0.05)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

    dfs.append(
        planning(
            fields_id,
            crops_id,
            seasons_id,
            years,
            t_i,
            T_hat_i_s,
            R_ij,
            grains_A,
            grains_B,
            vege_A,
            vege_B,
            mush,
            beans,
            stats_2023,
            [
                S,
                Y,
                P,
                C,
            ],
        )
    )
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c4bb6516a4b74d67865cabd4d7c81af5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/c4bb6516a4b74d67865cabd4d7c81af5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.29628e+08 - 0.55 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 16397 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23322 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24396 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26674 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26051 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22813 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18112 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18226 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21863 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 437340 elements
# Cbc0038I Initial state - 383 integers unsatisfied sum - 47.1233
# Cbc0038I Pass   1: (4.95 seconds) suminf.    4.50000 (15) obj. -1.17597e+08 iterations 2701
# Cbc0038I Pass   2: (4.99 seconds) suminf.    4.50000 (15) obj. -1.17597e+08 iterations 7
# Cbc0038I Pass   3: (5.02 seconds) suminf.    1.20000 (4) obj. -1.18119e+08 iterations 132
# Cbc0038I Pass   4: (5.06 seconds) suminf.    0.60000 (2) obj. -1.17946e+08 iterations 5
# Cbc0038I Pass   5: (5.10 seconds) suminf.    0.60000 (2) obj. -1.18162e+08 iterations 6
# Cbc0038I Pass   6: (5.16 seconds) suminf.   28.69162 (94) obj. -1.04041e+08 iterations 1145
# Cbc0038I Pass   7: (5.20 seconds) suminf.   22.48686 (78) obj. -1.04251e+08 iterations 125
# Cbc0038I Pass   8: (5.24 seconds) suminf.   22.48686 (78) obj. -1.04251e+08 iterations 1
# Cbc0038I Pass   9: (5.28 seconds) suminf.   21.49832 (73) obj. -1.03913e+08 iterations 167
# Cbc0038I Pass  10: (5.32 seconds) suminf.   20.38686 (71) obj. -1.0376e+08 iterations 14
# Cbc0038I Pass  11: (5.36 seconds) suminf.   20.69832 (71) obj. -1.04055e+08 iterations 34
# Cbc0038I Pass  12: (5.39 seconds) suminf.   20.38686 (71) obj. -1.03865e+08 iterations 7
# Cbc0038I Pass  13: (5.43 seconds) suminf.   19.60000 (66) obj. -1.03078e+08 iterations 103
# Cbc0038I Pass  14: (5.47 seconds) suminf.   19.38686 (68) obj. -1.0359e+08 iterations 6
# Cbc0038I Pass  15: (5.51 seconds) suminf.   20.09832 (69) obj. -1.03782e+08 iterations 92
# Cbc0038I Pass  16: (5.55 seconds) suminf.   19.78686 (69) obj. -1.03592e+08 iterations 7
# Cbc0038I Pass  17: (5.60 seconds) suminf.   20.09832 (69) obj. -1.03668e+08 iterations 34
# Cbc0038I Pass  18: (5.64 seconds) suminf.   19.78686 (69) obj. -1.03478e+08 iterations 7
# Cbc0038I Pass  19: (5.68 seconds) suminf.   19.70000 (65) obj. -1.03233e+08 iterations 122
# Cbc0038I Pass  20: (5.71 seconds) suminf.   19.08686 (67) obj. -1.03739e+08 iterations 39
# Cbc0038I Pass  21: (5.75 seconds) suminf.   20.19832 (68) obj. -1.03596e+08 iterations 134
# Cbc0038I Pass  22: (5.79 seconds) suminf.   19.48686 (68) obj. -1.034e+08 iterations 40
# Cbc0038I Pass  23: (5.83 seconds) suminf.   19.70000 (65) obj. -1.03168e+08 iterations 125
# Cbc0038I Pass  24: (5.87 seconds) suminf.   19.08686 (67) obj. -1.03674e+08 iterations 39
# Cbc0038I Pass  25: (5.90 seconds) suminf.   20.19832 (68) obj. -1.03592e+08 iterations 132
# Cbc0038I Pass  26: (5.94 seconds) suminf.   19.48686 (68) obj. -1.03396e+08 iterations 40
# Cbc0038I Pass  27: (5.98 seconds) suminf.   19.30000 (65) obj. -1.03161e+08 iterations 88
# Cbc0038I Pass  28: (6.06 seconds) suminf.   50.15339 (163) obj. -9.51856e+07 iterations 1187
# Cbc0038I Pass  29: (6.11 seconds) suminf.   33.67196 (120) obj. -9.52196e+07 iterations 314
# Cbc0038I Pass  30: (6.15 seconds) suminf.   33.93041 (120) obj. -9.50627e+07 iterations 154
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6507 integers at bound fixed and 5370 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 6712 rows 1459 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1.18754e+08 (7.03 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -1.18754e+08
# Cbc0038I Round again with cutoff of -1.18764e+08
# Cbc0038I Reduced cost fixing fixed 188 variables on major pass 2
# Cbc0038I Pass  30: (9.06 seconds) suminf.    0.83458 (6) obj. -1.18764e+08 iterations 2905
# Cbc0038I Pass  31: (9.13 seconds) suminf.    0.12231 (3) obj. -1.18764e+08 iterations 176
# Cbc0038I Pass  32: (9.37 seconds) suminf.    0.00000 (0) obj. -1.18764e+08 iterations 1299
# Cbc0038I Solution found of -1.18764e+08
# Cbc0038I Relaxing continuous gives -1.18788e+08
# Cbc0038I Before mini branch and bound, 6996 integers at bound fixed and 5766 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1536 rows 695 columns
# Cbc0038I Mini branch and bound improved solution from -1.18788e+08 to -1.18843e+08 (9.74 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -1.18843e+08
# Cbc0038I Round again with cutoff of -1.18845e+08
# Cbc0038I Reduced cost fixing fixed 1097 variables on major pass 3
# Cbc0038I Pass  33: (11.28 seconds) suminf.    4.05845 (178) obj. -1.18845e+08 iterations 1919
# Cbc0038I Pass  34: (11.41 seconds) suminf.    2.03873 (283) obj. -1.18845e+08 iterations 683
# Cbc0038I Pass  35: (11.82 seconds) suminf.    5.26239 (15) obj. -1.18845e+08 iterations 1974
# Cbc0038I Pass  36: (11.89 seconds) suminf.    5.00633 (15) obj. -1.18845e+08 iterations 176
# Cbc0038I Pass  37: (11.98 seconds) suminf.    5.20866 (16) obj. -1.18845e+08 iterations 309
# Cbc0038I Pass  38: (12.23 seconds) suminf.    2.54487 (121) obj. -1.18845e+08 iterations 1320
# Cbc0038I Pass  39: (12.37 seconds) suminf.    2.03873 (283) obj. -1.18845e+08 iterations 599
# Cbc0038I Pass  40: (12.72 seconds) suminf.    5.63294 (16) obj. -1.18845e+08 iterations 1851
# Cbc0038I Pass  41: (12.95 seconds) suminf.    2.83108 (45) obj. -1.18845e+08 iterations 981
# Cbc0038I Pass  42: (13.15 seconds) suminf.    5.19136 (197) obj. -1.18845e+08 iterations 1017
# Cbc0038I Pass  43: (13.24 seconds) suminf.    2.03873 (283) obj. -1.18845e+08 iterations 350
# Cbc0038I Pass  44: (13.32 seconds) suminf.    2.63961 (217) obj. -1.18845e+08 iterations 228
# Cbc0038I Pass  45: (13.39 seconds) suminf.    2.63881 (287) obj. -1.18845e+08 iterations 344
# Cbc0038I Pass  46: (13.46 seconds) suminf.    2.93873 (286) obj. -1.18845e+08 iterations 232
# Cbc0038I Pass  47: (13.53 seconds) suminf.    3.83897 (289) obj. -1.18845e+08 iterations 227
# Cbc0038I Pass  48: (13.61 seconds) suminf.    4.13979 (215) obj. -1.18845e+08 iterations 316
# Cbc0038I Pass  49: (13.68 seconds) suminf.    2.63963 (222) obj. -1.18845e+08 iterations 287
# Cbc0038I Pass  50: (13.75 seconds) suminf.    2.58961 (223) obj. -1.18845e+08 iterations 278
# Cbc0038I Pass  51: (13.83 seconds) suminf.    6.59425 (183) obj. -1.18845e+08 iterations 350
# Cbc0038I Pass  52: (13.89 seconds) suminf.    4.59138 (172) obj. -1.18845e+08 iterations 259
# Cbc0038I Pass  53: (13.96 seconds) suminf.    2.28860 (277) obj. -1.18845e+08 iterations 259
# Cbc0038I Pass  54: (14.01 seconds) suminf.    2.03873 (283) obj. -1.18845e+08 iterations 42
# Cbc0038I Pass  55: (14.36 seconds) suminf.    5.26239 (15) obj. -1.18845e+08 iterations 1764
# Cbc0038I Pass  56: (14.43 seconds) suminf.    5.00633 (15) obj. -1.18845e+08 iterations 166
# Cbc0038I Pass  57: (14.51 seconds) suminf.    5.20866 (16) obj. -1.18845e+08 iterations 253
# Cbc0038I Pass  58: (14.79 seconds) suminf.    2.54487 (121) obj. -1.18845e+08 iterations 1313
# Cbc0038I Pass  59: (14.93 seconds) suminf.    2.03873 (283) obj. -1.18845e+08 iterations 555
# Cbc0038I Pass  60: (15.28 seconds) suminf.    5.49123 (16) obj. -1.18845e+08 iterations 1715
# Cbc0038I Pass  61: (15.62 seconds) suminf.    2.55826 (172) obj. -1.18845e+08 iterations 1583
# Cbc0038I Pass  62: (15.69 seconds) suminf.    6.19675 (178) obj. -1.18845e+08 iterations 160
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6963 integers at bound fixed and 5754 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 2130 rows 726 columns
# Cbc0038I Mini branch and bound did not improve solution (15.86 seconds)
# Cbc0038I After 15.86 seconds - Feasibility pump exiting with objective of -1.18843e+08 - took 11.03 seconds
# Cbc0012I Integer solution of -1.1884344e+08 found by feasibility pump after 0 iterations and 0 nodes (16.04 seconds)
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1408 rows 652 columns
# Cbc0031I 177 added rows had average density of 6.2485876
# Cbc0013I At root node, 186 cuts changed objective from -1.1885127e+08 to -1.1884344e+08 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 209 row cuts average 2.3 elements, 4091 column cuts (4091 active)  in 0.130 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 81 row cuts average 16.0 elements, 0 column cuts (0 active)  in 0.064 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 65 row cuts average 14.3 elements, 0 column cuts (0 active)  in 0.040 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 132 row cuts average 18.3 elements, 0 column cuts (0 active)  in 0.113 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -118843440.9832909, took 276 iterations and 0 nodes (19.26 seconds)
# Cbc0035I Maximum depth 0, 1775 variables fixed on reduced cost
# Cuts at root node changed objective from -1.18851e+08 to -1.18843e+08
# Probing was tried 2 times and created 4300 cuts of which 0 were active after adding rounds of cuts (0.130 seconds)
# Gomory was tried 2 times and created 81 cuts of which 0 were active after adding rounds of cuts (0.064 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 2 times and created 65 cuts of which 0 were active after adding rounds of cuts (0.040 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# TwoMirCuts was tried 2 times and created 132 cuts of which 0 were active after adding rounds of cuts (0.113 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
#
# Result - Optimal solution found
#
# Objective value:                118843440.98329093
# Enumerated nodes:               0
# Total iterations:               276
# Time (CPU seconds):             21.98
# Time (Wallclock seconds):       22.32
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       22.26   (Wallclock seconds):       22.62
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d7121e2952714ad9888629ff579ec802-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/d7121e2952714ad9888629ff579ec802-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.26831e+08 - 0.50 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 15306 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22540 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25277 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23721 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25995 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24092 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20469 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19363 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20486 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 436735 elements
# Cbc0038I Initial state - 296 integers unsatisfied sum - 27.3518
# Cbc0038I Pass   1: (4.90 seconds) suminf.    0.00000 (0) obj. -1.21451e+08 iterations 2204
# Cbc0038I Solution found of -1.21451e+08
# Cbc0038I Relaxing continuous gives -1.21451e+08
# Cbc0038I Before mini branch and bound, 7087 integers at bound fixed and 5862 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1038 rows 491 columns
# Cbc0038I Mini branch and bound did not improve solution (5.08 seconds)
# Cbc0038I Round again with cutoff of -1.21456e+08
# Cbc0038I Reduced cost fixing fixed 423 variables on major pass 2
# Cbc0038I Pass   2: (7.09 seconds) suminf.    0.35164 (14) obj. -1.21456e+08 iterations 2851
# Cbc0038I Pass   3: (7.35 seconds) suminf.    0.60917 (2) obj. -1.21456e+08 iterations 1451
# Cbc0038I Pass   4: (7.61 seconds) suminf.    3.73250 (76) obj. -1.21456e+08 iterations 1799
# Cbc0038I Pass   5: (7.71 seconds) suminf.    2.88171 (55) obj. -1.21456e+08 iterations 412
# Cbc0038I Pass   6: (7.86 seconds) suminf.    3.79398 (27) obj. -1.21456e+08 iterations 721
# Cbc0038I Pass   7: (7.98 seconds) suminf.    3.61187 (72) obj. -1.21456e+08 iterations 615
# Cbc0038I Pass   8: (8.05 seconds) suminf.    3.61182 (68) obj. -1.21456e+08 iterations 274
# Cbc0038I Pass   9: (8.16 seconds) suminf.    6.69270 (38) obj. -1.21456e+08 iterations 515
# Cbc0038I Pass  10: (8.24 seconds) suminf.    4.31767 (64) obj. -1.21456e+08 iterations 206
# Cbc0038I Pass  11: (8.32 seconds) suminf.    6.46033 (86) obj. -1.21456e+08 iterations 334
# Cbc0038I Pass  12: (8.42 seconds) suminf.    4.99769 (68) obj. -1.21456e+08 iterations 378
# Cbc0038I Pass  13: (8.47 seconds) suminf.    4.99769 (68) obj. -1.21456e+08 iterations 48
# Cbc0038I Pass  14: (8.57 seconds) suminf.    6.00448 (88) obj. -1.21456e+08 iterations 453
# Cbc0038I Pass  15: (8.66 seconds) suminf.    5.22420 (69) obj. -1.21456e+08 iterations 381
# Cbc0038I Pass  16: (8.70 seconds) suminf.    5.68573 (69) obj. -1.21456e+08 iterations 1
# Cbc0038I Pass  17: (8.78 seconds) suminf.    5.39868 (85) obj. -1.21456e+08 iterations 287
# Cbc0038I Pass  18: (8.84 seconds) suminf.    5.16781 (69) obj. -1.21456e+08 iterations 213
# Cbc0038I Pass  19: (8.97 seconds) suminf.    6.42425 (38) obj. -1.21456e+08 iterations 581
# Cbc0038I Pass  20: (9.06 seconds) suminf.    4.92616 (64) obj. -1.21456e+08 iterations 211
# Cbc0038I Pass  21: (9.12 seconds) suminf.    4.34202 (68) obj. -1.21456e+08 iterations 56
# Cbc0038I Pass  22: (9.16 seconds) suminf.    4.34202 (68) obj. -1.21456e+08 iterations 42
# Cbc0038I Pass  23: (9.25 seconds) suminf.    5.65018 (127) obj. -1.21456e+08 iterations 376
# Cbc0038I Pass  24: (9.32 seconds) suminf.    5.11922 (116) obj. -1.21456e+08 iterations 238
# Cbc0038I Pass  25: (9.36 seconds) suminf.    5.58076 (116) obj. -1.21456e+08 iterations 1
# Cbc0038I Pass  26: (9.43 seconds) suminf.    5.96032 (124) obj. -1.21456e+08 iterations 281
# Cbc0038I Pass  27: (9.51 seconds) suminf.    5.49865 (107) obj. -1.21456e+08 iterations 236
# Cbc0038I Pass  28: (9.64 seconds) suminf.    5.68621 (24) obj. -1.21456e+08 iterations 588
# Cbc0038I Pass  29: (9.77 seconds) suminf.    4.88050 (68) obj. -1.21456e+08 iterations 536
# Cbc0038I Pass  30: (9.89 seconds) suminf.    6.14843 (38) obj. -1.21456e+08 iterations 549
# Cbc0038I Pass  31: (10.02 seconds) suminf.    6.56028 (81) obj. -1.21456e+08 iterations 602
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7048 integers at bound fixed and 5813 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1567 rows 581 columns
# Cbc0038I Mini branch and bound did not improve solution (10.16 seconds)
# Cbc0038I After 10.16 seconds - Feasibility pump exiting with objective of -1.21451e+08 - took 5.40 seconds
# Cbc0012I Integer solution of -1.2145128e+08 found by feasibility pump after 0 iterations and 0 nodes (10.32 seconds)
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1048 rows 496 columns
# Cbc0031I 162 added rows had average density of 6.0802469
# Cbc0013I At root node, 162 cuts changed objective from -1.2149865e+08 to -1.2145128e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 176 row cuts average 2.0 elements, 4237 column cuts (4237 active)  in 0.129 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 63 row cuts average 15.4 elements, 0 column cuts (0 active)  in 0.066 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.041 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 33 row cuts average 12.3 elements, 0 column cuts (0 active)  in 0.057 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.048 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 93 row cuts average 19.3 elements, 0 column cuts (0 active)  in 0.110 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -121451278.7660352, took 334 iterations and 0 nodes (12.93 seconds)
# Cbc0032I Strong branching done 2 times (3 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 1744 variables fixed on reduced cost
# Cuts at root node changed objective from -1.21499e+08 to -1.21451e+08
# Probing was tried 3 times and created 4413 cuts of which 0 were active after adding rounds of cuts (0.129 seconds)
# Gomory was tried 3 times and created 63 cuts of which 0 were active after adding rounds of cuts (0.066 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 3 times and created 33 cuts of which 0 were active after adding rounds of cuts (0.057 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.048 seconds)
# TwoMirCuts was tried 3 times and created 93 cuts of which 0 were active after adding rounds of cuts (0.110 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
#
# Result - Optimal solution found
#
# Objective value:                121451278.76603515
# Enumerated nodes:               0
# Total iterations:               334
# Time (CPU seconds):             15.72
# Time (Wallclock seconds):       16.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       16.01   (Wallclock seconds):       16.39
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0eba6caf2a154662bebb9dd048aa3ea3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/0eba6caf2a154662bebb9dd048aa3ea3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.37321e+08 - 0.55 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 15586 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23245 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26501 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25557 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28285 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24872 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20354 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20509 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24165 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 448560 elements
# Cbc0038I Initial state - 549 integers unsatisfied sum - 81.9023
# Cbc0038I Pass   1: (5.24 seconds) suminf.    1.20000 (4) obj. -1.27869e+08 iterations 2830
# Cbc0038I Pass   2: (5.28 seconds) suminf.    0.60000 (2) obj. -1.2787e+08 iterations 2
# Cbc0038I Pass   3: (5.31 seconds) suminf.    0.60000 (2) obj. -1.2786e+08 iterations 4
# Cbc0038I Pass   4: (5.39 seconds) suminf.   21.80000 (68) obj. -1.13133e+08 iterations 1103
# Cbc0038I Pass   5: (5.42 seconds) suminf.   17.50000 (58) obj. -1.13226e+08 iterations 109
# Cbc0038I Pass   6: (5.46 seconds) suminf.   14.70000 (48) obj. -1.149e+08 iterations 173
# Cbc0038I Pass   7: (5.50 seconds) suminf.   13.80000 (46) obj. -1.14876e+08 iterations 40
# Cbc0038I Pass   8: (5.54 seconds) suminf.   14.80000 (47) obj. -1.14529e+08 iterations 75
# Cbc0038I Pass   9: (5.58 seconds) suminf.   14.20000 (47) obj. -1.14343e+08 iterations 20
# Cbc0038I Pass  10: (5.62 seconds) suminf.   14.60000 (48) obj. -1.13068e+08 iterations 140
# Cbc0038I Pass  11: (5.66 seconds) suminf.   13.80000 (46) obj. -1.13052e+08 iterations 21
# Cbc0038I Pass  12: (5.70 seconds) suminf.   14.40000 (46) obj. -1.12387e+08 iterations 145
# Cbc0038I Pass  13: (5.74 seconds) suminf.   13.80000 (46) obj. -1.12375e+08 iterations 17
# Cbc0038I Pass  14: (5.78 seconds) suminf.   14.10000 (46) obj. -1.12891e+08 iterations 52
# Cbc0038I Pass  15: (5.82 seconds) suminf.   13.80000 (46) obj. -1.12885e+08 iterations 15
# Cbc0038I Pass  16: (5.86 seconds) suminf.   14.10000 (46) obj. -1.12381e+08 iterations 50
# Cbc0038I Pass  17: (5.90 seconds) suminf.   33.71905 (108) obj. -9.93399e+07 iterations 996
# Cbc0038I Pass  18: (5.94 seconds) suminf.   26.36667 (87) obj. -9.92402e+07 iterations 225
# Cbc0038I Pass  19: (5.96 seconds) suminf.   26.36667 (87) obj. -9.92402e+07 iterations 0
# Cbc0038I Pass  20: (6.00 seconds) suminf.   25.30000 (82) obj. -9.85354e+07 iterations 135
# Cbc0038I Pass  21: (6.04 seconds) suminf.   24.60000 (81) obj. -9.84425e+07 iterations 32
# Cbc0038I Pass  22: (6.08 seconds) suminf.   25.10000 (81) obj. -9.85659e+07 iterations 27
# Cbc0038I Pass  23: (6.12 seconds) suminf.   24.60000 (81) obj. -9.84702e+07 iterations 30
# Cbc0038I Pass  24: (6.16 seconds) suminf.   24.80000 (80) obj. -9.85976e+07 iterations 66
# Cbc0038I Pass  25: (6.20 seconds) suminf.   24.30000 (80) obj. -9.85019e+07 iterations 30
# Cbc0038I Pass  26: (6.24 seconds) suminf.   25.00000 (80) obj. -9.85668e+07 iterations 68
# Cbc0038I Pass  27: (6.28 seconds) suminf.   24.30000 (80) obj. -9.84772e+07 iterations 37
# Cbc0038I Pass  28: (6.33 seconds) suminf.   25.00000 (79) obj. -9.83616e+07 iterations 108
# Cbc0038I Pass  29: (6.37 seconds) suminf.   24.00000 (79) obj. -9.82389e+07 iterations 50
# Cbc0038I Pass  30: (6.41 seconds) suminf.   25.00000 (78) obj. -9.83607e+07 iterations 125
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6401 integers at bound fixed and 5287 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 6691 rows 1679 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1.2779e+08 (7.48 seconds)
# Cbc0038I Round again with cutoff of -1.27811e+08
# Cbc0038I Reduced cost fixing fixed 39 variables on major pass 2
# Cbc0038I Pass  30: (7.61 seconds) suminf.    1.20000 (4) obj. -1.27869e+08 iterations 0
# Cbc0038I Pass  31: (7.65 seconds) suminf.    0.60000 (2) obj. -1.2787e+08 iterations 5
# Cbc0038I Pass  32: (7.69 seconds) suminf.    0.60000 (2) obj. -1.27846e+08 iterations 14
# Cbc0038I Pass  33: (8.09 seconds) suminf.    5.35830 (104) obj. -1.27811e+08 iterations 2973
# Cbc0038I Pass  34: (8.30 seconds) suminf.    1.93912 (7) obj. -1.27811e+08 iterations 1092
# Cbc0038I Pass  35: (8.35 seconds) suminf.    1.03557 (4) obj. -1.27811e+08 iterations 103
# Cbc0038I Pass  36: (8.47 seconds) suminf.    1.48418 (40) obj. -1.27811e+08 iterations 465
# Cbc0038I Pass  37: (8.59 seconds) suminf.    1.05494 (4) obj. -1.27811e+08 iterations 483
# Cbc0038I Pass  38: (8.69 seconds) suminf.    1.50908 (5) obj. -1.27811e+08 iterations 332
# Cbc0038I Pass  39: (8.77 seconds) suminf.    1.40101 (4) obj. -1.27811e+08 iterations 201
# Cbc0038I Pass  40: (8.91 seconds) suminf.    1.07289 (26) obj. -1.27811e+08 iterations 618
# Cbc0038I Pass  41: (9.08 seconds) suminf.    4.10222 (109) obj. -1.27811e+08 iterations 731
# Cbc0038I Pass  42: (9.21 seconds) suminf.    2.11977 (44) obj. -1.27811e+08 iterations 595
# Cbc0038I Pass  43: (9.25 seconds) suminf.    2.11977 (44) obj. -1.27811e+08 iterations 2
# Cbc0038I Pass  44: (9.32 seconds) suminf.    2.81425 (97) obj. -1.27811e+08 iterations 169
# Cbc0038I Pass  45: (9.36 seconds) suminf.    1.67433 (91) obj. -1.27811e+08 iterations 9
# Cbc0038I Pass  46: (9.49 seconds) suminf.    1.74625 (5) obj. -1.27811e+08 iterations 606
# Cbc0038I Pass  47: (9.62 seconds) suminf.    1.08584 (27) obj. -1.27811e+08 iterations 524
# Cbc0038I Pass  48: (9.78 seconds) suminf.    3.93356 (114) obj. -1.27811e+08 iterations 690
# Cbc0038I Pass  49: (9.99 seconds) suminf.    1.82520 (92) obj. -1.27811e+08 iterations 1115
# Cbc0038I Pass  50: (10.03 seconds) suminf.    1.52520 (91) obj. -1.27811e+08 iterations 1
# Cbc0038I Pass  51: (10.20 seconds) suminf.    1.72128 (5) obj. -1.27811e+08 iterations 713
# Cbc0038I Pass  52: (10.33 seconds) suminf.    1.04254 (27) obj. -1.27811e+08 iterations 542
# Cbc0038I Pass  53: (10.48 seconds) suminf.    4.68656 (112) obj. -1.27811e+08 iterations 688
# Cbc0038I Pass  54: (10.61 seconds) suminf.    1.43699 (27) obj. -1.27811e+08 iterations 650
# Cbc0038I Pass  55: (10.70 seconds) suminf.    1.85121 (5) obj. -1.27811e+08 iterations 311
# Cbc0038I Pass  56: (10.82 seconds) suminf.    1.09108 (27) obj. -1.27811e+08 iterations 350
# Cbc0038I Pass  57: (10.92 seconds) suminf.    1.58756 (48) obj. -1.27811e+08 iterations 335
# Cbc0038I Pass  58: (11.05 seconds) suminf.    3.13195 (105) obj. -1.27811e+08 iterations 514
# Cbc0038I Pass  59: (11.23 seconds) suminf.    1.48538 (27) obj. -1.27811e+08 iterations 887
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6747 integers at bound fixed and 5577 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 3220 rows 1083 columns
# Cbc0038I Mini branch and bound improved solution from -1.2779e+08 to -1.27969e+08 (11.81 seconds)
# Cbc0038I Round again with cutoff of -1.27976e+08
# Cbc0038I Reduced cost fixing fixed 390 variables on major pass 3
# Cbc0038I Pass  59: (15.02 seconds) suminf.    7.33928 (173) obj. -1.27976e+08 iterations 4601
# Cbc0038I Pass  60: (15.07 seconds) suminf.    6.86180 (172) obj. -1.27976e+08 iterations 7
# Cbc0038I Pass  61: (15.12 seconds) suminf.    5.80836 (175) obj. -1.27976e+08 iterations 55
# Cbc0038I Pass  62: (15.19 seconds) suminf.    5.35887 (171) obj. -1.27976e+08 iterations 175
# Cbc0038I Pass  63: (15.34 seconds) suminf.    5.40924 (56) obj. -1.27976e+08 iterations 776
# Cbc0038I Pass  64: (15.44 seconds) suminf.    6.12700 (175) obj. -1.27976e+08 iterations 830
# Cbc0038I Pass  65: (15.51 seconds) suminf.    6.12700 (175) obj. -1.27976e+08 iterations 189
# Cbc0038I Pass  66: (15.68 seconds) suminf.    6.69634 (60) obj. -1.27976e+08 iterations 763
# Cbc0038I Pass  67: (15.77 seconds) suminf.    7.15229 (179) obj. -1.27976e+08 iterations 686
# Cbc0038I Pass  68: (15.86 seconds) suminf.    6.86407 (175) obj. -1.27976e+08 iterations 449
# Cbc0038I Pass  69: (15.97 seconds) suminf.    8.69558 (183) obj. -1.27976e+08 iterations 519
# Cbc0038I Pass  70: (16.03 seconds) suminf.    7.09773 (176) obj. -1.27976e+08 iterations 148
# Cbc0038I Pass  71: (16.11 seconds) suminf.    7.67360 (171) obj. -1.27976e+08 iterations 263
# Cbc0038I Pass  72: (16.20 seconds) suminf.    8.25605 (170) obj. -1.27976e+08 iterations 423
# Cbc0038I Pass  73: (16.29 seconds) suminf.    8.41640 (183) obj. -1.27976e+08 iterations 412
# Cbc0038I Pass  74: (16.38 seconds) suminf.    6.93395 (178) obj. -1.27976e+08 iterations 307
# Cbc0038I Pass  75: (16.45 seconds) suminf.    7.56739 (179) obj. -1.27976e+08 iterations 375
# Cbc0038I Pass  76: (16.52 seconds) suminf.    7.12390 (177) obj. -1.27976e+08 iterations 172
# Cbc0038I Pass  77: (16.56 seconds) suminf.    7.12390 (177) obj. -1.27976e+08 iterations 1
# Cbc0038I Pass  78: (16.62 seconds) suminf.    8.14616 (185) obj. -1.27976e+08 iterations 249
# Cbc0038I Pass  79: (16.70 seconds) suminf.    7.95533 (185) obj. -1.27976e+08 iterations 308
# Cbc0038I Pass  80: (16.82 seconds) suminf.   11.36152 (188) obj. -1.27976e+08 iterations 555
# Cbc0038I Pass  81: (16.89 seconds) suminf.    8.45123 (179) obj. -1.27976e+08 iterations 204
# Cbc0038I Pass  82: (16.93 seconds) suminf.    8.45123 (179) obj. -1.27976e+08 iterations 1
# Cbc0038I Pass  83: (17.01 seconds) suminf.   10.90077 (185) obj. -1.27976e+08 iterations 241
# Cbc0038I Pass  84: (17.09 seconds) suminf.    8.45123 (179) obj. -1.27976e+08 iterations 218
# Cbc0038I Pass  85: (17.17 seconds) suminf.   10.60966 (186) obj. -1.27976e+08 iterations 211
# Cbc0038I Pass  86: (17.24 seconds) suminf.    9.21978 (181) obj. -1.27976e+08 iterations 211
# Cbc0038I Pass  87: (17.26 seconds) suminf.    9.21978 (181) obj. -1.27976e+08 iterations 0
# Cbc0038I Pass  88: (17.29 seconds) suminf.    9.21978 (181) obj. -1.27976e+08 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6793 integers at bound fixed and 5639 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 3265 rows 978 columns
# Cbc0038I Mini branch and bound did not improve solution (17.96 seconds)
# Cbc0038I After 17.96 seconds - Feasibility pump exiting with objective of -1.27969e+08 - took 12.84 seconds
# Cbc0012I Integer solution of -1.2796926e+08 found by feasibility pump after 0 iterations and 0 nodes (18.14 seconds)
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1955 rows 900 columns
# Cbc0012I Integer solution of -1.2797016e+08 found by DiveCoefficient after 413 iterations and 0 nodes (21.36 seconds)
# Cbc0031I 201 added rows had average density of 7.6069652
# Cbc0013I At root node, 201 cuts changed objective from -1.280043e+08 to -1.2797016e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 160 row cuts average 2.1 elements, 4134 column cuts (4134 active)  in 0.142 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 177 row cuts average 17.5 elements, 0 column cuts (0 active)  in 0.129 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.040 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 160 row cuts average 10.7 elements, 0 column cuts (0 active)  in 0.057 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 3 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.048 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 202 row cuts average 18.7 elements, 0 column cuts (0 active)  in 0.228 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -127970158.8217624, took 413 iterations and 0 nodes (21.41 seconds)
# Cbc0035I Maximum depth 0, 1569 variables fixed on reduced cost
# Cuts at root node changed objective from -1.28004e+08 to -1.2797e+08
# Probing was tried 3 times and created 4294 cuts of which 0 were active after adding rounds of cuts (0.142 seconds)
# Gomory was tried 3 times and created 177 cuts of which 0 were active after adding rounds of cuts (0.129 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.040 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 3 times and created 160 cuts of which 0 were active after adding rounds of cuts (0.057 seconds)
# FlowCover was tried 3 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.048 seconds)
# TwoMirCuts was tried 3 times and created 202 cuts of which 0 were active after adding rounds of cuts (0.228 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
#
# Result - Optimal solution found
#
# Objective value:                127970158.82176240
# Enumerated nodes:               0
# Total iterations:               413
# Time (CPU seconds):             24.26
# Time (Wallclock seconds):       24.66
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       24.57   (Wallclock seconds):       24.99
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b9dd008b0b094216b1da474dc3ce3dae-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/b9dd008b0b094216b1da474dc3ce3dae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.26831e+08 - 0.52 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 15306 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22540 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25277 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23721 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25995 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24092 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20469 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19363 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20486 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 436735 elements
# Cbc0038I Initial state - 296 integers unsatisfied sum - 27.3518
# Cbc0038I Pass   1: (5.05 seconds) suminf.    0.00000 (0) obj. -1.21451e+08 iterations 2204
# Cbc0038I Solution found of -1.21451e+08
# Cbc0038I Relaxing continuous gives -1.21451e+08
# Cbc0038I Before mini branch and bound, 7087 integers at bound fixed and 5862 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1038 rows 491 columns
# Cbc0038I Mini branch and bound did not improve solution (5.25 seconds)
# Cbc0038I Round again with cutoff of -1.21456e+08
# Cbc0038I Reduced cost fixing fixed 423 variables on major pass 2
# Cbc0038I Pass   2: (7.31 seconds) suminf.    0.35164 (14) obj. -1.21456e+08 iterations 2851
# Cbc0038I Pass   3: (7.57 seconds) suminf.    0.60917 (2) obj. -1.21456e+08 iterations 1451
# Cbc0038I Pass   4: (7.84 seconds) suminf.    3.73250 (76) obj. -1.21456e+08 iterations 1799
# Cbc0038I Pass   5: (7.94 seconds) suminf.    2.88171 (55) obj. -1.21456e+08 iterations 412
# Cbc0038I Pass   6: (8.10 seconds) suminf.    3.79398 (27) obj. -1.21456e+08 iterations 721
# Cbc0038I Pass   7: (8.23 seconds) suminf.    3.61187 (72) obj. -1.21456e+08 iterations 615
# Cbc0038I Pass   8: (8.30 seconds) suminf.    3.61182 (68) obj. -1.21456e+08 iterations 274
# Cbc0038I Pass   9: (8.42 seconds) suminf.    6.69270 (38) obj. -1.21456e+08 iterations 515
# Cbc0038I Pass  10: (8.50 seconds) suminf.    4.31767 (64) obj. -1.21456e+08 iterations 206
# Cbc0038I Pass  11: (8.59 seconds) suminf.    6.46033 (86) obj. -1.21456e+08 iterations 334
# Cbc0038I Pass  12: (8.68 seconds) suminf.    4.99769 (68) obj. -1.21456e+08 iterations 378
# Cbc0038I Pass  13: (8.73 seconds) suminf.    4.99769 (68) obj. -1.21456e+08 iterations 48
# Cbc0038I Pass  14: (8.83 seconds) suminf.    6.00448 (88) obj. -1.21456e+08 iterations 453
# Cbc0038I Pass  15: (8.92 seconds) suminf.    5.22420 (69) obj. -1.21456e+08 iterations 381
# Cbc0038I Pass  16: (8.96 seconds) suminf.    5.68573 (69) obj. -1.21456e+08 iterations 1
# Cbc0038I Pass  17: (9.04 seconds) suminf.    5.39868 (85) obj. -1.21456e+08 iterations 287
# Cbc0038I Pass  18: (9.09 seconds) suminf.    5.16781 (69) obj. -1.21456e+08 iterations 213
# Cbc0038I Pass  19: (9.22 seconds) suminf.    6.42425 (38) obj. -1.21456e+08 iterations 581
# Cbc0038I Pass  20: (9.30 seconds) suminf.    4.92616 (64) obj. -1.21456e+08 iterations 211
# Cbc0038I Pass  21: (9.36 seconds) suminf.    4.34202 (68) obj. -1.21456e+08 iterations 56
# Cbc0038I Pass  22: (9.41 seconds) suminf.    4.34202 (68) obj. -1.21456e+08 iterations 42
# Cbc0038I Pass  23: (9.50 seconds) suminf.    5.65018 (127) obj. -1.21456e+08 iterations 376
# Cbc0038I Pass  24: (9.57 seconds) suminf.    5.11922 (116) obj. -1.21456e+08 iterations 238
# Cbc0038I Pass  25: (9.61 seconds) suminf.    5.58076 (116) obj. -1.21456e+08 iterations 1
# Cbc0038I Pass  26: (9.68 seconds) suminf.    5.96032 (124) obj. -1.21456e+08 iterations 281
# Cbc0038I Pass  27: (9.76 seconds) suminf.    5.49865 (107) obj. -1.21456e+08 iterations 236
# Cbc0038I Pass  28: (9.89 seconds) suminf.    5.68621 (24) obj. -1.21456e+08 iterations 588
# Cbc0038I Pass  29: (10.02 seconds) suminf.    4.88050 (68) obj. -1.21456e+08 iterations 536
# Cbc0038I Pass  30: (10.14 seconds) suminf.    6.14843 (38) obj. -1.21456e+08 iterations 549
# Cbc0038I Pass  31: (10.28 seconds) suminf.    6.56028 (81) obj. -1.21456e+08 iterations 602
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7048 integers at bound fixed and 5813 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1567 rows 581 columns
# Cbc0038I Mini branch and bound did not improve solution (10.42 seconds)
# Cbc0038I After 10.42 seconds - Feasibility pump exiting with objective of -1.21451e+08 - took 5.49 seconds
# Cbc0012I Integer solution of -1.2145128e+08 found by feasibility pump after 0 iterations and 0 nodes (10.59 seconds)
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1048 rows 496 columns
# Cbc0031I 162 added rows had average density of 6.0802469
# Cbc0013I At root node, 162 cuts changed objective from -1.2149865e+08 to -1.2145128e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 176 row cuts average 2.0 elements, 4237 column cuts (4237 active)  in 0.127 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 63 row cuts average 15.4 elements, 0 column cuts (0 active)  in 0.062 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.036 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 33 row cuts average 12.3 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 93 row cuts average 19.3 elements, 0 column cuts (0 active)  in 0.107 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -121451278.7660352, took 334 iterations and 0 nodes (13.22 seconds)
# Cbc0032I Strong branching done 2 times (3 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 1744 variables fixed on reduced cost
# Cuts at root node changed objective from -1.21499e+08 to -1.21451e+08
# Probing was tried 3 times and created 4413 cuts of which 0 were active after adding rounds of cuts (0.127 seconds)
# Gomory was tried 3 times and created 63 cuts of which 0 were active after adding rounds of cuts (0.062 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.036 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 3 times and created 33 cuts of which 0 were active after adding rounds of cuts (0.053 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# TwoMirCuts was tried 3 times and created 93 cuts of which 0 were active after adding rounds of cuts (0.107 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
#
# Result - Optimal solution found
#
# Objective value:                121451278.76603515
# Enumerated nodes:               0
# Total iterations:               334
# Time (CPU seconds):             16.15
# Time (Wallclock seconds):       16.46
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       16.46   (Wallclock seconds):       16.76
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0b217e5b4a954314a2c3f332efb8349c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/0b217e5b4a954314a2c3f332efb8349c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.37321e+08 - 0.51 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 15586 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23245 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26501 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25557 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28285 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24872 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20354 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20509 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24165 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 448560 elements
# Cbc0038I Initial state - 549 integers unsatisfied sum - 81.9023
# Cbc0038I Pass   1: (5.07 seconds) suminf.    1.20000 (4) obj. -1.27869e+08 iterations 2830
# Cbc0038I Pass   2: (5.11 seconds) suminf.    0.60000 (2) obj. -1.2787e+08 iterations 2
# Cbc0038I Pass   3: (5.14 seconds) suminf.    0.60000 (2) obj. -1.2786e+08 iterations 4
# Cbc0038I Pass   4: (5.22 seconds) suminf.   21.80000 (68) obj. -1.13133e+08 iterations 1103
# Cbc0038I Pass   5: (5.26 seconds) suminf.   17.50000 (58) obj. -1.13226e+08 iterations 109
# Cbc0038I Pass   6: (5.30 seconds) suminf.   14.70000 (48) obj. -1.149e+08 iterations 173
# Cbc0038I Pass   7: (5.33 seconds) suminf.   13.80000 (46) obj. -1.14876e+08 iterations 40
# Cbc0038I Pass   8: (5.37 seconds) suminf.   14.80000 (47) obj. -1.14529e+08 iterations 75
# Cbc0038I Pass   9: (5.40 seconds) suminf.   14.20000 (47) obj. -1.14343e+08 iterations 20
# Cbc0038I Pass  10: (5.44 seconds) suminf.   14.60000 (48) obj. -1.13068e+08 iterations 140
# Cbc0038I Pass  11: (5.48 seconds) suminf.   13.80000 (46) obj. -1.13052e+08 iterations 21
# Cbc0038I Pass  12: (5.52 seconds) suminf.   14.40000 (46) obj. -1.12387e+08 iterations 145
# Cbc0038I Pass  13: (5.55 seconds) suminf.   13.80000 (46) obj. -1.12375e+08 iterations 17
# Cbc0038I Pass  14: (5.59 seconds) suminf.   14.10000 (46) obj. -1.12891e+08 iterations 52
# Cbc0038I Pass  15: (5.63 seconds) suminf.   13.80000 (46) obj. -1.12885e+08 iterations 15
# Cbc0038I Pass  16: (5.66 seconds) suminf.   14.10000 (46) obj. -1.12381e+08 iterations 50
# Cbc0038I Pass  17: (5.72 seconds) suminf.   33.71905 (108) obj. -9.93399e+07 iterations 996
# Cbc0038I Pass  18: (5.76 seconds) suminf.   26.36667 (87) obj. -9.92402e+07 iterations 225
# Cbc0038I Pass  19: (5.78 seconds) suminf.   26.36667 (87) obj. -9.92402e+07 iterations 0
# Cbc0038I Pass  20: (5.82 seconds) suminf.   25.30000 (82) obj. -9.85354e+07 iterations 135
# Cbc0038I Pass  21: (5.86 seconds) suminf.   24.60000 (81) obj. -9.84425e+07 iterations 32
# Cbc0038I Pass  22: (5.90 seconds) suminf.   25.10000 (81) obj. -9.85659e+07 iterations 27
# Cbc0038I Pass  23: (5.94 seconds) suminf.   24.60000 (81) obj. -9.84702e+07 iterations 30
# Cbc0038I Pass  24: (5.98 seconds) suminf.   24.80000 (80) obj. -9.85976e+07 iterations 66
# Cbc0038I Pass  25: (6.02 seconds) suminf.   24.30000 (80) obj. -9.85019e+07 iterations 30
# Cbc0038I Pass  26: (6.06 seconds) suminf.   25.00000 (80) obj. -9.85668e+07 iterations 68
# Cbc0038I Pass  27: (6.10 seconds) suminf.   24.30000 (80) obj. -9.84772e+07 iterations 37
# Cbc0038I Pass  28: (6.14 seconds) suminf.   25.00000 (79) obj. -9.83616e+07 iterations 108
# Cbc0038I Pass  29: (6.18 seconds) suminf.   24.00000 (79) obj. -9.82389e+07 iterations 50
# Cbc0038I Pass  30: (6.21 seconds) suminf.   25.00000 (78) obj. -9.83607e+07 iterations 125
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6401 integers at bound fixed and 5287 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 6691 rows 1679 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1.2779e+08 (7.25 seconds)
# Cbc0038I Round again with cutoff of -1.27811e+08
# Cbc0038I Reduced cost fixing fixed 39 variables on major pass 2
# Cbc0038I Pass  30: (7.39 seconds) suminf.    1.20000 (4) obj. -1.27869e+08 iterations 0
# Cbc0038I Pass  31: (7.42 seconds) suminf.    0.60000 (2) obj. -1.2787e+08 iterations 5
# Cbc0038I Pass  32: (7.46 seconds) suminf.    0.60000 (2) obj. -1.27846e+08 iterations 14
# Cbc0038I Pass  33: (7.85 seconds) suminf.    5.35830 (104) obj. -1.27811e+08 iterations 2973
# Cbc0038I Pass  34: (8.06 seconds) suminf.    1.93912 (7) obj. -1.27811e+08 iterations 1092
# Cbc0038I Pass  35: (8.11 seconds) suminf.    1.03557 (4) obj. -1.27811e+08 iterations 103
# Cbc0038I Pass  36: (8.22 seconds) suminf.    1.48418 (40) obj. -1.27811e+08 iterations 465
# Cbc0038I Pass  37: (8.33 seconds) suminf.    1.05494 (4) obj. -1.27811e+08 iterations 483
# Cbc0038I Pass  38: (8.43 seconds) suminf.    1.50908 (5) obj. -1.27811e+08 iterations 332
# Cbc0038I Pass  39: (8.50 seconds) suminf.    1.40101 (4) obj. -1.27811e+08 iterations 201
# Cbc0038I Pass  40: (8.64 seconds) suminf.    1.07289 (26) obj. -1.27811e+08 iterations 618
# Cbc0038I Pass  41: (8.79 seconds) suminf.    4.10222 (109) obj. -1.27811e+08 iterations 731
# Cbc0038I Pass  42: (8.92 seconds) suminf.    2.11977 (44) obj. -1.27811e+08 iterations 595
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.29523e+08 - 0.56 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 15194 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22663 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25667 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25642 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26400 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23886 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21428 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19322 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23471 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 443159 elements
# Cbc0038I Initial state - 308 integers unsatisfied sum - 34.6437
# Cbc0038I Pass   1: (5.25 seconds) suminf.    0.00000 (0) obj. -1.22648e+08 iterations 2756
# Cbc0038I Solution found of -1.22648e+08
# Cbc0038I Relaxing continuous gives -1.22648e+08
# Cbc0038I Before mini branch and bound, 7075 integers at bound fixed and 5848 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1135 rows 528 columns
# Cbc0038I Mini branch and bound did not improve solution (5.48 seconds)
# Cbc0038I Round again with cutoff of -1.2266e+08
# Cbc0038I Reduced cost fixing fixed 136 variables on major pass 2
# Cbc0038I Pass   2: (7.23 seconds) suminf.    0.16226 (2) obj. -1.2266e+08 iterations 2191
# Cbc0038I Pass   3: (7.35 seconds) suminf.    0.68641 (2) obj. -1.2266e+08 iterations 654
# Cbc0038I Pass   4: (7.67 seconds) suminf.    2.42790 (53) obj. -1.2266e+08 iterations 2090
# Cbc0038I Pass   5: (7.74 seconds) suminf.    1.56023 (41) obj. -1.2266e+08 iterations 285
# Cbc0038I Pass   6: (7.92 seconds) suminf.    1.15875 (4) obj. -1.2266e+08 iterations 855
# Cbc0038I Pass   7: (8.02 seconds) suminf.    1.20814 (4) obj. -1.2266e+08 iterations 417
# Cbc0038I Pass   8: (8.27 seconds) suminf.    1.67061 (48) obj. -1.2266e+08 iterations 1595
# Cbc0038I Pass   9: (8.51 seconds) suminf.    1.15012 (4) obj. -1.2266e+08 iterations 1242
# Cbc0038I Pass  10: (8.61 seconds) suminf.    1.20985 (4) obj. -1.2266e+08 iterations 448
# Cbc0038I Pass  11: (8.88 seconds) suminf.    6.73891 (113) obj. -1.2266e+08 iterations 1619
# Cbc0038I Pass  12: (8.96 seconds) suminf.    2.27616 (104) obj. -1.2266e+08 iterations 347
# Cbc0038I Pass  13: (9.01 seconds) suminf.    2.27616 (104) obj. -1.2266e+08 iterations 1
# Cbc0038I Pass  14: (9.22 seconds) suminf.    3.92154 (15) obj. -1.2266e+08 iterations 963
# Cbc0038I Pass  15: (9.35 seconds) suminf.    2.53316 (13) obj. -1.2266e+08 iterations 476
# Cbc0038I Pass  16: (9.51 seconds) suminf.    5.62632 (72) obj. -1.2266e+08 iterations 841
# Cbc0038I Pass  17: (9.58 seconds) suminf.    3.36141 (105) obj. -1.2266e+08 iterations 302
# Cbc0038I Pass  18: (9.62 seconds) suminf.    3.36141 (105) obj. -1.2266e+08 iterations 2
# Cbc0038I Pass  19: (9.77 seconds) suminf.    3.90466 (15) obj. -1.2266e+08 iterations 652
# Cbc0038I Pass  20: (9.90 seconds) suminf.    2.64054 (13) obj. -1.2266e+08 iterations 565
# Cbc0038I Pass  21: (10.03 seconds) suminf.    2.36290 (104) obj. -1.2266e+08 iterations 574
# Cbc0038I Pass  22: (10.11 seconds) suminf.    3.29593 (105) obj. -1.2266e+08 iterations 260
# Cbc0038I Pass  23: (10.20 seconds) suminf.    3.29593 (105) obj. -1.2266e+08 iterations 280
# Cbc0038I Pass  24: (10.36 seconds) suminf.    3.91016 (15) obj. -1.2266e+08 iterations 702
# Cbc0038I Pass  25: (10.51 seconds) suminf.    2.60556 (13) obj. -1.2266e+08 iterations 555
# Cbc0038I Pass  26: (10.65 seconds) suminf.    2.33464 (104) obj. -1.2266e+08 iterations 559
# Cbc0038I Pass  27: (10.73 seconds) suminf.    3.54954 (117) obj. -1.2266e+08 iterations 255
# Cbc0038I Pass  28: (10.81 seconds) suminf.    3.54940 (105) obj. -1.2266e+08 iterations 246
# Cbc0038I Pass  29: (11.05 seconds) suminf.    3.83446 (15) obj. -1.2266e+08 iterations 1053
# Cbc0038I Pass  30: (11.34 seconds) suminf.    2.55091 (104) obj. -1.2266e+08 iterations 1186
# Cbc0038I Pass  31: (11.55 seconds) suminf.    3.83446 (15) obj. -1.2266e+08 iterations 974
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7019 integers at bound fixed and 5774 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1561 rows 658 columns
# Cbc0038I Mini branch and bound did not improve solution (11.68 seconds)
# Cbc0038I After 11.69 seconds - Feasibility pump exiting with objective of -1.22648e+08 - took 6.58 seconds
# Cbc0012I Integer solution of -1.2264753e+08 found by feasibility pump after 0 iterations and 0 nodes (11.89 seconds)
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1135 rows 528 columns
# Cbc0031I 165 added rows had average density of 8.4060606
# Cbc0013I At root node, 167 cuts changed objective from -1.2276915e+08 to -1.2264753e+08 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 178 row cuts average 2.0 elements, 4350 column cuts (4350 active)  in 0.125 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 83 row cuts average 17.1 elements, 0 column cuts (0 active)  in 0.067 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 78 row cuts average 11.5 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 120 row cuts average 19.7 elements, 0 column cuts (0 active)  in 0.114 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -122647529.0688817, took 435 iterations and 0 nodes (15.26 seconds)
# Cbc0035I Maximum depth 0, 1481 variables fixed on reduced cost
# Cuts at root node changed objective from -1.22769e+08 to -1.22648e+08
# Probing was tried 2 times and created 4528 cuts of which 0 were active after adding rounds of cuts (0.125 seconds)
# Gomory was tried 2 times and created 83 cuts of which 0 were active after adding rounds of cuts (0.067 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 2 times and created 78 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
# TwoMirCuts was tried 2 times and created 120 cuts of which 0 were active after adding rounds of cuts (0.114 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
#
# Result - Optimal solution found
#
# Objective value:                122647529.06888175
# Enumerated nodes:               0
# Total iterations:               435
# Time (CPU seconds):             18.18
# Time (Wallclock seconds):       18.55
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       18.46   (Wallclock seconds):       18.88
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cb9c96d9556f493d85d7e82baa572356-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/cb9c96d9556f493d85d7e82baa572356-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.30518e+08 - 0.46 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 15360 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23151 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25064 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20378 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24955 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24143 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20641 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19441 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21580 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115099 rows, 13485 columns (7383 integer (7383 of which binary)) and 434199 elements
# Cbc0038I Initial state - 354 integers unsatisfied sum - 34.7596
# Cbc0038I Pass   1: (4.89 seconds) suminf.    0.00000 (0) obj. -1.22197e+08 iterations 2495
# Cbc0038I Solution found of -1.22197e+08
# Cbc0038I Relaxing continuous gives -1.22197e+08
# Cbc0038I Before mini branch and bound, 7029 integers at bound fixed and 5830 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1341 rows 600 columns
# Cbc0038I Mini branch and bound did not improve solution (5.19 seconds)
# Cbc0038I Round again with cutoff of -1.2221e+08
# Cbc0038I Reduced cost fixing fixed 135 variables on major pass 2
# Cbc0038I Pass   2: (6.59 seconds) suminf.    0.16338 (2) obj. -1.2221e+08 iterations 1882
# Cbc0038I Pass   3: (6.71 seconds) suminf.    0.72461 (2) obj. -1.2221e+08 iterations 500
# Cbc0038I Pass   4: (7.01 seconds) suminf.    2.32738 (65) obj. -1.2221e+08 iterations 2115
# Cbc0038I Pass   5: (7.09 seconds) suminf.    1.32228 (61) obj. -1.2221e+08 iterations 398
# Cbc0038I Pass   6: (7.33 seconds) suminf.    1.22564 (4) obj. -1.2221e+08 iterations 1251
# Cbc0038I Pass   7: (7.41 seconds) suminf.    1.11015 (4) obj. -1.2221e+08 iterations 272
# Cbc0038I Pass   8: (7.66 seconds) suminf.    3.62506 (83) obj. -1.2221e+08 iterations 1415
# Cbc0038I Pass   9: (7.75 seconds) suminf.    2.16783 (77) obj. -1.2221e+08 iterations 294
# Cbc0038I Pass  10: (7.79 seconds) suminf.    2.16783 (77) obj. -1.2221e+08 iterations 6
# Cbc0038I Pass  11: (8.06 seconds) suminf.    4.31594 (43) obj. -1.2221e+08 iterations 1464
# Cbc0038I Pass  12: (8.24 seconds) suminf.    2.39900 (13) obj. -1.2221e+08 iterations 861
# Cbc0038I Pass  13: (8.42 seconds) suminf.    4.71585 (117) obj. -1.2221e+08 iterations 967
# Cbc0038I Pass  14: (8.51 seconds) suminf.    2.71161 (77) obj. -1.2221e+08 iterations 488
# Cbc0038I Pass  15: (8.80 seconds) suminf.    4.00142 (43) obj. -1.2221e+08 iterations 1434
# Cbc0038I Pass  16: (8.98 seconds) suminf.    3.07225 (13) obj. -1.2221e+08 iterations 928
# Cbc0038I Pass  17: (9.16 seconds) suminf.    6.76364 (115) obj. -1.2221e+08 iterations 898
# Cbc0038I Pass  18: (9.21 seconds) suminf.    5.27481 (87) obj. -1.2221e+08 iterations 236
# Cbc0038I Pass  19: (9.23 seconds) suminf.    5.27481 (87) obj. -1.2221e+08 iterations 0
# Cbc0038I Pass  20: (9.36 seconds) suminf.    6.55482 (84) obj. -1.2221e+08 iterations 412
# Cbc0038I Pass  21: (9.40 seconds) suminf.    4.96318 (86) obj. -1.2221e+08 iterations 33
# Cbc0038I Pass  22: (9.47 seconds) suminf.    4.38637 (86) obj. -1.2221e+08 iterations 71
# Cbc0038I Pass  23: (9.54 seconds) suminf.    3.97182 (78) obj. -1.2221e+08 iterations 61
# Cbc0038I Pass  24: (9.59 seconds) suminf.    3.47357 (86) obj. -1.2221e+08 iterations 50
# Cbc0038I Pass  25: (9.64 seconds) suminf.    3.97182 (78) obj. -1.2221e+08 iterations 51
# Cbc0038I Pass  26: (9.74 seconds) suminf.    6.22418 (111) obj. -1.2221e+08 iterations 316
# Cbc0038I Pass  27: (9.81 seconds) suminf.    5.44542 (87) obj. -1.2221e+08 iterations 250
# Cbc0038I Pass  28: (9.87 seconds) suminf.    4.73718 (86) obj. -1.2221e+08 iterations 125
# Cbc0038I Pass  29: (9.92 seconds) suminf.    3.35170 (78) obj. -1.2221e+08 iterations 39
# Cbc0038I Pass  30: (10.01 seconds) suminf.    2.99071 (77) obj. -1.2221e+08 iterations 343
# Cbc0038I Pass  31: (10.25 seconds) suminf.    3.77634 (43) obj. -1.2221e+08 iterations 1412
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6968 integers at bound fixed and 5749 continuous
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 2007 rows 741 columns
# Cbc0038I Mini branch and bound did not improve solution (10.43 seconds)
# Cbc0038I After 10.44 seconds - Feasibility pump exiting with objective of -1.22197e+08 - took 5.70 seconds
# Cbc0012I Integer solution of -1.2219723e+08 found by feasibility pump after 0 iterations and 0 nodes (10.61 seconds)
# Cbc0038I Full problem 115099 rows 13485 columns, reduced to 1341 rows 600 columns
# Cbc0031I 171 added rows had average density of 7.8245614
# Cbc0013I At root node, 183 cuts changed objective from -1.2232626e+08 to -1.2219723e+08 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 180 row cuts average 2.0 elements, 4450 column cuts (4450 active)  in 0.120 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 74 row cuts average 16.0 elements, 0 column cuts (0 active)  in 0.072 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.031 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 85 row cuts average 11.4 elements, 0 column cuts (0 active)  in 0.039 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 110 row cuts average 19.3 elements, 0 column cuts (0 active)  in 0.111 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -122197231.3910365, took 662 iterations and 0 nodes (13.07 seconds)
# Cbc0035I Maximum depth 0, 1504 variables fixed on reduced cost
# Cuts at root node changed objective from -1.22326e+08 to -1.22197e+08
# Probing was tried 2 times and created 4630 cuts of which 0 were active after adding rounds of cuts (0.120 seconds)
# Gomory was tried 2 times and created 74 cuts of which 0 were active after adding rounds of cuts (0.072 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.031 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 2 times and created 85 cuts of which 0 were active after adding rounds of cuts (0.039 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# TwoMirCuts was tried 2 times and created 110 cuts of which 0 were active after adding rounds of cuts (0.111 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
#
# Result - Optimal solution found
#
# Objective value:                122197231.39103650
# Enumerated nodes:               0
# Total iterations:               662
# Time (CPU seconds):             15.94
# Time (Wallclock seconds):       16.27
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       16.22   (Wallclock seconds):       16.57

# %%
# 修正后的代码
df = pd.concat(dfs)

# 计算平均值时需要指定哪些列进行聚合
df = df.groupby(["Field", "Crop", "Season", "Year"]).agg("mean").reset_index()
df = df[~((df["Season"] == 2) & (df["Field"] < 27))]  # 去掉单季地块第二季度的数据

# 获取不包括 2023 年的唯一年份
years = df["Year"].unique()
years = [year for year in years if year != 2023]


# 创建一个 Excel writer 对象
with pd.ExcelWriter(f"exp-{times}.xlsx") as writer:
    for year in years:
        # 过滤特定年份的数据
        df_year = df[df["Year"] == year]

        # 透视表，Field 作为行，Crop 作为列
        pivot_table = df_year.pivot_table(
            index=["Season", "Field"], columns="Crop", values="Planting", aggfunc="sum"
        ).round(
            1
        )  # 保留一位小数

        # 将透视表写入 Excel 的 sheet
        pivot_table.to_excel(writer, sheet_name=str(year))

print(f"Exported to exp-{times}.xlsx")
# Out:
# Exported to test-1.xlsx
