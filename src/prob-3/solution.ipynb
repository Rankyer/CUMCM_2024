# %%
import pandas as pd
import numpy as np
import datetime
from planning import planning

stats_2023 = pd.read_csv("../../data/preprocess/pre-processed.csv")
stats_2023.dtypes
# Out:
# Field ID           int64
# Field Name        object
# Crop ID            int64
# Crop Name         object
# Crop Type         object
# Planting Area    float64
# Season ID          int64
# Season            object
# Field Type        object
# Field Area       float64
# Per Yield        float64
# Per Cost         float64
# Per Price        float64
# Yield            float64
# Cost             float64
# Selling          float64
# Revenue          float64
# Profit           float64
# dtype: object

# %%
fields_id = list(map(int, stats_2023["Field ID"].unique()))  # 所有的地块
crops_id = list(map(int, stats_2023["Crop ID"].unique()))  # 所有的作物
seasons_id = list(map(int, stats_2023["Season ID"].unique()))  # 所有的时节
fields_id.sort()
crops_id.sort()
seasons_id.sort()
years = range(2023, 2031)  # 要优化的年份


def pop_ndarray(arr, element_to_pop):
    index = np.where(arr == element_to_pop)[0]
    if index.size > 0:
        arr = np.delete(arr, index)
    return arr


# A类粮食作物的集合
grains_A = stats_2023[
    (stats_2023["Crop Type"] == "粮食") | (stats_2023["Crop Type"] == "粮食（豆类）")
]["Crop ID"].unique()
grains_A = pop_ndarray(grains_A, 16)
grains_A.sort()

# B类粮食作物的集合
grains_B = np.array([16])

# A类蔬菜作物的集合
vege_A = stats_2023[
    (stats_2023["Crop Type"] == "蔬菜") | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
for i in range(3):
    vege_A = pop_ndarray(vege_A, 35 + i)
vege_A.sort()

# B类蔬菜作物的集合
vege_B = np.array([35, 36, 37])

# 食用菌作物的集合
mush = stats_2023[stats_2023["Crop Type"] == "食用菌"]["Crop ID"].unique()
mush.sort()

# 豆类作物的集合
beans = stats_2023[
    (stats_2023["Crop Type"] == "粮食（豆类）")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
beans.sort()

# 第 i 个地块的类型（如平旱地、梯田、山坡地、智能大棚、普通大棚、水浇地）
t_i = {
    i: stats_2023[stats_2023["Field ID"] == i]["Field Type"].values[0]
    for i in fields_id
}

# 第 i 个地块在第 s 季可种植的作物集合
T_hat_i_s: dict[tuple : np.ndarray] = {}


for i in fields_id:
    if t_i[i] in ["平旱地", "梯田", "山坡地"]:
        T_hat_i_s[i, 1] = grains_A
        T_hat_i_s[i, 2] = np.array([])
    elif t_i[i] in ["水浇地"]:
        T_hat_i_s[i, 1] = np.concatenate([grains_B, vege_A])
        T_hat_i_s[i, 2] = vege_B
    elif t_i[i] in ["普通大棚"]:
        T_hat_i_s[i, 1] = vege_A
        T_hat_i_s[i, 2] = mush
    elif t_i[i] in ["智慧大棚"]:
        T_hat_i_s[i, 1] = vege_A
        T_hat_i_s[i, 2] = vege_A

# 市场互替性系数
R_ij = {}  # 作物 i 对作物 j 在市场上的互替性系数

# 将所有作物对初始化为 0
for i in crops_id:
    for j in crops_id:
        if i != j:
            R_ij[i, j] = 0


# 对于同类型的作物，其市场价格接近，互替性系数越高
# 定义一个函数来计算互替性系数
def calculate_substitutability(price_i, price_j):
    # 计算价格差距的百分比
    price_diff_percentage = abs(price_i - price_j) / ((price_i + price_j) / 2)
    # 使用一个简单的公式来量化互替性系数
    # 这里假设价格差距越小，互替性越高
    substitutability = max(0, 1 - price_diff_percentage)
    return substitutability


# 计算同类型作物之间的互替性系数
def calculate_R_ij_for_type(crop_ids):
    for i in crop_ids:
        for j in crop_ids:
            if i != j:
                price_i = stats_2023[stats_2023["Crop ID"] == i]["Per Price"].values[0]
                price_j = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
                if price_i is not None and price_j is not None:
                    R_ij[i, j] = calculate_substitutability(price_i, price_j)


# 假设 grains_A 是同类型作物的集合
calculate_R_ij_for_type(grains_A)
calculate_R_ij_for_type(grains_B)
calculate_R_ij_for_type(vege_A)
calculate_R_ij_for_type(vege_B)
calculate_R_ij_for_type(mush)
calculate_R_ij_for_type(beans)

print(R_ij)
# Out:
# {(1, 2): np.float64(0.2093023255813954), (1, 3): np.float64(0.13043478260869568), (1, 4): np.float64(0.2682926829268293), (1, 5): np.float64(0.30000000000000004), (1, 6): np.float64(0.9259259259259259), (1, 7): np.float64(0.92), (1, 8): np.float64(0.30000000000000004), (1, 9): np.float64(0.4054054054054054), (1, 10): np.float64(0.2093023255813954), (1, 11): 0, (1, 12): np.float64(0.26315789473684215), (1, 13): np.float64(1.0), (1, 14): np.float64(0.48571428571428577), (1, 15): np.float64(0.9259259259259259), (1, 16): 0, (1, 17): np.float64(0.15555555555555556), (1, 18): np.float64(0.30000000000000004), (1, 19): np.float64(0.33333333333333337), (1, 20): 0, (1, 21): 0, (1, 22): 0, (1, 23): 0, (1, 24): 0, (1, 25): 0, (1, 26): 0, (1, 27): 0, (1, 28): 0, (1, 29): 0, (1, 30): 0, (1, 31): 0, (1, 32): 0, (1, 33): 0, (1, 34): 0, (1, 35): 0, (1, 36): 0, (1, 37): 0, (1, 38): 0, (1, 39): 0, (1, 40): 0, (1, 41): 0, (2, 1): np.float64(0.2093023255813954), (2, 3): np.float64(0.9047619047619048), (2, 4): np.float64(0.9310344827586207), (2, 5): np.float64(0.8947368421052632), (2, 6): np.float64(0.2727272727272727), (2, 7): np.float64(0.1428571428571429), (2, 8): np.float64(0.8947368421052632), (2, 9): np.float64(0.7777777777777778), (2, 10): np.float64(1.0), (2, 11): 0, (2, 12): 0, (2, 13): np.float64(0.2093023255813954), (2, 14): np.float64(0.6923076923076923), (2, 15): np.float64(0.2727272727272727), (2, 16): 0, (2, 17): np.float64(0.935483870967742), (2, 18): np.float64(0.8947368421052632), (2, 19): np.float64(0.8571428571428572), (2, 20): 0, (2, 21): 0, (2, 22): 0, (2, 23): 0, (2, 24): 0, (2, 25): 0, (2, 26): 0, (2, 27): 0, (2, 28): 0, (2, 29): 0, (2, 30): 0, (2, 31): 0, (2, 32): 0, (2, 33): 0, (2, 34): 0, (2, 35): 0, (2, 36): 0, (2, 37): 0, (2, 38): 0, (2, 39): 0, (2, 40): 0, (2, 41): 0, (3, 1): np.float64(0.13043478260869568), (3, 2): np.float64(0.9047619047619048), (3, 4): np.float64(0.8360655737704918), (3, 5): np.float64(0.8), (3, 6): np.float64(0.19148936170212771), (3, 7): np.float64(0.06666666666666665), (3, 8): np.float64(0.8), (3, 9): np.float64(0.6842105263157895), (3, 10): np.float64(0.9047619047619048), (3, 11): 0, (3, 12): 0, (3, 13): np.float64(0.13043478260869568), (3, 14): np.float64(0.6), (3, 15): np.float64(0.19148936170212771), (3, 16): 0, (3, 17): np.float64(0.9692307692307692), (3, 18): np.float64(0.8), (3, 19): np.float64(0.7627118644067796), (3, 20): 0, (3, 21): 0, (3, 22): 0, (3, 23): 0, (3, 24): 0, (3, 25): 0, (3, 26): 0, (3, 27): 0, (3, 28): 0, (3, 29): 0, (3, 30): 0, (3, 31): 0, (3, 32): 0, (3, 33): 0, (3, 34): 0, (3, 35): 0, (3, 36): 0, (3, 37): 0, (3, 38): 0, (3, 39): 0, (3, 40): 0, (3, 41): 0, (4, 1): np.float64(0.2682926829268293), (4, 2): np.float64(0.9310344827586207), (4, 3): np.float64(0.8360655737704918), (4, 5): np.float64(0.9636363636363636), (4, 6): np.float64(0.33333333333333337), (4, 7): np.float64(0.19999999999999996), (4, 8): np.float64(0.9636363636363636), (4, 9): np.float64(0.8461538461538461), (4, 10): np.float64(0.9310344827586207), (4, 11): 0, (4, 12): 0, (4, 13): np.float64(0.2682926829268293), (4, 14): np.float64(0.76), (4, 15): np.float64(0.33333333333333337), (4, 16): 0, (4, 17): np.float64(0.8666666666666667), (4, 18): np.float64(0.9636363636363636), (4, 19): np.float64(0.9259259259259259), (4, 20): 0, (4, 21): 0, (4, 22): 0, (4, 23): 0, (4, 24): 0, (4, 25): 0, (4, 26): 0, (4, 27): 0, (4, 28): 0, (4, 29): 0, (4, 30): 0, (4, 31): 0, (4, 32): 0, (4, 33): 0, (4, 34): 0, (4, 35): 0, (4, 36): 0, (4, 37): 0, (4, 38): 0, (4, 39): 0, (4, 40): 0, (4, 41): 0, (5, 1): np.float64(0.30000000000000004), (5, 2): np.float64(0.8947368421052632), (5, 3): np.float64(0.8), (5, 4): np.float64(0.9636363636363636), (5, 6): np.float64(0.36585365853658536), (5, 7): np.float64(0.23076923076923073), (5, 8): np.float64(1.0), (5, 9): np.float64(0.8823529411764706), (5, 10): np.float64(0.8947368421052632), (5, 11): 0, (5, 12): 0, (5, 13): np.float64(0.30000000000000004), (5, 14): np.float64(0.7959183673469388), (5,  ...

# %%
dfs = []
times = 30  # 重复次数


def expected_selling(percost, price):
    return 8122.041 + 1.385 * percost - 1.2894625 * price


for i in range(times):
    # 使用当前时间作为随机数种子
    np.random.seed(datetime.datetime.now().second)

    S = {}  # 期望产量
    Y = {}  # 单位面积产量
    P = {}  # 售价
    C = {}  # 单位面积成本

    for j in crops_id:
        Y[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Yield"].values[0]
        P[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
        C[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Cost"].values[0]
        S[j, 2023] = expected_selling(C[j, 2023], P[j, 2023])

    for j in crops_id:
        # 小麦和玉米的预期销售量有平均5%-10%的年增长
        for k in years:

            # 农作物亩产量可能有±10%的变化.
            increment = np.random.uniform(-0.1, 0.1)
            Y[j, k + 1] = Y[j, k] * np.random.normal(1 + increment, 0.01)

            # 种植成本每年增长约5%。
            increment = 0.05
            C[j, k + 1] = C[j, k] * np.random.normal(1 + increment, 0.01)

            # 蔬菜类作物价格每年增长约5%。
            if j in vege_A or j in vege_B:
                increment = 0.05
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 食用菌价格每年下降1%-5%。
            if j in mush:
                increment = np.random.uniform(-0.05, -0.01)
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 羊肚菌的销售价格每年下降幅5%
            if j == 41:
                increment = -0.05
                P[j, k + 1] = P[j, k] * (1 + increment)
            else:
                P[j, k + 1] = P[j, k]

            S[j, k + 1] = expected_selling(C[j, k + 1], P[j, k + 1])

            if j in [6, 7]:
                increment = np.random.uniform(0.05, 0.1)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 其他作物的预期销售量变化约±5%。
            else:
                increment = np.random.uniform(-0.05, 0.05)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

    dfs.append(
        planning(
            fields_id,
            crops_id,
            seasons_id,
            years,
            t_i,
            T_hat_i_s,
            R_ij,
            grains_A,
            grains_B,
            vege_A,
            vege_B,
            mush,
            beans,
            stats_2023,
            [
                S,
                Y,
                P,
                C,
            ],
        )
    )
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/efb5abc83356480c9516cba69f5657e5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/efb5abc83356480c9516cba69f5657e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224047 COLUMNS
# At line 766896 RHS
# At line 990939 BOUNDS
# At line 1030792 ENDATA
# Problem MODEL has 224042 rows, 88560 columns and 436576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.24474e+08 - 0.52 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 17047 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26670 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24937 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26006 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24840 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23409 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21143 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22514 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25496 strengthened rows, 0 substitutions
# Cgl0004I processed model has 115092 rows, 13485 columns (7383 integer (7383 of which binary)) and 451527 elements
# Cbc0038I Initial state - 701 integers unsatisfied sum - 218.113
# Cbc0038I Pass   1: (5.22 seconds) suminf.    6.30000 (21) obj. -1.06633e+08 iterations 3074
# Cbc0038I Pass   2: (5.26 seconds) suminf.    5.10000 (17) obj. -1.06617e+08 iterations 43
# Cbc0038I Pass   3: (5.30 seconds) suminf.    0.60000 (2) obj. -1.07594e+08 iterations 68
# Cbc0038I Pass   4: (5.34 seconds) suminf.    0.60000 (2) obj. -1.07579e+08 iterations 8
# Cbc0038I Pass   5: (5.39 seconds) suminf.   24.13333 (76) obj. -9.57433e+07 iterations 1007
# Cbc0038I Pass   6: (5.43 seconds) suminf.   19.00000 (64) obj. -9.55025e+07 iterations 125
# Cbc0038I Pass   7: (5.48 seconds) suminf.   17.00000 (56) obj. -9.61587e+07 iterations 124
# Cbc0038I Pass   8: (5.52 seconds) suminf.   16.80000 (56) obj. -9.61629e+07 iterations 3
# Cbc0038I Pass   9: (5.56 seconds) suminf.   15.00000 (49) obj. -9.56315e+07 iterations 101
# Cbc0038I Pass  10: (5.61 seconds) suminf.   14.70000 (49) obj. -9.56357e+07 iterations 9
# Cbc0038I Pass  11: (5.65 seconds) suminf.   15.00000 (49) obj. -9.57777e+07 iterations 56
# Cbc0038I Pass  12: (5.69 seconds) suminf.   14.70000 (49) obj. -9.57854e+07 iterations 17
# Cbc0038I Pass  13: (5.73 seconds) suminf.   14.90000 (48) obj. -9.57436e+07 iterations 115
# Cbc0038I Pass  14: (5.77 seconds) suminf.   14.40000 (48) obj. -9.57522e+07 iterations 19
# Cbc0038I Pass  15: (5.81 seconds) suminf.   14.90000 (48) obj. -9.57757e+07 iterations 73
# Cbc0038I Pass  16: (5.85 seconds) suminf.   14.40000 (48) obj. -9.57843e+07 iterations 14
# Cbc0038I Pass  17: (5.89 seconds) suminf.   14.70000 (48) obj. -9.57376e+07 iterations 12
# Cbc0038I Pass  18: (5.92 seconds) suminf.   14.40000 (48) obj. -9.57455e+07 iterations 8
# Cbc0038I Pass  19: (5.96 seconds) suminf.   14.40000 (47) obj. -9.56919e+07 iterations 140
# Cbc0038I Pass  20: (6.00 seconds) suminf.   14.10000 (47) obj. -9.56998e+07 iterations 10
# Cbc0038I Pass  21: (6.04 seconds) suminf.   14.40000 (47) obj. -9.62474e+07 iterations 76
# Cbc0038I Pass  22: (6.08 seconds) suminf.   14.10000 (47) obj. -9.62553e+07 iterations 15
# Cbc0038I Pass  23: (6.12 seconds) suminf.   14.70000 (47) obj. -9.53645e+07 iterations 133
# Cbc0038I Pass  24: (6.16 seconds) suminf.   14.10000 (47) obj. -9.53652e+07 iterations 42
# Cbc0038I Pass  25: (6.20 seconds) suminf.   14.90000 (47) obj. -9.61798e+07 iterations 157
# Cbc0038I Pass  26: (6.23 seconds) suminf.   14.10000 (47) obj. -9.61847e+07 iterations 58
# Cbc0038I Pass  27: (6.27 seconds) suminf.   14.60000 (47) obj. -9.52874e+07 iterations 92
# Cbc0038I Pass  28: (6.31 seconds) suminf.   14.10000 (47) obj. -9.53088e+07 iterations 12
# Cbc0038I Pass  29: (6.35 seconds) suminf.   14.40000 (47) obj. -9.61685e+07 iterations 89
# Cbc0038I Pass  30: (6.42 seconds) suminf.   34.20702 (109) obj. -8.68213e+07 iterations 1015
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6254 integers at bound fixed and 5215 continuous
# Cbc0038I Full problem 115092 rows 13485 columns, reduced to 7838 rows 1927 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1.16352e+08 (8.05 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -1.16352e+08
# Cbc0038I Round again with cutoff of -1.1648e+08
# Cbc0038I Pass  30: (10.10 seconds) suminf.   11.70548 (39) obj. -1.1648e+08 iterations 3168
# Cbc0038I Pass  31: (10.20 seconds) suminf.    3.07639 (10) obj. -1.1648e+08 iterations 395
# Cbc0038I Pass  32: (10.27 seconds) suminf.    0.66991 (3) obj. -1.1648e+08 iterations 260
# Cbc0038I Pass  33: (10.32 seconds) suminf.    0.66991 (3) obj. -1.1648e+08 iterations 1
# Cbc0038I Pass  34: (10.39 seconds) suminf.    0.74271 (3) obj. -1.1648e+08 iterations 229
# Cbc0038I Pass  35: (10.63 seconds) suminf.    0.00000 (0) obj. -1.1648e+08 iterations 1122
# Cbc0038I Solution found of -1.1648e+08
# Cbc0038I Relaxing continuous gives -1.16494e+08
# Cbc0038I Rounding solution of -1.16521e+08 is better than previous of -1.16494e+08
#
# Cbc0038I Before mini branch and bound, 6673 integers at bound fixed and 5548 continuous
# Cbc0038I Full problem 115092 rows 13485 columns, reduced to 2360 rows 1132 columns
# Cbc0038I Mini branch and bound improved solution from -1.16521e+08 to -1.16539e+08 (11.46 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -1.16539e+08
# Cbc0038I Round again with cutoff of -1.16758e+08
# Cbc0038I Pass  36: (11.83 seconds) suminf.   25.01592 (82) obj. -1.16758e+08 iterations 316
# Cbc0038I Pass  37: (11.91 seconds) suminf.    2.74906 (28) obj. -1.16758e+08 iterations 219
# Cbc0038I Pass  38: (12.14 seconds) suminf.    0.43692 (4) obj. -1.16758e+08 iterations 1465
# Cbc0038I Pass  39: (12.37 seconds) suminf.    0.00000 (0) obj. -1.16758e+08 iterations 1092
# Cbc0038I Solution found of -1.16758e+08
# Cbc0038I Relaxing continuous gives -1.16759e+08
# Cbc0038I Before mini branch and bound, 6666 integers at bound fixed and 5539 continuous
# Cbc0038I Full problem 115092 rows 13485 columns, reduced to 2437 rows 1147 columns
# Cbc0038I Mini branch and bound improved solution from -1.16759e+08 to -1.16785e+08 (13.14 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -1.16785e+08
# Cbc0038I Round again with cutoff of -1.1704e+08
# Cbc0038I Pass  40: (13.44 seconds) suminf.   40.83430 (125) obj. -1.1704e+08 iterations 231
# Cbc0038I Pass  41: (13.57 seconds) suminf.   25.74379 (111) obj. -1.1704e+08 iterations 599
# Cbc0038I Pass  42: (13.62 seconds) suminf.   21.26239 (99) obj. -1.1704e+08 iterations 22
# Cbc0038I Pass  43: (13.66 seconds) suminf.   18.01960 (97) obj. -1.1704e+08 iterations 9
# Cbc0038I Pass  44: (13.73 seconds) suminf.   17.43036 (86) obj. -1.1704e+08 iterations 88
# Cbc0038I Pass  45: (13.79 seconds) suminf.   16.60635 (56) obj. -1.1704e+08 iterations 166
# Cbc0038I Pass  46: (13.81 seconds) suminf.   16.60635 (56) obj. -1.1704e+08 iterations 0
# Cbc0038I Pass  47: (13.86 seconds) suminf.   17.34954 (75) obj. -1.1704e+08 iterations 40
# Cbc0038I Pass  48: (13.91 seconds) suminf.   16.60635 (56) obj. -1.1704e+08 iterations 65
# Cbc0038I Pass  49: (14.04 seconds) suminf.   29.33513 (126) obj. -1.1704e+08 iterations 597
# Cbc0038I Pass  50: (14.12 seconds) suminf.   25.20277 (108) obj. -1.1704e+08 iterations 290
# Cbc0038I Pass  51: (14.16 seconds) suminf.   25.20277 (108) obj. -1.1704e+08 iterations 2
# Cbc0038I Pass  52: (14.22 seconds) suminf.   25.22555 (98) obj. -1.1704e+08 iterations 92
# Cbc0038I Pass  53: (14.27 seconds) suminf.   25.19747 (108) obj. -1.1704e+08 iterations 98
# Cbc0038I Pass  54: (14.29 seconds) suminf.   25.19747 (108) obj. -1.1704e+08 iterations 0
# Cbc0038I Pass  55: (14.33 seconds) suminf.   23.86857 (109) obj. -1.1704e+08 iterations 2
# Cbc0038I Pass  56: (14.38 seconds) suminf.   20.87543 (99) obj. -1.1704e+08 iterations 11
# Cbc0038I Pass  57: (14.44 seconds) suminf.   16.81984 (94) obj. -1.1704e+08 iterations 63
# Cbc0038I Pass  58: (14.46 seconds) suminf.   16.81984 (94) obj. -1.1704e+08 iterations 0
# Cbc0038I Pass  59: (14.50 seconds) suminf.   16.81984 (94) obj. -1.1704e+08 iterations 3
# Cbc0038I Pass  60: (14.54 seconds) suminf.   16.81984 (94) obj. -1.1704e+08 iterations 6
# Cbc0038I Pass  61: (14.58 seconds) suminf.   16.81984 (94) obj. -1.1704e+08 iterations 1
# Cbc0038I Pass  62: (14.70 seconds) suminf.   30.30244 (128) obj. -1.1704e+08 iterations 384
# Cbc0038I Pass  63: (14.79 seconds) suminf.   23.03601 (100) obj. -1.1704e+08 iterations 516
# Cbc0038I Pass  64: (14.86 seconds) suminf.   20.68996 (98) obj. -1.1704e+08 iterations 104
# Cbc0038I Pass  65: (14.95 seconds) suminf.   20.00810 (53) obj. -1.1704e+08 iterations 307
# Cbc0038I Pass  66: (15.02 seconds) suminf.   19.82531 (95) obj. -1.1704e+08 iterations 188
# Cbc0038I Pass  67: (15.04 seconds) suminf.   19.82531 (95) obj. -1.1704e+08 iterations 0
# Cbc0038I Pass  68: (15.09 seconds) suminf.   20.42901 (94) obj. -1.1704e+08 iterations 68
# Cbc0038I Pass  69: (15.18 seconds) suminf.   19.49078 (86) obj. -1.1704e+08 iterations 252
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6616 integers at bound fixed and 5496 continuous
# Cbc0038I Full problem 115092 rows 13485 columns, reduced to 2957 rows 1254 columns
# Cbc0038I Mini branch and bound improved solution from -1.16785e+08 to -1.16818e+08 (16.15 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -1.16818e+08
# Cbc0038I Round again with cutoff of -1.17218e+08
# Cbc0038I Reduced cost fixing fixed 5 variables on major pass 5
# Cbc0038I Pass  69: (16.63 seconds) suminf.   69.62616 (196) obj. -1.17218e+08 iterations 419
# Cbc0038I Pass  70: (16.75 seconds) suminf.   43.06853 (152) obj. -1.17218e+08 iterations 307
# Cbc0038I Pass  71: (16.80 seconds) suminf.   40.60096 (144) obj. -1.17218e+08 iterations 123
# Cbc0038I Pass  72: (16.84 seconds) suminf.   36.76940 (132) obj. -1.17218e+08 iterations 5
# Cbc0038I Pass  73: (16.89 seconds) suminf.   34.50441 (130) obj. -1.17218e+08 iterations 9
# Cbc0038I Pass  74: (16.95 seconds) suminf.   31.89595 (129) obj. -1.17218e+08 iterations 83
# Cbc0038I Pass  75: (17.00 seconds) suminf.   31.89595 (129) obj. -1.17218e+08 iterations 6
# Cbc0038I Pass  76: (17.04 seconds) suminf.   31.89595 (129) obj. -1.17218e+08 iterations 2
# Cbc0038I Pass  77: (17.06 seconds) suminf.   31.89595 (129) obj. -1.17218e+08 iterations 0
# Cbc0038I Pass  78: (17.11 seconds) suminf.   30.89595 (127) obj. -1.17218e+08 iterations 8
# Cbc0038I Pass  79: (17.15 seconds) suminf.   28.49275 (120) obj. -1.17218e+08 iterations 3
# Cbc0038I Pass  80: (17.20 seconds) suminf.   26.57370 (117) obj. -1.17218e+08 iterations 3
# Cbc0038I Pass  81: (17.24 seconds) suminf.   26.57370 (117) obj. -1.17218e+08 iterations 1
# Cbc0038I Pass  82: (17.28 seconds) suminf.   26.42370 (117) obj. -1.17218e+08 iterations 3
# Cbc0038I Pass  83: (17.32 seconds) suminf.   26.42370 (117) obj. -1.17218e+08 iterations 1
# Cbc0038I Pass  84: (17.34 seconds) suminf.   26.42370 (117) obj. -1.17218e+08 iterations 0
# Cbc0038I Pass  85: (17.39 seconds) suminf.   25.40651 (117) obj. -1.17218e+08 iterations 8
# Cbc0038I Pass  86: (17.43 seconds) suminf.   24.94497 (117) obj. -1.17218e+08 iterations 7
# Cbc0038I Pass  87: (17.45 seconds) suminf.   24.94497 (117) obj. -1.17218e+08 iterations 0
# Cbc0038I Pass  88: (17.49 seconds) suminf.   24.94497 (117) obj. -1.17218e+08 iterations 3
# Cbc0038I Pass  89: (17.53 seconds) suminf.   24.94497 (117) obj. -1.17218e+08 iterations 1
# Cbc0038I Pass  90: (17.57 seconds) suminf.   25.68827 (114) obj. -1.17218e+08 iterations 10
# Cbc0038I Pass  91: (17.61 seconds) suminf.   24.70967 (117) obj. -1.17218e+08 iterations 5
# Cbc0038I Pass  92: (17.65 seconds) suminf.   24.70967 (117) obj. -1.17218e+08 iterations 1
# Cbc0038I Pass  93: (17.69 seconds) suminf.   24.47438 (117) obj. -1.17218e+08 iterations 6
# Cbc0038I Pass  94: (17.73 seconds) suminf.   24.47438 (117) obj. -1.17218e+08 iterations 3
# Cbc0038I Pass  95: (17.78 seconds) suminf.   25.45297 (114) obj. -1.17218e+08 iterations 7
# Cbc0038I Pass  96: (17.82 seconds) suminf.   24.47438 (117) obj. -1.17218e+08 iterations 4
# Cbc0038I Pass  97: (17.86 seconds) suminf.   24.47438 (117) obj. -1.17218e+08 iterations 1
# Cbc0038I Pass  98: (17.90 seconds) suminf.   24.47438 (117) obj. -1.17218e+08 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6664 integers at bound fixed and 5540 continuous
# Cbc0038I Full problem 115092 rows 13485 columns, reduced to 2466 rows 1144 columns
# Cbc0038I Mini branch and bound did not improve solution (18.61 seconds)
# Cbc0038I After 18.61 seconds - Feasibility pump exiting with objective of -1.16818e+08 - took 13.51 seconds
# Cbc0012I Integer solution of -1.168176e+08 found by feasibility pump after 0 iterations and 0 nodes (18.82 seconds)
# Cbc0038I Full problem 115092 rows 13485 columns, reduced to 2308 rows 1119 columns
# Cbc0012I Integer solution of -1.1718983e+08 found by DiveCoefficient after 3871 iterations and 0 nodes (32.60 seconds)
# Cbc0031I 402 added rows had average density of 21.599502
# Cbc0013I At root node, 402 cuts changed objective from -1.1763341e+08 to -1.1723914e+08 in 42 passes
# Cbc0014I Cut generator 0 (Probing) - 273 row cuts average 2.0 elements, 41 column cuts (208 active)  in 2.216 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1595 row cuts average 55.9 elements, 0 column cuts (0 active)  in 1.793 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.310 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 465 row cuts average 23.5 elements, 0 column cuts (0 active)  in 1.078 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 12 row cuts average 15.8 elements, 0 column cuts (0 active)  in 0.712 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1535 row cuts average 42.4 elements, 0 column cuts (0 active)  in 1.474 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -1.1718983e+08 best solution, best possible -1.1723914e+08 (32.92 seconds)
# Cbc0012I Integer solution of -1.1720495e+08 found by DiveCoefficient after 3904 iterations and 1 nodes (34.31 seconds)
# Cbc0012I Integer solution of -1.1722397e+08 found by DiveCoefficient after 3906 iterations and 2 nodes (35.35 seconds)
# Cbc0012I Integer solution of -1.1723909e+08 found by DiveCoefficient after 3919 iterations and 2 nodes (36.57 seconds)
# Cbc0001I Search completed - best objective -117239085.4721335, took 4153 iterations and 8 nodes (39.14 seconds)
# Cbc0032I Strong branching done 106 times (1399 iterations), fathomed 2 nodes and fixed 5 variables
# Cbc0035I Maximum depth 3, 1608 variables fixed on reduced cost
# Cuts at root node changed objective from -1.17633e+08 to -1.17239e+08
# Probing was tried 50 times and created 320 cuts of which 167 were active after adding rounds of cuts (2.292 seconds)
# Gomory was tried 50 times and created 1595 cuts of which 0 were active after adding rounds of cuts (1.863 seconds)
# Knapsack was tried 42 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.310 seconds)
# Clique was tried 42 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# MixedIntegerRounding2 was tried 50 times and created 481 cuts of which 0 were active after adding rounds of cuts (1.271 seconds)
# FlowCover was tried 42 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.712 seconds)
# TwoMirCuts was tried 42 times and created 1535 cuts of which 0 were active after adding rounds of cuts (1.474 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.029 seconds)
# ImplicationCuts was tried 8 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                117239085.47213349
# Enumerated nodes:               8
# Total iterations:               4153
# Time (CPU seconds):             41.55
# Time (Wallclock seconds):       42.16
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       41.85   (Wallclock seconds):       42.48

# %%
# 修正后的代码
df = pd.concat(dfs)

# 计算平均值时需要指定哪些列进行聚合
df = df.groupby(["Field", "Crop", "Season", "Year"]).agg("mean").reset_index()
df = df[~((df["Season"] == 2) & (df["Field"] < 27))]  # 去掉单季地块第二季度的数据

# 获取不包括 2023 年的唯一年份
years = df["Year"].unique()
years = [year for year in years if year != 2023]


# 创建一个 Excel writer 对象
with pd.ExcelWriter(f"test-{times}.xlsx") as writer:
    for year in years:
        # 过滤特定年份的数据
        df_year = df[df["Year"] == year]

        # 透视表，Field 作为行，Crop 作为列
        pivot_table = df_year.pivot_table(
            index=["Season", "Field"], columns="Crop", values="Planting", aggfunc="sum"
        ).round(
            1
        )  # 保留一位小数

        # 将透视表写入 Excel 的 sheet
        pivot_table.to_excel(writer, sheet_name=str(year))

print(f"Exported to test-{times}.xlsx")
# Out:
# Exported to test-1.xlsx
