# %%
import pandas as pd
import numpy as np
import datetime
from planning import planning

stats_2023 = pd.read_csv("../../data/preprocess/pre-processed.csv")
stats_2023.dtypes
# Out:
# Field ID           int64
# Field Name        object
# Crop ID            int64
# Crop Name         object
# Crop Type         object
# Planting Area    float64
# Season ID          int64
# Season            object
# Field Type        object
# Field Area       float64
# Per Yield        float64
# Per Cost         float64
# Per Price        float64
# Yield            float64
# Cost             float64
# Selling          float64
# Revenue          float64
# Profit           float64
# dtype: object

# %%
fields_id = list(map(int, stats_2023["Field ID"].unique()))  # 所有的地块
crops_id = list(map(int, stats_2023["Crop ID"].unique()))  # 所有的作物
seasons_id = list(map(int, stats_2023["Season ID"].unique()))  # 所有的时节
fields_id.sort()
crops_id.sort()
seasons_id.sort()
years = range(2023, 2031)  # 要优化的年份


def pop_ndarray(arr, element_to_pop):
    index = np.where(arr == element_to_pop)[0]
    if index.size > 0:
        arr = np.delete(arr, index)
    return arr


# A类粮食作物的集合
grains_A = stats_2023[
    (stats_2023["Crop Type"] == "粮食") | (stats_2023["Crop Type"] == "粮食（豆类）")
]["Crop ID"].unique()
grains_A = pop_ndarray(grains_A, 16)
grains_A.sort()

# B类粮食作物的集合
grains_B = np.array([16])

# A类蔬菜作物的集合
vege_A = stats_2023[
    (stats_2023["Crop Type"] == "蔬菜") | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
for i in range(3):
    vege_A = pop_ndarray(vege_A, 35 + i)
vege_A.sort()

# B类蔬菜作物的集合
vege_B = np.array([35, 36, 37])

# 食用菌作物的集合
mush = stats_2023[stats_2023["Crop Type"] == "食用菌"]["Crop ID"].unique()
mush.sort()

# 豆类作物的集合
beans = stats_2023[
    (stats_2023["Crop Type"] == "粮食（豆类）")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
beans.sort()

# 第 i 个地块的类型（如平旱地、梯田、山坡地、智能大棚、普通大棚、水浇地）
t_i = {
    i: stats_2023[stats_2023["Field ID"] == i]["Field Type"].values[0]
    for i in fields_id
}

# 第 i 个地块在第 s 季可种植的作物集合
T_hat_i_s: dict[tuple : np.ndarray] = {}


for i in fields_id:
    if t_i[i] in ["平旱地", "梯田", "山坡地"]:
        T_hat_i_s[i, 1] = grains_A
        T_hat_i_s[i, 2] = np.array([])
    elif t_i[i] in ["水浇地"]:
        T_hat_i_s[i, 1] = np.concatenate([grains_B, vege_A])
        T_hat_i_s[i, 2] = vege_B
    elif t_i[i] in ["普通大棚"]:
        T_hat_i_s[i, 1] = vege_A
        T_hat_i_s[i, 2] = mush
    elif t_i[i] in ["智慧大棚"]:
        T_hat_i_s[i, 1] = vege_A
        T_hat_i_s[i, 2] = vege_A

# 市场互替性系数
R_ij = {}  # 作物 i 对作物 j 在市场上的互替性系数

# 将所有作物对初始化为 0
for i in crops_id:
    for j in crops_id:
        if i != j:
            R_ij[i, j] = 0


# 对于同类型的作物，其市场价格接近，互替性系数越高
# 定义一个函数来计算互替性系数
def calculate_substitutability(price_i, price_j):
    # 计算价格差距的百分比
    price_diff_percentage = abs(price_i - price_j) / ((price_i + price_j) / 2)
    # 使用一个简单的公式来量化互替性系数
    # 这里假设价格差距越小，互替性越高
    substitutability = max(0, 1 - price_diff_percentage)
    return substitutability


# 计算同类型作物之间的互替性系数
def calculate_R_ij_for_type(crop_ids):
    for i in crop_ids:
        for j in crop_ids:
            if i != j:
                price_i = stats_2023[stats_2023["Crop ID"] == i]["Per Price"].values[0]
                price_j = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
                if price_i is not None and price_j is not None:
                    R_ij[i, j] = calculate_substitutability(price_i, price_j)


# 假设 grains_A 是同类型作物的集合
calculate_R_ij_for_type(grains_A)
calculate_R_ij_for_type(grains_B)
calculate_R_ij_for_type(vege_A)
calculate_R_ij_for_type(vege_B)
calculate_R_ij_for_type(mush)
calculate_R_ij_for_type(beans)

print(R_ij)
# Out:
# {(1, 2): np.float64(0.2093023255813954), (1, 3): np.float64(0.13043478260869568), (1, 4): np.float64(0.2682926829268293), (1, 5): np.float64(0.30000000000000004), (1, 6): np.float64(0.9259259259259259), (1, 7): np.float64(0.92), (1, 8): np.float64(0.30000000000000004), (1, 9): np.float64(0.4054054054054054), (1, 10): np.float64(0.2093023255813954), (1, 11): 0, (1, 12): np.float64(0.26315789473684215), (1, 13): np.float64(1.0), (1, 14): np.float64(0.48571428571428577), (1, 15): np.float64(0.9259259259259259), (1, 16): 0, (1, 17): np.float64(0.15555555555555556), (1, 18): np.float64(0.30000000000000004), (1, 19): np.float64(0.33333333333333337), (1, 20): 0, (1, 21): 0, (1, 22): 0, (1, 23): 0, (1, 24): 0, (1, 25): 0, (1, 26): 0, (1, 27): 0, (1, 28): 0, (1, 29): 0, (1, 30): 0, (1, 31): 0, (1, 32): 0, (1, 33): 0, (1, 34): 0, (1, 35): 0, (1, 36): 0, (1, 37): 0, (1, 38): 0, (1, 39): 0, (1, 40): 0, (1, 41): 0, (2, 1): np.float64(0.2093023255813954), (2, 3): np.float64(0.9047619047619048), (2, 4): np.float64(0.9310344827586207), (2, 5): np.float64(0.8947368421052632), (2, 6): np.float64(0.2727272727272727), (2, 7): np.float64(0.1428571428571429), (2, 8): np.float64(0.8947368421052632), (2, 9): np.float64(0.7777777777777778), (2, 10): np.float64(1.0), (2, 11): 0, (2, 12): 0, (2, 13): np.float64(0.2093023255813954), (2, 14): np.float64(0.6923076923076923), (2, 15): np.float64(0.2727272727272727), (2, 16): 0, (2, 17): np.float64(0.935483870967742), (2, 18): np.float64(0.8947368421052632), (2, 19): np.float64(0.8571428571428572), (2, 20): 0, (2, 21): 0, (2, 22): 0, (2, 23): 0, (2, 24): 0, (2, 25): 0, (2, 26): 0, (2, 27): 0, (2, 28): 0, (2, 29): 0, (2, 30): 0, (2, 31): 0, (2, 32): 0, (2, 33): 0, (2, 34): 0, (2, 35): 0, (2, 36): 0, (2, 37): 0, (2, 38): 0, (2, 39): 0, (2, 40): 0, (2, 41): 0, (3, 1): np.float64(0.13043478260869568), (3, 2): np.float64(0.9047619047619048), (3, 4): np.float64(0.8360655737704918), (3, 5): np.float64(0.8), (3, 6): np.float64(0.19148936170212771), (3, 7): np.float64(0.06666666666666665), (3, 8): np.float64(0.8), (3, 9): np.float64(0.6842105263157895), (3, 10): np.float64(0.9047619047619048), (3, 11): 0, (3, 12): 0, (3, 13): np.float64(0.13043478260869568), (3, 14): np.float64(0.6), (3, 15): np.float64(0.19148936170212771), (3, 16): 0, (3, 17): np.float64(0.9692307692307692), (3, 18): np.float64(0.8), (3, 19): np.float64(0.7627118644067796), (3, 20): 0, (3, 21): 0, (3, 22): 0, (3, 23): 0, (3, 24): 0, (3, 25): 0, (3, 26): 0, (3, 27): 0, (3, 28): 0, (3, 29): 0, (3, 30): 0, (3, 31): 0, (3, 32): 0, (3, 33): 0, (3, 34): 0, (3, 35): 0, (3, 36): 0, (3, 37): 0, (3, 38): 0, (3, 39): 0, (3, 40): 0, (3, 41): 0, (4, 1): np.float64(0.2682926829268293), (4, 2): np.float64(0.9310344827586207), (4, 3): np.float64(0.8360655737704918), (4, 5): np.float64(0.9636363636363636), (4, 6): np.float64(0.33333333333333337), (4, 7): np.float64(0.19999999999999996), (4, 8): np.float64(0.9636363636363636), (4, 9): np.float64(0.8461538461538461), (4, 10): np.float64(0.9310344827586207), (4, 11): 0, (4, 12): 0, (4, 13): np.float64(0.2682926829268293), (4, 14): np.float64(0.76), (4, 15): np.float64(0.33333333333333337), (4, 16): 0, (4, 17): np.float64(0.8666666666666667), (4, 18): np.float64(0.9636363636363636), (4, 19): np.float64(0.9259259259259259), (4, 20): 0, (4, 21): 0, (4, 22): 0, (4, 23): 0, (4, 24): 0, (4, 25): 0, (4, 26): 0, (4, 27): 0, (4, 28): 0, (4, 29): 0, (4, 30): 0, (4, 31): 0, (4, 32): 0, (4, 33): 0, (4, 34): 0, (4, 35): 0, (4, 36): 0, (4, 37): 0, (4, 38): 0, (4, 39): 0, (4, 40): 0, (4, 41): 0, (5, 1): np.float64(0.30000000000000004), (5, 2): np.float64(0.8947368421052632), (5, 3): np.float64(0.8), (5, 4): np.float64(0.9636363636363636), (5, 6): np.float64(0.36585365853658536), (5, 7): np.float64(0.23076923076923073), (5, 8): np.float64(1.0), (5, 9): np.float64(0.8823529411764706), (5, 10): np.float64(0.8947368421052632), (5, 11): 0, (5, 12): 0, (5, 13): np.float64(0.30000000000000004), (5, 14): np.float64(0.7959183673469388), (5,  ...

# %%
dfs = []
times = 50  # 重复次数


def expected_selling(percost, price):
    return 8122.041 + 1.385 * percost - 1.2894625 * price


for i in range(times):
    # 使用当前时间作为随机数种子
    np.random.seed(datetime.datetime.now().second)

    S = {}  # 期望产量
    Y = {}  # 单位面积产量
    P = {}  # 售价
    C = {}  # 单位面积成本

    for j in crops_id:
        Y[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Yield"].values[0]
        P[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
        C[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Cost"].values[0]
        S[j, 2023] = expected_selling(C[j, 2023], P[j, 2023])

    for j in crops_id:
        # 小麦和玉米的预期销售量有平均5%-10%的年增长
        for k in years:

            # 农作物亩产量可能有±10%的变化.
            increment = np.random.uniform(-0.1, 0.1)
            Y[j, k + 1] = Y[j, k] * np.random.normal(1 + increment, 0.01)

            # 种植成本每年增长约5%。
            increment = 0.05
            C[j, k + 1] = C[j, k] * np.random.normal(1 + increment, 0.01)

            # 蔬菜类作物价格每年增长约5%。
            if j in vege_A or j in vege_B:
                increment = 0.05
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 食用菌价格每年下降1%-5%。
            if j in mush:
                increment = np.random.uniform(-0.05, -0.01)
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 羊肚菌的销售价格每年下降幅5%
            if j == 41:
                increment = -0.05
                P[j, k + 1] = P[j, k] * (1 + increment)
            else:
                P[j, k + 1] = P[j, k]

            S[j, k + 1] = expected_selling(C[j, k + 1], P[j, k + 1])

            if j in [6, 7]:
                increment = np.random.uniform(0.05, 0.1)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 其他作物的预期销售量变化约±5%。
            else:
                increment = np.random.uniform(-0.05, 0.05)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

    dfs.append(
        planning(
            fields_id,
            crops_id,
            seasons_id,
            years,
            t_i,
            T_hat_i_s,
            R_ij,
            grains_A,
            grains_B,
            vege_A,
            vege_B,
            mush,
            beans,
            stats_2023,
            [
                S,
                Y,
                P,
                C,
            ],
        )
    )
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4941048ec56d4aec94cab849e4d1b493-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/4941048ec56d4aec94cab849e4d1b493-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.29668e+08 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3264 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 107 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 55 integers unsatisfied sum - 16.5
# Cbc0038I Pass   1: (0.60 seconds) suminf.    0.00000 (0) obj. -1.21926e+08 iterations 1166
# Cbc0038I Solution found of -1.21926e+08
# Cbc0038I Relaxing continuous gives -1.21926e+08
# Cbc0038I Before mini branch and bound, 7214 integers at bound fixed and 5770 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 168 rows 165 columns
# Cbc0038I Mini branch and bound improved solution from -1.21926e+08 to -1.21927e+08 (0.65 seconds)
# Cbc0038I Round again with cutoff of -1.21929e+08
# Cbc0038I Reduced cost fixing fixed 609 variables on major pass 2
# Cbc0038I Pass   2: (0.81 seconds) suminf.    0.31623 (2) obj. -1.21929e+08 iterations 820
# Cbc0038I Pass   3: (0.82 seconds) suminf.    0.91046 (4) obj. -1.21929e+08 iterations 84
# Cbc0038I Pass   4: (0.85 seconds) suminf.    0.91046 (4) obj. -1.21929e+08 iterations 450
# Cbc0038I Pass   5: (0.87 seconds) suminf.    2.49416 (10) obj. -1.21929e+08 iterations 472
# Cbc0038I Pass   6: (0.88 seconds) suminf.    2.19416 (9) obj. -1.21929e+08 iterations 229
# Cbc0038I Pass   7: (0.91 seconds) suminf.    2.47867 (7) obj. -1.21929e+08 iterations 402
# Cbc0038I Pass   8: (0.92 seconds) suminf.    0.84804 (4) obj. -1.21929e+08 iterations 117
# Cbc0038I Pass   9: (0.94 seconds) suminf.    0.93168 (4) obj. -1.21929e+08 iterations 277
# Cbc0038I Pass  10: (0.95 seconds) suminf.    0.57023 (2) obj. -1.21929e+08 iterations 34
# Cbc0038I Pass  11: (0.97 seconds) suminf.    2.22922 (7) obj. -1.21929e+08 iterations 415
# Cbc0038I Pass  12: (1.02 seconds) suminf.    0.45340 (2) obj. -1.21929e+08 iterations 953
# Cbc0038I Pass  13: (1.07 seconds) suminf.    0.88740 (3) obj. -1.21929e+08 iterations 958
# Cbc0038I Pass  14: (1.12 seconds) suminf.    0.11854 (2) obj. -1.21929e+08 iterations 1018
# Cbc0038I Pass  15: (1.16 seconds) suminf.    0.41694 (2) obj. -1.21929e+08 iterations 797
# Cbc0038I Pass  16: (1.18 seconds) suminf.    2.10361 (8) obj. -1.21929e+08 iterations 448
# Cbc0038I Pass  17: (1.21 seconds) suminf.    1.19918 (4) obj. -1.21929e+08 iterations 602
# Cbc0038I Pass  18: (1.24 seconds) suminf.    1.08508 (4) obj. -1.21929e+08 iterations 494
# Cbc0038I Pass  19: (1.26 seconds) suminf.    2.74921 (9) obj. -1.21929e+08 iterations 419
# Cbc0038I Pass  20: (1.28 seconds) suminf.    1.11478 (4) obj. -1.21929e+08 iterations 508
# Cbc0038I Pass  21: (1.30 seconds) suminf.    1.48076 (4) obj. -1.21929e+08 iterations 257
# Cbc0038I Pass  22: (1.32 seconds) suminf.    1.59520 (5) obj. -1.21929e+08 iterations 317
# Cbc0038I Pass  23: (1.37 seconds) suminf.    0.49906 (2) obj. -1.21929e+08 iterations 1023
# Cbc0038I Pass  24: (1.43 seconds) suminf.    0.93254 (2) obj. -1.21929e+08 iterations 933
# Cbc0038I Pass  25: (1.45 seconds) suminf.    1.68698 (5) obj. -1.21929e+08 iterations 227
# Cbc0038I Pass  26: (1.47 seconds) suminf.    1.08698 (3) obj. -1.21929e+08 iterations 182
# Cbc0038I Pass  27: (1.54 seconds) suminf.    0.84947 (2) obj. -1.21929e+08 iterations 737
# Cbc0038I Pass  28: (1.55 seconds) suminf.    0.47480 (2) obj. -1.21929e+08 iterations 46
# Cbc0038I Pass  29: (1.58 seconds) suminf.    2.08698 (6) obj. -1.21929e+08 iterations 387
# Cbc0038I Pass  30: (1.60 seconds) suminf.    1.48698 (4) obj. -1.21929e+08 iterations 170
# Cbc0038I Pass  31: (1.65 seconds) suminf.    0.84947 (2) obj. -1.21929e+08 iterations 910
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7189 integers at bound fixed and 5748 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 231 rows 220 columns
# Cbc0038I Mini branch and bound improved solution from -1.21927e+08 to -1.2194e+08 (1.69 seconds)
# Cbc0038I Round again with cutoff of -1.2194e+08
# Cbc0038I Reduced cost fixing fixed 810 variables on major pass 3
# Cbc0038I Pass  31: (1.71 seconds) suminf.    1.46003 (6) obj. -1.2194e+08 iterations 29
# Cbc0038I Pass  32: (1.73 seconds) suminf.    2.48059 (9) obj. -1.2194e+08 iterations 161
# Cbc0038I Pass  33: (1.74 seconds) suminf.    2.48059 (9) obj. -1.2194e+08 iterations 6
# Cbc0038I Pass  34: (1.76 seconds) suminf.    1.88793 (8) obj. -1.2194e+08 iterations 331
# Cbc0038I Pass  35: (1.77 seconds) suminf.    1.10407 (4) obj. -1.2194e+08 iterations 64
# Cbc0038I Pass  36: (1.79 seconds) suminf.    1.51602 (4) obj. -1.2194e+08 iterations 329
# Cbc0038I Pass  37: (1.81 seconds) suminf.    3.04658 (11) obj. -1.2194e+08 iterations 289
# Cbc0038I Pass  38: (1.83 seconds) suminf.    1.10407 (4) obj. -1.2194e+08 iterations 465
# Cbc0038I Pass  39: (1.84 seconds) suminf.    1.51602 (4) obj. -1.2194e+08 iterations 240
# Cbc0038I Pass  40: (1.86 seconds) suminf.    1.83339 (7) obj. -1.2194e+08 iterations 292
# Cbc0038I Pass  41: (1.87 seconds) suminf.    1.19185 (4) obj. -1.2194e+08 iterations 518
# Cbc0038I Pass  42: (1.90 seconds) suminf.    1.22685 (4) obj. -1.2194e+08 iterations 259
# Cbc0038I Pass  43: (1.91 seconds) suminf.    1.50300 (6) obj. -1.2194e+08 iterations 225
# Cbc0038I Pass  44: (1.93 seconds) suminf.    1.19929 (4) obj. -1.2194e+08 iterations 513
# Cbc0038I Pass  45: (1.95 seconds) suminf.    1.20234 (4) obj. -1.2194e+08 iterations 243
# Cbc0038I Pass  46: (1.97 seconds) suminf.    2.60291 (9) obj. -1.2194e+08 iterations 332
# Cbc0038I Pass  47: (1.98 seconds) suminf.    1.75300 (6) obj. -1.2194e+08 iterations 484
# Cbc0038I Pass  48: (2.00 seconds) suminf.    1.95483 (6) obj. -1.2194e+08 iterations 247
# Cbc0038I Pass  49: (2.02 seconds) suminf.    1.82257 (6) obj. -1.2194e+08 iterations 288
# Cbc0038I Pass  50: (2.03 seconds) suminf.    1.10477 (4) obj. -1.2194e+08 iterations 416
# Cbc0038I Pass  51: (2.05 seconds) suminf.    1.51372 (4) obj. -1.2194e+08 iterations 212
# Cbc0038I Pass  52: (2.07 seconds) suminf.    1.08481 (5) obj. -1.2194e+08 iterations 237
# Cbc0038I Pass  53: (2.08 seconds) suminf.    1.08481 (5) obj. -1.2194e+08 iterations 165
# Cbc0038I Pass  54: (2.10 seconds) suminf.    1.59695 (4) obj. -1.2194e+08 iterations 314
# Cbc0038I Pass  55: (2.11 seconds) suminf.    0.87314 (4) obj. -1.2194e+08 iterations 43
# Cbc0038I Pass  56: (2.13 seconds) suminf.    1.30204 (4) obj. -1.2194e+08 iterations 187
# Cbc0038I Pass  57: (2.15 seconds) suminf.    1.12421 (4) obj. -1.2194e+08 iterations 86
# Cbc0038I Pass  58: (2.17 seconds) suminf.    1.48051 (5) obj. -1.2194e+08 iterations 416
# Cbc0038I Pass  59: (2.18 seconds) suminf.    1.11719 (4) obj. -1.2194e+08 iterations 406
# Cbc0038I Pass  60: (2.20 seconds) suminf.    1.47281 (4) obj. -1.2194e+08 iterations 233
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7191 integers at bound fixed and 5755 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 216 rows 205 columns
# Cbc0038I Mini branch and bound did not improve solution (2.23 seconds)
# Cbc0038I After 2.23 seconds - Feasibility pump exiting with objective of -1.2194e+08 - took 1.64 seconds
# Cbc0012I Integer solution of -1.2193969e+08 found by feasibility pump after 0 iterations and 0 nodes (2.24 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 175 rows 169 columns
# Cbc0031I 51 added rows had average density of 8.4313725
# Cbc0013I At root node, 153 cuts changed objective from -1.2194362e+08 to -1.2193969e+08 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 2.0 elements, 4612 column cuts (4612 active)  in 0.013 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 52 row cuts average 8.9 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 47 row cuts average 8.9 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 52 row cuts average 8.9 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -121939691.7117538, took 0 iterations and 0 nodes (2.35 seconds)
# Cbc0035I Maximum depth 0, 799 variables fixed on reduced cost
# Cuts at root node changed objective from -1.21944e+08 to -1.2194e+08
# Probing was tried 1 times and created 4614 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Gomory was tried 1 times and created 52 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 47 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 52 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                121939691.71175385
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             3.60
# Time (Wallclock seconds):       3.69
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.76   (Wallclock seconds):       3.87
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4b42b71620ea43a8be863b41144637b2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/4b42b71620ea43a8be863b41144637b2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.30931e+08 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3264 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 107 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 182 integers unsatisfied sum - 48.5885
# Cbc0038I Pass   1: (0.57 seconds) suminf.    0.00000 (0) obj. -1.20469e+08 iterations 1190
# Cbc0038I Solution found of -1.20469e+08
# Cbc0038I Relaxing continuous gives -1.20469e+08
# Cbc0038I Rounding solution of -1.20476e+08 is better than previous of -1.20469e+08
#
# Cbc0038I Before mini branch and bound, 7087 integers at bound fixed and 5703 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 473 rows 344 columns
# Cbc0038I Mini branch and bound improved solution from -1.20476e+08 to -1.2067e+08 (0.72 seconds)
# Cbc0038I Round again with cutoff of -1.20681e+08
# Cbc0038I Reduced cost fixing fixed 108 variables on major pass 2
# Cbc0038I Pass   2: (0.90 seconds) suminf.    4.20346 (12) obj. -1.20681e+08 iterations 1317
# Cbc0038I Pass   3: (0.92 seconds) suminf.    1.90332 (11) obj. -1.20681e+08 iterations 68
# Cbc0038I Pass   4: (0.93 seconds) suminf.    1.90332 (11) obj. -1.20681e+08 iterations 3
# Cbc0038I Pass   5: (0.95 seconds) suminf.    5.19472 (21) obj. -1.20681e+08 iterations 268
# Cbc0038I Pass   6: (0.96 seconds) suminf.    3.72581 (16) obj. -1.20681e+08 iterations 15
# Cbc0038I Pass   7: (0.98 seconds) suminf.    3.82590 (17) obj. -1.20681e+08 iterations 208
# Cbc0038I Pass   8: (0.99 seconds) suminf.    3.48569 (16) obj. -1.20681e+08 iterations 16
# Cbc0038I Pass   9: (1.01 seconds) suminf.    4.08043 (17) obj. -1.20681e+08 iterations 223
# Cbc0038I Pass  10: (1.03 seconds) suminf.    4.56718 (25) obj. -1.20681e+08 iterations 297
# Cbc0038I Pass  11: (1.04 seconds) suminf.    2.79613 (10) obj. -1.20681e+08 iterations 221
# Cbc0038I Pass  12: (1.06 seconds) suminf.    2.11524 (9) obj. -1.20681e+08 iterations 107
# Cbc0038I Pass  13: (1.07 seconds) suminf.    3.19187 (11) obj. -1.20681e+08 iterations 137
# Cbc0038I Pass  14: (1.09 seconds) suminf.    2.59201 (9) obj. -1.20681e+08 iterations 216
# Cbc0038I Pass  15: (1.11 seconds) suminf.    0.84554 (2) obj. -1.20681e+08 iterations 313
# Cbc0038I Pass  16: (1.12 seconds) suminf.    0.42704 (2) obj. -1.20681e+08 iterations 99
# Cbc0038I Pass  17: (1.14 seconds) suminf.    0.84554 (2) obj. -1.20681e+08 iterations 145
# Cbc0038I Pass  18: (1.16 seconds) suminf.    4.67560 (20) obj. -1.20681e+08 iterations 427
# Cbc0038I Pass  19: (1.18 seconds) suminf.    3.47560 (16) obj. -1.20681e+08 iterations 205
# Cbc0038I Pass  20: (1.19 seconds) suminf.    4.35736 (17) obj. -1.20681e+08 iterations 212
# Cbc0038I Pass  21: (1.21 seconds) suminf.   10.34036 (39) obj. -1.20681e+08 iterations 284
# Cbc0038I Pass  22: (1.24 seconds) suminf.    4.28168 (18) obj. -1.20681e+08 iterations 567
# Cbc0038I Pass  23: (1.26 seconds) suminf.    4.18322 (17) obj. -1.20681e+08 iterations 50
# Cbc0038I Pass  24: (1.28 seconds) suminf.    5.41615 (17) obj. -1.20681e+08 iterations 203
# Cbc0038I Pass  25: (1.29 seconds) suminf.    2.90321 (16) obj. -1.20681e+08 iterations 49
# Cbc0038I Pass  26: (1.31 seconds) suminf.    3.30693 (13) obj. -1.20681e+08 iterations 193
# Cbc0038I Pass  27: (1.33 seconds) suminf.    3.00693 (12) obj. -1.20681e+08 iterations 3
# Cbc0038I Pass  28: (1.34 seconds) suminf.    4.29705 (12) obj. -1.20681e+08 iterations 62
# Cbc0038I Pass  29: (1.36 seconds) suminf.    2.06589 (11) obj. -1.20681e+08 iterations 185
# Cbc0038I Pass  30: (1.37 seconds) suminf.    4.04357 (12) obj. -1.20681e+08 iterations 89
# Cbc0038I Pass  31: (1.39 seconds) suminf.    2.19411 (11) obj. -1.20681e+08 iterations 187
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7044 integers at bound fixed and 5658 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 579 rows 431 columns
# Cbc0038I Mini branch and bound improved solution from -1.2067e+08 to -1.20711e+08 (1.53 seconds)
# Cbc0038I Round again with cutoff of -1.20726e+08
# Cbc0038I Reduced cost fixing fixed 231 variables on major pass 3
# Cbc0038I Pass  31: (1.58 seconds) suminf.    9.04784 (46) obj. -1.20726e+08 iterations 196
# Cbc0038I Pass  32: (1.59 seconds) suminf.    7.84033 (39) obj. -1.20726e+08 iterations 49
# Cbc0038I Pass  33: (1.60 seconds) suminf.   11.05572 (51) obj. -1.20726e+08 iterations 45
# Cbc0038I Pass  34: (1.61 seconds) suminf.    9.64144 (46) obj. -1.20726e+08 iterations 8
# Cbc0038I Pass  35: (1.62 seconds) suminf.    9.43628 (46) obj. -1.20726e+08 iterations 19
# Cbc0038I Pass  36: (1.63 seconds) suminf.    9.43628 (46) obj. -1.20726e+08 iterations 16
# Cbc0038I Pass  37: (1.64 seconds) suminf.    9.64144 (46) obj. -1.20726e+08 iterations 11
# Cbc0038I Pass  38: (1.66 seconds) suminf.   13.61692 (50) obj. -1.20726e+08 iterations 251
# Cbc0038I Pass  39: (1.68 seconds) suminf.    9.01251 (44) obj. -1.20726e+08 iterations 329
# Cbc0038I Pass  40: (1.68 seconds) suminf.    9.01251 (44) obj. -1.20726e+08 iterations 0
# Cbc0038I Pass  41: (1.69 seconds) suminf.    9.01251 (44) obj. -1.20726e+08 iterations 11
# Cbc0038I Pass  42: (1.70 seconds) suminf.   12.95233 (55) obj. -1.20726e+08 iterations 237
# Cbc0038I Pass  43: (1.72 seconds) suminf.   11.59911 (54) obj. -1.20726e+08 iterations 205
# Cbc0038I Pass  44: (1.72 seconds) suminf.   11.59911 (54) obj. -1.20726e+08 iterations 0
# Cbc0038I Pass  45: (1.73 seconds) suminf.   11.59911 (54) obj. -1.20726e+08 iterations 20
# Cbc0038I Pass  46: (1.75 seconds) suminf.   11.47291 (47) obj. -1.20726e+08 iterations 274
# Cbc0038I Pass  47: (1.78 seconds) suminf.   10.14700 (47) obj. -1.20726e+08 iterations 495
# Cbc0038I Pass  48: (1.79 seconds) suminf.   10.14700 (47) obj. -1.20726e+08 iterations 28
# Cbc0038I Pass  49: (1.81 seconds) suminf.   11.45220 (52) obj. -1.20726e+08 iterations 325
# Cbc0038I Pass  50: (1.82 seconds) suminf.    8.34324 (40) obj. -1.20726e+08 iterations 235
# Cbc0038I Pass  51: (1.83 seconds) suminf.    8.34324 (40) obj. -1.20726e+08 iterations 5
# Cbc0038I Pass  52: (1.85 seconds) suminf.   11.97088 (44) obj. -1.20726e+08 iterations 70
# Cbc0038I Pass  53: (1.86 seconds) suminf.   11.43039 (44) obj. -1.20726e+08 iterations 25
# Cbc0038I Pass  54: (1.87 seconds) suminf.    8.41076 (36) obj. -1.20726e+08 iterations 142
# Cbc0038I Pass  55: (1.89 seconds) suminf.    7.51805 (33) obj. -1.20726e+08 iterations 52
# Cbc0038I Pass  56: (1.90 seconds) suminf.    7.51805 (33) obj. -1.20726e+08 iterations 10
# Cbc0038I Pass  57: (1.92 seconds) suminf.   11.31357 (51) obj. -1.20726e+08 iterations 259
# Cbc0038I Pass  58: (1.93 seconds) suminf.   10.71100 (44) obj. -1.20726e+08 iterations 229
# Cbc0038I Pass  59: (1.94 seconds) suminf.   11.24210 (44) obj. -1.20726e+08 iterations 44
# Cbc0038I Pass  60: (1.96 seconds) suminf.   10.67632 (43) obj. -1.20726e+08 iterations 15
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7050 integers at bound fixed and 5658 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 574 rows 427 columns
# Cbc0038I Mini branch and bound did not improve solution (2.03 seconds)
# Cbc0038I After 2.03 seconds - Feasibility pump exiting with objective of -1.20711e+08 - took 1.49 seconds
# Cbc0012I Integer solution of -1.2071147e+08 found by feasibility pump after 0 iterations and 0 nodes (2.05 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 499 rows 358 columns
# Cbc0012I Integer solution of -1.2076048e+08 found by DiveCoefficient after 104 iterations and 0 nodes (2.27 seconds)
# Cbc0031I 76 added rows had average density of 11.197368
# Cbc0013I At root node, 76 cuts changed objective from -1.2078407e+08 to -1.2076048e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 829 column cuts (829 active)  in 0.026 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 140 row cuts average 13.5 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 72 row cuts average 28.4 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 142 row cuts average 13.6 elements, 0 column cuts (0 active)  in 0.030 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -120760483.379386, took 104 iterations and 0 nodes (2.27 seconds)
# Cbc0035I Maximum depth 0, 255 variables fixed on reduced cost
# Cuts at root node changed objective from -1.20784e+08 to -1.2076e+08
# Probing was tried 3 times and created 829 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# Gomory was tried 3 times and created 140 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 72 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 3 times and created 142 cuts of which 0 were active after adding rounds of cuts (0.030 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
#
# Result - Optimal solution found
#
# Objective value:                120760483.37938601
# Enumerated nodes:               0
# Total iterations:               104
# Time (CPU seconds):             3.55
# Time (Wallclock seconds):       3.62
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.68   (Wallclock seconds):       3.80
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/65daaf0374a841138028a149d6f93c8e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/65daaf0374a841138028a149d6f93c8e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.39856e+08 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 108 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 42 integers unsatisfied sum - 15.45
# Cbc0038I Pass   1: (0.57 seconds) suminf.    0.00000 (0) obj. -1.28554e+08 iterations 1090
# Cbc0038I Solution found of -1.28554e+08
# Cbc0038I Relaxing continuous gives -1.28554e+08
# Cbc0038I Rounding solution of -1.28561e+08 is better than previous of -1.28554e+08
#
# Cbc0038I Before mini branch and bound, 7227 integers at bound fixed and 5820 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 118 rows 103 columns
# Cbc0038I Mini branch and bound improved solution from -1.28561e+08 to -1.28763e+08 (0.62 seconds)
# Cbc0038I Round again with cutoff of -1.28765e+08
# Cbc0038I Reduced cost fixing fixed 643 variables on major pass 2
# Cbc0038I Pass   2: (0.76 seconds) suminf.    3.87997 (10) obj. -1.28765e+08 iterations 1055
# Cbc0038I Pass   3: (0.77 seconds) suminf.    2.98884 (10) obj. -1.28765e+08 iterations 217
# Cbc0038I Pass   4: (0.79 seconds) suminf.    1.97329 (7) obj. -1.28765e+08 iterations 288
# Cbc0038I Pass   5: (0.81 seconds) suminf.    1.67329 (6) obj. -1.28765e+08 iterations 13
# Cbc0038I Pass   6: (0.82 seconds) suminf.    2.61043 (11) obj. -1.28765e+08 iterations 157
# Cbc0038I Pass   7: (0.84 seconds) suminf.    1.11355 (6) obj. -1.28765e+08 iterations 260
# Cbc0038I Pass   8: (0.86 seconds) suminf.    0.38719 (2) obj. -1.28765e+08 iterations 105
# Cbc0038I Pass   9: (0.87 seconds) suminf.    0.90594 (2) obj. -1.28765e+08 iterations 32
# Cbc0038I Pass  10: (0.89 seconds) suminf.    1.38668 (4) obj. -1.28765e+08 iterations 463
# Cbc0038I Pass  11: (0.92 seconds) suminf.    0.46229 (2) obj. -1.28765e+08 iterations 538
# Cbc0038I Pass  12: (0.94 seconds) suminf.    1.05014 (5) obj. -1.28765e+08 iterations 162
# Cbc0038I Pass  13: (0.95 seconds) suminf.    0.52990 (4) obj. -1.28765e+08 iterations 152
# Cbc0038I Pass  14: (1.00 seconds) suminf.    0.00000 (0) obj. -1.28765e+08 iterations 850
# Cbc0038I Solution found of -1.28765e+08
# Cbc0038I Relaxing continuous gives -1.28765e+08
# Cbc0038I Before mini branch and bound, 7215 integers at bound fixed and 5807 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 151 rows 129 columns
# Cbc0038I Mini branch and bound improved solution from -1.28765e+08 to -1.28775e+08 (1.07 seconds)
# Cbc0038I Round again with cutoff of -1.28775e+08
# Cbc0038I Reduced cost fixing fixed 864 variables on major pass 3
# Cbc0038I Pass  15: (1.14 seconds) suminf.    2.42704 (16) obj. -1.28775e+08 iterations 298
# Cbc0038I Pass  16: (1.15 seconds) suminf.    2.16048 (16) obj. -1.28775e+08 iterations 50
# Cbc0038I Pass  17: (1.17 seconds) suminf.    7.06467 (17) obj. -1.28775e+08 iterations 231
# Cbc0038I Pass  18: (1.18 seconds) suminf.    5.95038 (13) obj. -1.28775e+08 iterations 27
# Cbc0038I Pass  19: (1.20 seconds) suminf.    1.82056 (14) obj. -1.28775e+08 iterations 227
# Cbc0038I Pass  20: (1.21 seconds) suminf.    1.56048 (14) obj. -1.28775e+08 iterations 9
# Cbc0038I Pass  21: (1.23 seconds) suminf.    6.31655 (13) obj. -1.28775e+08 iterations 242
# Cbc0038I Pass  22: (1.25 seconds) suminf.    3.02637 (13) obj. -1.28775e+08 iterations 172
# Cbc0038I Pass  23: (1.26 seconds) suminf.    1.82056 (14) obj. -1.28775e+08 iterations 38
# Cbc0038I Pass  24: (1.28 seconds) suminf.    2.12056 (15) obj. -1.28775e+08 iterations 174
# Cbc0038I Pass  25: (1.30 seconds) suminf.    3.23637 (13) obj. -1.28775e+08 iterations 409
# Cbc0038I Pass  26: (1.31 seconds) suminf.    1.82056 (14) obj. -1.28775e+08 iterations 195
# Cbc0038I Pass  27: (1.33 seconds) suminf.    1.56048 (14) obj. -1.28775e+08 iterations 3
# Cbc0038I Pass  28: (1.35 seconds) suminf.    5.95038 (13) obj. -1.28775e+08 iterations 220
# Cbc0038I Pass  29: (1.36 seconds) suminf.    5.95038 (13) obj. -1.28775e+08 iterations 20
# Cbc0038I Pass  30: (1.38 seconds) suminf.    1.82056 (14) obj. -1.28775e+08 iterations 224
# Cbc0038I Pass  31: (1.40 seconds) suminf.    2.72056 (17) obj. -1.28775e+08 iterations 176
# Cbc0038I Pass  32: (1.41 seconds) suminf.    2.16048 (16) obj. -1.28775e+08 iterations 173
# Cbc0038I Pass  33: (1.43 seconds) suminf.    5.79961 (16) obj. -1.28775e+08 iterations 62
# Cbc0038I Pass  34: (1.44 seconds) suminf.    5.77011 (16) obj. -1.28775e+08 iterations 21
# Cbc0038I Pass  35: (1.46 seconds) suminf.    6.64217 (16) obj. -1.28775e+08 iterations 345
# Cbc0038I Pass  36: (1.48 seconds) suminf.    4.05048 (16) obj. -1.28775e+08 iterations 180
# Cbc0038I Pass  37: (1.50 seconds) suminf.    2.23333 (16) obj. -1.28775e+08 iterations 56
# Cbc0038I Pass  38: (1.51 seconds) suminf.    2.00000 (16) obj. -1.28775e+08 iterations 2
# Cbc0038I Pass  39: (1.53 seconds) suminf.    6.55038 (15) obj. -1.28775e+08 iterations 218
# Cbc0038I Pass  40: (1.54 seconds) suminf.    6.55038 (15) obj. -1.28775e+08 iterations 25
# Cbc0038I Pass  41: (1.57 seconds) suminf.    2.42056 (16) obj. -1.28775e+08 iterations 240
# Cbc0038I Pass  42: (1.58 seconds) suminf.    2.16048 (16) obj. -1.28775e+08 iterations 6
# Cbc0038I Pass  43: (1.59 seconds) suminf.    5.79961 (16) obj. -1.28775e+08 iterations 134
# Cbc0038I Pass  44: (1.60 seconds) suminf.    5.27011 (15) obj. -1.28775e+08 iterations 23
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7220 integers at bound fixed and 5815 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 134 rows 115 columns
# Cbc0038I Mini branch and bound did not improve solution (1.63 seconds)
# Cbc0038I After 1.63 seconds - Feasibility pump exiting with objective of -1.28775e+08 - took 1.07 seconds
# Cbc0012I Integer solution of -1.2877485e+08 found by feasibility pump after 0 iterations and 0 nodes (1.64 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 117 rows 103 columns
# Cbc0031I 29 added rows had average density of 9.6896552
# Cbc0013I At root node, 92 cuts changed objective from -1.2877633e+08 to -1.2877485e+08 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 5062 column cuts (5062 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 33 row cuts average 10.8 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 25 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 34 row cuts average 11.1 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -128774850.6745518, took 0 iterations and 0 nodes (1.76 seconds)
# Cbc0035I Maximum depth 0, 838 variables fixed on reduced cost
# Cuts at root node changed objective from -1.28776e+08 to -1.28775e+08
# Probing was tried 1 times and created 5062 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Gomory was tried 1 times and created 33 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 25 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 34 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
#
# Result - Optimal solution found
#
# Objective value:                128774850.67455177
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             3.07
# Time (Wallclock seconds):       3.16
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.24   (Wallclock seconds):       3.33
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3d573e483b5448ecad65042879a8d40e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/3d573e483b5448ecad65042879a8d40e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.26831e+08 - 0.05 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 108 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 113 integers unsatisfied sum - 28.5462
# Cbc0038I Pass   1: (0.53 seconds) suminf.    0.00000 (0) obj. -1.21446e+08 iterations 869
# Cbc0038I Solution found of -1.21446e+08
# Cbc0038I Relaxing continuous gives -1.21446e+08
# Cbc0038I Before mini branch and bound, 7156 integers at bound fixed and 5798 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 283 rows 189 columns
# Cbc0038I Mini branch and bound improved solution from -1.21446e+08 to -1.21446e+08 (0.58 seconds)
# Cbc0038I Round again with cutoff of -1.21451e+08
# Cbc0038I Reduced cost fixing fixed 410 variables on major pass 2
# Cbc0038I Pass   2: (0.68 seconds) suminf.    0.39335 (2) obj. -1.21451e+08 iterations 652
# Cbc0038I Pass   3: (0.70 seconds) suminf.    0.60763 (2) obj. -1.21451e+08 iterations 423
# Cbc0038I Pass   4: (0.73 seconds) suminf.    5.85648 (24) obj. -1.21451e+08 iterations 605
# Cbc0038I Pass   5: (0.75 seconds) suminf.    3.54932 (14) obj. -1.21451e+08 iterations 388
# Cbc0038I Pass   6: (0.75 seconds) suminf.    3.54932 (14) obj. -1.21451e+08 iterations 0
# Cbc0038I Pass   7: (0.77 seconds) suminf.    3.93288 (15) obj. -1.21451e+08 iterations 293
# Cbc0038I Pass   8: (0.79 seconds) suminf.    3.28832 (13) obj. -1.21451e+08 iterations 27
# Cbc0038I Pass   9: (0.80 seconds) suminf.    2.65149 (13) obj. -1.21451e+08 iterations 60
# Cbc0038I Pass  10: (0.81 seconds) suminf.    6.02124 (27) obj. -1.21451e+08 iterations 285
# Cbc0038I Pass  11: (0.83 seconds) suminf.    5.10375 (23) obj. -1.21451e+08 iterations 300
# Cbc0038I Pass  12: (0.85 seconds) suminf.    6.47948 (24) obj. -1.21451e+08 iterations 311
# Cbc0038I Pass  13: (0.86 seconds) suminf.    4.80034 (22) obj. -1.21451e+08 iterations 75
# Cbc0038I Pass  14: (0.87 seconds) suminf.    4.19118 (22) obj. -1.21451e+08 iterations 22
# Cbc0038I Pass  15: (0.89 seconds) suminf.    4.77805 (22) obj. -1.21451e+08 iterations 30
# Cbc0038I Pass  16: (0.90 seconds) suminf.    6.75999 (27) obj. -1.21451e+08 iterations 282
# Cbc0038I Pass  17: (0.92 seconds) suminf.    5.06878 (22) obj. -1.21451e+08 iterations 305
# Cbc0038I Pass  18: (0.93 seconds) suminf.    5.53031 (22) obj. -1.21451e+08 iterations 16
# Cbc0038I Pass  19: (0.95 seconds) suminf.    6.17390 (25) obj. -1.21451e+08 iterations 258
# Cbc0038I Pass  20: (0.97 seconds) suminf.    5.81169 (24) obj. -1.21451e+08 iterations 327
# Cbc0038I Pass  21: (0.98 seconds) suminf.    3.72510 (22) obj. -1.21451e+08 iterations 37
# Cbc0038I Pass  22: (0.99 seconds) suminf.    3.25025 (22) obj. -1.21451e+08 iterations 32
# Cbc0038I Pass  23: (1.00 seconds) suminf.    6.71349 (24) obj. -1.21451e+08 iterations 115
# Cbc0038I Pass  24: (1.02 seconds) suminf.    3.71179 (22) obj. -1.21451e+08 iterations 187
# Cbc0038I Pass  25: (1.03 seconds) suminf.    5.09100 (25) obj. -1.21451e+08 iterations 212
# Cbc0038I Pass  26: (1.05 seconds) suminf.    4.02772 (22) obj. -1.21451e+08 iterations 211
# Cbc0038I Pass  27: (1.07 seconds) suminf.    6.47529 (24) obj. -1.21451e+08 iterations 230
# Cbc0038I Pass  28: (1.08 seconds) suminf.    4.48926 (22) obj. -1.21451e+08 iterations 223
# Cbc0038I Pass  29: (1.10 seconds) suminf.    6.83428 (28) obj. -1.21451e+08 iterations 259
# Cbc0038I Pass  30: (1.12 seconds) suminf.    4.36526 (22) obj. -1.21451e+08 iterations 289
# Cbc0038I Pass  31: (1.12 seconds) suminf.    4.36526 (22) obj. -1.21451e+08 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7119 integers at bound fixed and 5760 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 380 rows 271 columns
# Cbc0038I Mini branch and bound improved solution from -1.21446e+08 to -1.21449e+08 (1.16 seconds)
# Cbc0038I Round again with cutoff of -1.2146e+08
# Cbc0038I Reduced cost fixing fixed 475 variables on major pass 3
# Cbc0038I Pass  31: (1.20 seconds) suminf.    1.20258 (13) obj. -1.2146e+08 iterations 107
# Cbc0038I Pass  32: (1.22 seconds) suminf.    1.20258 (13) obj. -1.2146e+08 iterations 19
# Cbc0038I Pass  33: (1.23 seconds) suminf.    6.83383 (28) obj. -1.2146e+08 iterations 283
# Cbc0038I Pass  34: (1.24 seconds) suminf.    3.92283 (22) obj. -1.2146e+08 iterations 241
# Cbc0038I Pass  35: (1.25 seconds) suminf.    3.92283 (22) obj. -1.2146e+08 iterations 4
# Cbc0038I Pass  36: (1.27 seconds) suminf.    6.57815 (24) obj. -1.2146e+08 iterations 278
# Cbc0038I Pass  37: (1.28 seconds) suminf.    4.57671 (22) obj. -1.2146e+08 iterations 76
# Cbc0038I Pass  38: (1.30 seconds) suminf.    6.79033 (28) obj. -1.2146e+08 iterations 319
# Cbc0038I Pass  39: (1.31 seconds) suminf.    5.67114 (24) obj. -1.2146e+08 iterations 245
# Cbc0038I Pass  40: (1.32 seconds) suminf.    5.28557 (23) obj. -1.2146e+08 iterations 25
# Cbc0038I Pass  41: (1.35 seconds) suminf.    6.14441 (24) obj. -1.2146e+08 iterations 268
# Cbc0038I Pass  42: (1.36 seconds) suminf.    4.88557 (22) obj. -1.2146e+08 iterations 73
# Cbc0038I Pass  43: (1.37 seconds) suminf.    5.25423 (23) obj. -1.2146e+08 iterations 213
# Cbc0038I Pass  44: (1.38 seconds) suminf.    5.25423 (23) obj. -1.2146e+08 iterations 193
# Cbc0038I Pass  45: (1.40 seconds) suminf.    6.17730 (23) obj. -1.2146e+08 iterations 4
# Cbc0038I Pass  46: (1.41 seconds) suminf.    7.08665 (25) obj. -1.2146e+08 iterations 210
# Cbc0038I Pass  47: (1.42 seconds) suminf.    5.56357 (23) obj. -1.2146e+08 iterations 202
# Cbc0038I Pass  48: (1.44 seconds) suminf.    6.32633 (24) obj. -1.2146e+08 iterations 329
# Cbc0038I Pass  49: (1.45 seconds) suminf.    5.14750 (22) obj. -1.2146e+08 iterations 64
# Cbc0038I Pass  50: (1.47 seconds) suminf.    4.60777 (22) obj. -1.2146e+08 iterations 22
# Cbc0038I Pass  51: (1.48 seconds) suminf.    6.29504 (24) obj. -1.2146e+08 iterations 265
# Cbc0038I Pass  52: (1.51 seconds) suminf.    7.10596 (27) obj. -1.2146e+08 iterations 306
# Cbc0038I Pass  53: (1.53 seconds) suminf.    4.15332 (22) obj. -1.2146e+08 iterations 248
# Cbc0038I Pass  54: (1.54 seconds) suminf.    4.15332 (22) obj. -1.2146e+08 iterations 4
# Cbc0038I Pass  55: (1.56 seconds) suminf.    6.49341 (24) obj. -1.2146e+08 iterations 252
# Cbc0038I Pass  56: (1.57 seconds) suminf.    4.76879 (22) obj. -1.2146e+08 iterations 59
# Cbc0038I Pass  57: (1.58 seconds) suminf.    6.31220 (26) obj. -1.2146e+08 iterations 250
# Cbc0038I Pass  58: (1.60 seconds) suminf.    3.68328 (22) obj. -1.2146e+08 iterations 201
# Cbc0038I Pass  59: (1.61 seconds) suminf.    3.68328 (22) obj. -1.2146e+08 iterations 1
# Cbc0038I Pass  60: (1.62 seconds) suminf.    4.14482 (22) obj. -1.2146e+08 iterations 24
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7125 integers at bound fixed and 5767 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 361 rows 255 columns
# Cbc0038I Mini branch and bound did not improve solution (1.65 seconds)
# Cbc0038I After 1.65 seconds - Feasibility pump exiting with objective of -1.21449e+08 - took 1.14 seconds
# Cbc0012I Integer solution of -1.2144884e+08 found by feasibility pump after 0 iterations and 0 nodes (1.66 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 293 rows 195 columns
# Cbc0012I Integer solution of -1.2145128e+08 found by DiveCoefficient after 29 iterations and 0 nodes (1.84 seconds)
# Cbc0031I 23 added rows had average density of 14.608696
# Cbc0013I At root node, 23 cuts changed objective from -1.2149864e+08 to -1.2145128e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 4822 column cuts (4822 active)  in 0.022 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 90 row cuts average 15.2 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 15 row cuts average 25.9 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 92 row cuts average 16.2 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -121451278.7660352, took 29 iterations and 0 nodes (1.85 seconds)
# Cbc0035I Maximum depth 0, 849 variables fixed on reduced cost
# Cuts at root node changed objective from -1.21499e+08 to -1.21451e+08
# Probing was tried 3 times and created 4822 cuts of which 0 were active after adding rounds of cuts (0.022 seconds)
# Gomory was tried 3 times and created 90 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 3 times and created 92 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
#
# Result - Optimal solution found
#
# Objective value:                121451278.76603515
# Enumerated nodes:               0
# Total iterations:               29
# Time (CPU seconds):             3.06
# Time (Wallclock seconds):       3.13
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.21   (Wallclock seconds):       3.30
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e8b08b17d88843cab794b0b5027ddaee-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/e8b08b17d88843cab794b0b5027ddaee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.30881e+08 - 0.05 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3264 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 107 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 49 integers unsatisfied sum - 17.55
# Cbc0038I Pass   1: (0.58 seconds) suminf.    1.20000 (4) obj. -1.20764e+08 iterations 1064
# Cbc0038I Pass   2: (0.59 seconds) suminf.    0.60000 (2) obj. -1.20765e+08 iterations 2
# Cbc0038I Solution found of -1.20765e+08
# Cbc0038I Relaxing continuous gives -1.20783e+08
# Cbc0038I Before mini branch and bound, 7217 integers at bound fixed and 5800 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 147 rows 133 columns
# Cbc0038I Mini branch and bound improved solution from -1.20783e+08 to -1.2097e+08 (0.64 seconds)
# Cbc0038I Round again with cutoff of -1.20971e+08
# Cbc0038I Reduced cost fixing fixed 825 variables on major pass 2
# Cbc0038I Pass   3: (0.82 seconds) suminf.    4.15753 (14) obj. -1.20971e+08 iterations 1253
# Cbc0038I Pass   4: (0.84 seconds) suminf.    3.67371 (12) obj. -1.20971e+08 iterations 283
# Cbc0038I Pass   5: (0.86 seconds) suminf.    5.70454 (13) obj. -1.20971e+08 iterations 262
# Cbc0038I Pass   6: (0.88 seconds) suminf.    4.66654 (12) obj. -1.20971e+08 iterations 211
# Cbc0038I Pass   7: (0.89 seconds) suminf.    4.34718 (10) obj. -1.20971e+08 iterations 91
# Cbc0038I Pass   8: (0.91 seconds) suminf.    2.60153 (9) obj. -1.20971e+08 iterations 63
# Cbc0038I Pass   9: (0.93 seconds) suminf.    0.96677 (10) obj. -1.20971e+08 iterations 322
# Cbc0038I Pass  10: (0.94 seconds) suminf.    0.75292 (14) obj. -1.20971e+08 iterations 55
# Cbc0038I Pass  11: (0.96 seconds) suminf.    4.35929 (15) obj. -1.20971e+08 iterations 230
# Cbc0038I Pass  12: (0.98 seconds) suminf.    0.96677 (10) obj. -1.20971e+08 iterations 156
# Cbc0038I Pass  13: (0.99 seconds) suminf.    0.75292 (14) obj. -1.20971e+08 iterations 188
# Cbc0038I Pass  14: (1.01 seconds) suminf.    1.38387 (12) obj. -1.20971e+08 iterations 313
# Cbc0038I Pass  15: (1.02 seconds) suminf.    1.05292 (15) obj. -1.20971e+08 iterations 349
# Cbc0038I Pass  16: (1.04 seconds) suminf.    1.05292 (15) obj. -1.20971e+08 iterations 340
# Cbc0038I Pass  17: (1.06 seconds) suminf.    1.30390 (15) obj. -1.20971e+08 iterations 365
# Cbc0038I Pass  18: (1.07 seconds) suminf.    1.95292 (18) obj. -1.20971e+08 iterations 374
# Cbc0038I Pass  19: (1.09 seconds) suminf.    2.53679 (19) obj. -1.20971e+08 iterations 322
# Cbc0038I Pass  20: (1.10 seconds) suminf.    1.63679 (16) obj. -1.20971e+08 iterations 314
# Cbc0038I Pass  21: (1.11 seconds) suminf.    0.75292 (14) obj. -1.20971e+08 iterations 179
# Cbc0038I Pass  22: (1.13 seconds) suminf.    4.35929 (15) obj. -1.20971e+08 iterations 209
# Cbc0038I Pass  23: (1.15 seconds) suminf.    0.96677 (10) obj. -1.20971e+08 iterations 121
# Cbc0038I Pass  24: (1.17 seconds) suminf.    1.22383 (14) obj. -1.20971e+08 iterations 224
# Cbc0038I Pass  25: (1.18 seconds) suminf.    1.35292 (16) obj. -1.20971e+08 iterations 433
# Cbc0038I Pass  26: (1.20 seconds) suminf.    1.05292 (15) obj. -1.20971e+08 iterations 382
# Cbc0038I Pass  27: (1.22 seconds) suminf.    1.26677 (11) obj. -1.20971e+08 iterations 408
# Cbc0038I Pass  28: (1.23 seconds) suminf.    1.61155 (12) obj. -1.20971e+08 iterations 371
# Cbc0038I Pass  29: (1.25 seconds) suminf.    3.46318 (12) obj. -1.20971e+08 iterations 395
# Cbc0038I Pass  30: (1.27 seconds) suminf.    1.19995 (10) obj. -1.20971e+08 iterations 261
# Cbc0038I Pass  31: (1.29 seconds) suminf.    0.93452 (14) obj. -1.20971e+08 iterations 45
# Cbc0038I Pass  32: (1.32 seconds) suminf.    4.38691 (15) obj. -1.20971e+08 iterations 238
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7205 integers at bound fixed and 5795 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 179 rows 154 columns
# Cbc0038I Mini branch and bound did not improve solution (1.35 seconds)
# Cbc0038I After 1.35 seconds - Feasibility pump exiting with objective of -1.2097e+08 - took 0.80 seconds
# Cbc0012I Integer solution of -1.2097049e+08 found by feasibility pump after 0 iterations and 0 nodes (1.36 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 143 rows 130 columns
# Cbc0031I 40 added rows had average density of 9.075
# Cbc0013I At root node, 63 cuts changed objective from -1.2097406e+08 to -1.2097049e+08 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 5066 column cuts (5066 active)  in 0.016 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 50 row cuts average 10.2 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 34 row cuts average 10.1 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 57 row cuts average 11.1 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -120970492.7536216, took 45 iterations and 0 nodes (1.48 seconds)
# Cbc0035I Maximum depth 0, 933 variables fixed on reduced cost
# Cuts at root node changed objective from -1.20974e+08 to -1.2097e+08
# Probing was tried 2 times and created 5067 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# Gomory was tried 2 times and created 50 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 34 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 2 times and created 57 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
#
# Result - Optimal solution found
#
# Objective value:                120970492.75362162
# Enumerated nodes:               0
# Total iterations:               45
# Time (CPU seconds):             2.74
# Time (Wallclock seconds):       2.80
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.88   (Wallclock seconds):       2.96

# %%
# 修正后的代码
df = pd.concat(dfs)

# 计算平均值时需要指定哪些列进行聚合
df = df.groupby(["Field", "Crop", "Season", "Year"]).agg("mean").reset_index()
df = df[~((df["Season"] == 2) & (df["Field"] < 27))]  # 去掉单季地块第二季度的数据

# 获取不包括 2023 年的唯一年份
years = df["Year"].unique()
years = [year for year in years if year != 2023]


# 创建一个 Excel writer 对象
with pd.ExcelWriter(f"test-{times}.xlsx") as writer:
    for year in years:
        # 过滤特定年份的数据
        df_year = df[df["Year"] == year]

        # 透视表，Field 作为行，Crop 作为列
        pivot_table = df_year.pivot_table(
            index=["Season", "Field"], columns="Crop", values="Planting", aggfunc="sum"
        ).round(
            1
        )  # 保留一位小数

        # 将透视表写入 Excel 的 sheet
        pivot_table.to_excel(writer, sheet_name=str(year))

print(f"Exported to test-{times}.xlsx")
# Out:
# Exported to test-5.xlsx
