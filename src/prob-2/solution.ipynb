# %%
import pandas as pd
import numpy as np
import datetime
from planning import planning

stats_2023 = pd.read_csv("../../data/preprocess/pre-processed.csv")
stats_2023.dtypes
# Out:
# Field ID           int64
# Field Name        object
# Crop ID            int64
# Crop Name         object
# Crop Type         object
# Planting Area    float64
# Season ID          int64
# Season            object
# Field Type        object
# Field Area       float64
# Per Yield        float64
# Per Cost         float64
# Per Price        float64
# Yield            float64
# Cost             float64
# Selling          float64
# Revenue          float64
# Profit           float64
# dtype: object

# %%
fields_id = list(map(int, stats_2023["Field ID"].unique()))  # 所有的地块
crops_id = list(map(int, stats_2023["Crop ID"].unique()))  # 所有的作物
seasons_id = list(map(int, stats_2023["Season ID"].unique()))  # 所有的时节
fields_id.sort()
crops_id.sort()
seasons_id.sort()
years = range(2023, 2031)  # 要优化的年份

def pop_ndarray(arr, element_to_pop):
    index = np.where(arr == element_to_pop)[0]
    if index.size > 0:
        arr = np.delete(arr, index)
    return arr

# A类粮食作物的集合
grains_A = stats_2023[
    (stats_2023["Crop Type"] == "粮食")
    | (stats_2023["Crop Type"] == "粮食（豆类）")
]["Crop ID"].unique()
grains_A = pop_ndarray(grains_A, 16)
grains_A.sort()

# B类粮食作物的集合
grains_B = np.array([16])

# A类蔬菜作物的集合
vege_A = stats_2023[
    (stats_2023["Crop Type"] == "蔬菜")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
for i in range(3):
    vege_A = pop_ndarray(vege_A, 35 + i)
vege_A.sort()

# B类蔬菜作物的集合
vege_B = np.array([35, 36, 37])

# 食用菌作物的集合
mush = stats_2023[stats_2023["Crop Type"] == "食用菌"]["Crop ID"].unique()
mush.sort()

# 豆类作物的集合
beans = stats_2023[
    (stats_2023["Crop Type"] == "粮食（豆类）")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
beans.sort()

# 第 i 个地块的类型（如平旱地、梯田、山坡地、智能大棚、普通大棚、水浇地）
t_i = {
    i: stats_2023[stats_2023["Field ID"] == i]["Field Type"].values[0]
    for i in fields_id
}

# 第 i 个地块在第 s 季可种植的作物集合
T_hat_i_s: dict[tuple : np.ndarray] = {}


for i in fields_id:
    if t_i[i] in ["平旱地", "梯田", "山坡地"]:
        T_hat_i_s[(i, 1)] = grains_A
        T_hat_i_s[(i, 2)] = np.array([])
    elif t_i[i] in ["水浇地"]:
        T_hat_i_s[(i, 1)] = np.concatenate([grains_B, vege_A])
        T_hat_i_s[(i, 2)] = vege_B
    elif t_i[i] in ["普通大棚"]:
        T_hat_i_s[(i, 1)] = vege_A
        T_hat_i_s[(i, 2)] = mush
    elif t_i[i] in ["智慧大棚"]:
        T_hat_i_s[(i, 1)] = vege_A
        T_hat_i_s[(i, 2)] = vege_A

# %%
dfs = []

for i in range(5):
    # 使用当前时间作为随机数种子
    np.random.seed(datetime.datetime.now().second)

    S = {}  # 期望产量
    Y = {}  # 单位面积产量
    P = {}  # 售价
    C = {}  # 单位面积成本

    for j in crops_id:
        # 所有参数与 2023 年的保持一致
        S[j, 2023] = stats_2023.groupby(["Crop ID"])["Selling"].agg("sum").values[j - 1]
        Y[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Yield"].values[0]
        P[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
        C[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Cost"].values[0]

    for j in crops_id:
        # 小麦和玉米的预期销售量有平均5%-10%的年增长
        for k in years:
            if j in [6, 7]:
                increment = np.random.uniform(0.05, 0.1)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 其他作物的预期销售量变化约±5%。
            else:
                increment = np.random.uniform(-0.05, 0.05)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 农作物亩产量可能有±10%的变化.
            increment = np.random.uniform(-0.1, 0.1)
            Y[j, k + 1] = Y[j, k] * np.random.normal(1 + increment, 0.01)

            # 种植成本每年增长约5%。
            increment = 0.05
            C[j, k + 1] = C[j, k] * np.random.normal(1 + increment, 0.01)

            # 蔬菜类作物价格每年增长约5%。
            if j in vege_A or j in vege_B:
                increment = 0.05
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 食用菌价格每年下降1%-5%。
            if j in mush:
                increment = np.random.uniform(-0.05, -0.01)
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 羊肚菌的销售价格每年下降幅5%
            if j == 41:
                increment = -0.05
                P[j, k + 1] = P[j, k] * (1 + increment)
            else:
                P[j, k + 1] = P[j, k]
                
    dfs.append(
        planning(
            fields_id,
            crops_id,
            seasons_id,
            years,
            t_i,
            T_hat_i_s,
            grains_A,
            grains_B,
            vege_A,
            vege_B,
            mush,
            beans,
            stats_2023,
            S,
            Y,
            P,
            C,
        )
    )
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3eae01096d024b91820a368cc271bf4e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/3eae01096d024b91820a368cc271bf4e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 418368 RHS
# At line 516171 BOUNDS
# At line 556024 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.09015e+08 - 0.10 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 6577 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2382 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1985 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1142 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 753 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 157 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0004I processed model has 22017 rows, 16955 columns (7334 integer (7334 of which binary)) and 63190 elements
# Cbc0038I Initial state - 963 integers unsatisfied sum - 191.383
# Cbc0038I Pass   1: (1.18 seconds) suminf.    9.20000 (23) obj. -8.71464e+07 iterations 3933
# Cbc0038I Pass   2: (1.19 seconds) suminf.    6.40000 (16) obj. -8.71128e+07 iterations 20
# Cbc0038I Pass   3: (1.20 seconds) suminf.    6.40000 (16) obj. -8.71128e+07 iterations 2
# Cbc0038I Pass   4: (1.22 seconds) suminf.    0.80000 (2) obj. -8.6774e+07 iterations 133
# Cbc0038I Pass   5: (1.22 seconds) suminf.    0.80000 (2) obj. -8.6774e+07 iterations 0
# Cbc0038I Solution found of -8.6777e+07
# Cbc0038I Relaxing continuous gives -8.76241e+07
# Cbc0038I Before mini branch and bound, 6355 integers at bound fixed and 8409 continuous
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1717 rows 1088 columns
# Cbc0038I Mini branch and bound improved solution from -8.76241e+07 to -9.43278e+07 (1.81 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -9.47831e+07
# Cbc0038I Round again with cutoff of -9.54512e+07
# Cbc0038I Pass   6: (2.35 seconds) suminf.   37.22706 (164) obj. -9.54512e+07 iterations 2188
# Cbc0038I Pass   7: (2.38 seconds) suminf.   31.55784 (146) obj. -9.54512e+07 iterations 222
# Cbc0038I Pass   8: (2.39 seconds) suminf.   31.21060 (143) obj. -9.54512e+07 iterations 10
# Cbc0038I Pass   9: (2.43 seconds) suminf.   22.93391 (105) obj. -9.54512e+07 iterations 249
# Cbc0038I Pass  10: (2.45 seconds) suminf.   22.33373 (104) obj. -9.54512e+07 iterations 21
# Cbc0038I Pass  11: (2.47 seconds) suminf.   17.29170 (86) obj. -9.54512e+07 iterations 113
# Cbc0038I Pass  12: (2.49 seconds) suminf.   17.20272 (88) obj. -9.54512e+07 iterations 24
# Cbc0038I Pass  13: (2.55 seconds) suminf.    9.37924 (49) obj. -9.54512e+07 iterations 508
# Cbc0038I Pass  14: (2.57 seconds) suminf.    9.27223 (53) obj. -9.54512e+07 iterations 34
# Cbc0038I Pass  15: (2.60 seconds) suminf.    8.44531 (50) obj. -9.54512e+07 iterations 170
# Cbc0038I Pass  16: (2.62 seconds) suminf.    7.98237 (48) obj. -9.54512e+07 iterations 25
# Cbc0038I Pass  17: (2.66 seconds) suminf.    4.96899 (29) obj. -9.54512e+07 iterations 208
# Cbc0038I Pass  18: (2.68 seconds) suminf.    4.12102 (26) obj. -9.54512e+07 iterations 23
# Cbc0038I Pass  19: (2.74 seconds) suminf.   10.17127 (27) obj. -9.54512e+07 iterations 551
# Cbc0038I Pass  20: (2.78 seconds) suminf.    7.30534 (26) obj. -9.54512e+07 iterations 204
# Cbc0038I Pass  21: (2.82 seconds) suminf.    6.95156 (26) obj. -9.54512e+07 iterations 315
# Cbc0038I Pass  22: (2.86 seconds) suminf.    4.20825 (25) obj. -9.54512e+07 iterations 183
# Cbc0038I Pass  23: (2.88 seconds) suminf.    3.37932 (25) obj. -9.54512e+07 iterations 13
# Cbc0038I Pass  24: (2.94 seconds) suminf.    4.33457 (27) obj. -9.54512e+07 iterations 365
# Cbc0038I Pass  25: (2.95 seconds) suminf.    3.63842 (26) obj. -9.54512e+07 iterations 29
# Cbc0038I Pass  26: (2.97 seconds) suminf.    2.79493 (23) obj. -9.54512e+07 iterations 5
# Cbc0038I Pass  27: (3.04 seconds) suminf.    5.54145 (26) obj. -9.54512e+07 iterations 493
# Cbc0038I Pass  28: (3.05 seconds) suminf.    4.67352 (26) obj. -9.54512e+07 iterations 19
# Cbc0038I Pass  29: (3.13 seconds) suminf.    3.82448 (17) obj. -9.54512e+07 iterations 518
# Cbc0038I Pass  30: (3.15 seconds) suminf.    2.28649 (16) obj. -9.54512e+07 iterations 106
# Cbc0038I Pass  31: (3.19 seconds) suminf.    2.97405 (23) obj. -9.54512e+07 iterations 249
# Cbc0038I Pass  32: (3.21 seconds) suminf.    2.25809 (13) obj. -9.54512e+07 iterations 152
# Cbc0038I Pass  33: (3.27 seconds) suminf.    5.38479 (18) obj. -9.54512e+07 iterations 457
# Cbc0038I Pass  34: (3.28 seconds) suminf.    4.64995 (17) obj. -9.54512e+07 iterations 66
# Cbc0038I Pass  35: (3.32 seconds) suminf.    4.00152 (17) obj. -9.54512e+07 iterations 253
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6347 integers at bound fixed and 8308 continuous
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1981 rows 1313 columns
# Cbc0038I Mini branch and bound improved solution from -9.47831e+07 to -9.69611e+07 (3.89 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -9.70229e+07
# Cbc0038I Round again with cutoff of -9.79111e+07
# Cbc0038I Pass  35: (4.08 seconds) suminf.   52.72220 (232) obj. -9.79111e+07 iterations 366
# Cbc0038I Pass  36: (4.10 seconds) suminf.   46.81259 (215) obj. -9.79111e+07 iterations 183
# Cbc0038I Pass  37: (4.12 seconds) suminf.   45.91198 (212) obj. -9.79111e+07 iterations 12
# Cbc0038I Pass  38: (4.16 seconds) suminf.   35.21194 (177) obj. -9.79111e+07 iterations 327
# Cbc0038I Pass  39: (4.18 seconds) suminf.   34.49793 (175) obj. -9.79111e+07 iterations 32
# Cbc0038I Pass  40: (4.22 seconds) suminf.   25.76111 (148) obj. -9.79111e+07 iterations 327
# Cbc0038I Pass  41: (4.23 seconds) suminf.   25.76111 (148) obj. -9.79111e+07 iterations 0
# Cbc0038I Pass  42: (4.26 seconds) suminf.   24.35724 (141) obj. -9.79111e+07 iterations 257
# Cbc0038I Pass  43: (4.27 seconds) suminf.   24.35724 (141) obj. -9.79111e+07 iterations 0
# Cbc0038I Pass  44: (4.30 seconds) suminf.   20.79107 (124) obj. -9.79111e+07 iterations 218
# Cbc0038I Pass  45: (4.35 seconds) suminf.   21.31892 (124) obj. -9.79111e+07 iterations 334
# Cbc0038I Pass  46: (4.37 seconds) suminf.   19.33057 (120) obj. -9.79111e+07 iterations 48
# Cbc0038I Pass  47: (4.40 seconds) suminf.   15.47042 (104) obj. -9.79111e+07 iterations 182
# Cbc0038I Pass  48: (4.43 seconds) suminf.   14.72705 (104) obj. -9.79111e+07 iterations 112
# Cbc0038I Pass  49: (4.44 seconds) suminf.   13.96232 (101) obj. -9.79111e+07 iterations 13
# Cbc0038I Pass  50: (4.47 seconds) suminf.   13.75744 (100) obj. -9.79111e+07 iterations 190
# Cbc0038I Pass  51: (4.50 seconds) suminf.   12.01815 (94) obj. -9.79111e+07 iterations 128
# Cbc0038I Pass  52: (4.53 seconds) suminf.   12.40609 (103) obj. -9.79111e+07 iterations 188
# Cbc0038I Pass  53: (4.59 seconds) suminf.   13.40532 (111) obj. -9.79111e+07 iterations 452
# Cbc0038I Pass  54: (4.61 seconds) suminf.   11.50960 (110) obj. -9.79111e+07 iterations 50
# Cbc0038I Pass  55: (4.62 seconds) suminf.   11.40464 (107) obj. -9.79111e+07 iterations 7
# Cbc0038I Pass  56: (4.67 seconds) suminf.    9.37380 (99) obj. -9.79111e+07 iterations 406
# Cbc0038I Pass  57: (4.71 seconds) suminf.   10.32110 (104) obj. -9.79111e+07 iterations 278
# Cbc0038I Pass  58: (4.72 seconds) suminf.   10.02726 (103) obj. -9.79111e+07 iterations 21
# Cbc0038I Pass  59: (4.77 seconds) suminf.   12.49856 (104) obj. -9.79111e+07 iterations 288
# Cbc0038I Pass  60: (4.78 seconds) suminf.    9.94226 (104) obj. -9.79111e+07 iterations 66
# Cbc0038I Pass  61: (4.82 seconds) suminf.   10.06265 (103) obj. -9.79111e+07 iterations 224
# Cbc0038I Pass  62: (4.85 seconds) suminf.   11.37585 (100) obj. -9.79111e+07 iterations 259
# Cbc0038I Pass  63: (4.87 seconds) suminf.    9.94180 (100) obj. -9.79111e+07 iterations 58
# Cbc0038I Pass  64: (4.90 seconds) suminf.    9.57331 (100) obj. -9.79111e+07 iterations 102
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6319 integers at bound fixed and 8292 continuous
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2014 rows 1337 columns
# Cbc0038I Mini branch and bound did not improve solution (5.36 seconds)
# Cbc0038I After 5.36 seconds - Feasibility pump exiting with objective of -9.70229e+07 - took 4.26 seconds
# Cbc0012I Integer solution of -97022871 found by feasibility pump after 0 iterations and 0 nodes (5.41 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 3806 rows 3052 columns
# Cbc0031I 1233 added rows had average density of 21.290349
# Cbc0013I At root node, 1233 cuts changed objective from -1.0146396e+08 to -98524096 in 50 passes
# Cbc0014I Cut generator 0 (Probing) - 601 row cuts average 2.0 elements, 0 column cuts (843 active)  in 8.775 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 5925 row cuts average 98.1 elements, 0 column cuts (0 active)  in 3.077 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 70 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.275 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.046 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1716 row cuts average 15.2 elements, 0 column cuts (0 active)  in 0.313 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 2 row cuts average 9.5 elements, 0 column cuts (0 active)  in 0.205 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3640 row cuts average 50.9 elements, 0 column cuts (0 active)  in 1.054 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -97022871 best solution, best possible -98524096 (23.71 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2661 rows 2132 columns
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2555 rows 2061 columns
# Cbc0010I After 100 nodes, 56 on tree, -97022871 best solution, best possible -98524096 (61.11 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2404 rows 1966 columns
# Cbc0010I After 200 nodes, 106 on tree, -97022871 best solution, best possible -98524096 (71.99 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2298 rows 1891 columns
# Cbc0010I After 300 nodes, 156 on tree, -97022871 best solution, best possible -98524096 (81.56 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2133 rows 1777 columns
# Cbc0010I After 400 nodes, 211 on tree, -97022871 best solution, best possible -98524096 (90.15 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1924 rows 1628 columns
# Cbc0010I After 500 nodes, 266 on tree, -97022871 best solution, best possible -98524096 (94.93 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1674 rows 1459 columns
# Cbc0010I After 600 nodes, 324 on tree, -97022871 best solution, best possible -98524096 (100.15 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1551 rows 1371 columns
# Cbc0010I After 700 nodes, 381 on tree, -97022871 best solution, best possible -98524096 (103.56 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1422 rows 1277 columns
# Cbc0010I After 800 nodes, 443 on tree, -97022871 best solution, best possible -98524096 (107.53 seconds)
# Cbc0012I Integer solution of -97869399 found by rounding after 47776 iterations and 817 nodes (108.04 seconds)
# Cbc0004I Integer solution of -97890643 found after 47779 iterations and 818 nodes (108.12 seconds)
# Cbc0010I After 900 nodes, 459 on tree, -97890643 best solution, best possible -98524096 (111.62 seconds)
# Cbc0004I Integer solution of -97898815 found after 49229 iterations and 909 nodes (111.85 seconds)
# Cbc0010I After 1000 nodes, 459 on tree, -97898815 best solution, best possible -98524096 (117.13 seconds)
# Cbc0010I After 1100 nodes, 556 on tree, -97898815 best solution, best possible -98524096 (124.73 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1212 rows 1150 columns
# Cbc0010I After 1200 nodes, 656 on tree, -97898815 best solution, best possible -98524096 (128.49 seconds)
# Cbc0010I After 1300 nodes, 756 on tree, -97898815 best solution, best possible -98524096 (131.70 seconds)
# Cbc0004I Integer solution of -98137158 found after 57310 iterations and 1393 nodes (133.98 seconds)
# Cbc0010I After 1400 nodes, 585 on tree, -98137158 best solution, best possible -98524096 (134.10 seconds)
# Cbc0010I After 1500 nodes, 509 on tree, -98137158 best solution, best possible -98524096 (140.19 seconds)
# Cbc0010I After 1600 nodes, 485 on tree, -98137158 best solution, best possible -98524096 (144.86 seconds)
# Cbc0010I After 1700 nodes, 491 on tree, -98137158 best solution, best possible -98524096 (150.58 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 844 rows 867 columns
# Cbc0010I After 1800 nodes, 540 on tree, -98137158 best solution, best possible -98524096 (156.80 seconds)
# Cbc0010I After 1900 nodes, 581 on tree, -98137158 best solution, best possible -98524096 (161.99 seconds)
# Cbc0010I After 2000 nodes, 629 on tree, -98137158 best solution, best possible -98524096 (167.20 seconds)
# Cbc0010I After 2100 nodes, 678 on tree, -98137158 best solution, best possible -98524096 (173.14 seconds)
# Cbc0010I After 2200 nodes, 725 on tree, -98137158 best solution, best possible -98524096 (178.26 seconds)
# Cbc0010I After 2300 nodes, 776 on tree, -98137158 best solution, best possible -98524096 (182.52 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 733 rows 787 columns
# Cbc0010I After 2400 nodes, 824 on tree, -98137158 best solution, best possible -98524096 (187.67 seconds)
# Cbc0010I After 2500 nodes, 872 on tree, -98137158 best solution, best possible -98524096 (193.52 seconds)
# Cbc0010I After 2600 nodes, 913 on tree, -98137158 best solution, best possible -98524096 (199.38 seconds)
# Cbc0010I After 2700 nodes, 961 on tree, -98137158 best solution, best possible -98524096 (204.57 seconds)
# Cbc0010I After 2800 nodes, 1012 on tree, -98137158 best solution, best possible -98524096 (209.88 seconds)
# Cbc0010I After 2900 nodes, 1064 on tree, -98137158 best solution, best possible -98524096 (222.86 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2119 rows 1744 columns
# Cbc0010I After 3000 nodes, 1112 on tree, -98137158 best solution, best possible -98524096 (231.57 seconds)
# Cbc0010I After 3100 nodes, 1161 on tree, -98137158 best solution, best possible -98524096 (240.75 seconds)
# Cbc0010I After 3200 nodes, 1213 on tree, -98137158 best solution, best possible -98524096 (250.13 seconds)
# Cbc0010I After 3300 nodes, 1261 on tree, -98137158 best solution, best possible -98524096 (259.73 seconds)
# Cbc0010I After 3400 nodes, 1314 on tree, -98137158 best solution, best possible -98524096 (264.79 seconds)
# Cbc0010I After 3500 nodes, 1364 on tree, -98137158 best solution, best possible -98524096 (268.85 seconds)
# Cbc0010I After 3600 nodes, 1411 on tree, -98137158 best solution, best possible -98524096 (271.82 seconds)
# Cbc0004I Integer solution of -98150247 found after 119005 iterations and 3606 nodes (272.06 seconds)
# Cbc0010I After 3700 nodes, 1309 on tree, -98150247 best solution, best possible -98524096 (274.48 seconds)
# Cbc0004I Integer solution of -98159447 found after 119899 iterations and 3715 nodes (274.82 seconds)
# Cbc0010I After 3800 nodes, 1168 on tree, -98159447 best solution, best possible -98524096 (283.14 seconds)
# Cbc0010I After 3900 nodes, 1216 on tree, -98159447 best solution, best possible -98524096 (294.08 seconds)
# Cbc0010I After 4000 nodes, 1267 on tree, -98159447 best solution, best possible -98524096 (303.35 seconds)
# Cbc0010I After 4100 nodes, 1316 on tree, -98159447 best solution, best possible -98524096 (314.12 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2211 rows 1811 columns
# Cbc0010I After 4200 nodes, 1365 on tree, -98159447 best solution, best possible -98524096 (325.95 seconds)
# Cbc0010I After 4300 nodes, 1416 on tree, -98159447 best solution, best possible -98524096 (333.17 seconds)
# Cbc0010I After 4400 112430 (143.11 seconds)
# Cbc0012I Integer solution of -95803627 found by rounding after 50340 iterations and 1618 nodes (143.64 seconds)
# Cbc0004I Integer solution of -95803743 found after 50576 iterations and 1637 nodes (144.42 seconds)
# Cbc0010I After 1700 nodes, 410 on tree, -95803743 best solution, best possible -96112430 (151.28 seconds)
# Cbc0038I Full problem 21967 rows 16918 columns, reduced to 2042 rows 1703 columns
# Cbc0010I After 1800 nodes, 461 on tree, -95803743 best solution, best possible -96112430 (166.50 seconds)
# Cbc0010I After 1900 nodes, 510 on tree, -95803743 best solution, best possible -96112430 (177.60 seconds)
# Cbc0010I After 2000 nodes, 560 on tree, -95803743 best solution, best possible -96112430 (192.66 seconds)
# Cbc0010I After 2100 nodes, 609 on tree, -95803743 best solution, best possible -96112430 (208.71 seconds)
# Cbc0010I After 2200 nodes, 660 on tree, -95803743 best solution, best possible -96112430 (220.35 seconds)
# Cbc0010I After 2300 nodes, 709 on tree, -95803743 best solution, best possible -96112430 (231.90 seconds)
# Cbc0038I Full problem 21967 rows 16918 columns, reduced to 1888 rows 1601 columns
# Cbc0010I After 2400 nodes, 760 on tree, -95803743 best solution, best possible -96112430 (246.79 seconds)
# Cbc0010I After 2500 nodes, 809 on tree, -95803743 best solution, best possible -96112430 (259.96 seconds)
# Cbc0010I After 2600 nodes, 860 on tree, -95803743 best solution, best possible -96112430 (282.39 seconds)
# Cbc0010I After 2700 nodes, 910 on tree, -95803743 best solution, best possible -96112430 (295.31 seconds)
# Cbc0010I After 2800 nodes, 959 on tree, -95803743 best solution, best possible -96112430 (313.65 seconds)
# Cbc0010I After 2900 nodes, 1010 on tree, -95803743 best solution, best possible -96112430 (329.00 seconds)
# Cbc0038I Full problem 21967 rows 16918 columns, reduced to 2009 rows 1689 columns
# Cbc0010I After 3000 nodes, 1059 on tree, -95803743 best solution, best possible -96112430 (342.43 seconds)
# Cbc0010I After 3100 nodes, 1109 on tree, -95803743 best solution, best possible -96112430 (352.67 seconds)
# Cbc0010I After 3200 nodes, 1160 on tree, -95803743 best solution, best possible -96112430 (367.45 seconds)
# Cbc0010I After 3300 nodes, 1210 on tree, -95803743 best solution, best possible -96112430 (380.07 seconds)
# Cbc0010I After 3400 nodes, 1256 on tree, -95803743 best solution, best possible -96112430 (389.52 seconds)
# Cbc0010I After 3500 nodes, 1304 on tree, -95803743 best solution, best possible -96112430 (400.66 seconds)
# Cbc0038I Full problem 21967 rows 16918 columns, reduced to 2252 rows 1840 columns
# Cbc0010I After 3600 nodes, 1354 on tree, -95803743 best solution, best possible -96112430 (410.10 seconds)
# Cbc0010I After 3700 nodes, 1404 on tree, -95803743 best solution, best possible -96112430 (426.55 seconds)
# Cbc0010I After 3800 nodes, 1453 on tree, -95803743 best solution, best possible -96112430 (440.09 seconds)
# Cbc0010I After 3900 nodes, 1499 on tree, -95803743 best solution, best possible -96112430 (452.82 seconds)
# Cbc0010I After 4000 nodes, 1548 on tree, -95803743 best solution, best possible -96112430 (465.58 seconds)
# Cbc0010I After 4100 nodes, 1599 on tree, -95803743 best solution, best possible -96112430 (482.99 seconds)
# Cbc0038I Full problem 21967 rows 16918 columns, reduced to 2082 rows 1725 columns
# Cbc0010I After 4200 nodes, 1649 on tree, -95803743 best solution, best possible -96112430 (497.21 seconds)
# Cbc0010I After 4300 nodes, 1698 on tree, -95803743 best solution, best possible -96112430 (509.41 seconds)
# Cbc0010I After 4400 nodes, 1745 on tree, -95803743 best solution, best possible -96112430 (525.00 seconds)
# Cbc0010I After 4500 nodes, 1794 on tree, -95803743 best solution, best possible -96112430 (538.84 seconds)
# Cbc0010I After 4600 nodes, 1844 on tree, -95803743 best solution, best possible -96112430 (548.08 seconds)
# Cbc0010I After 4700 nodes, 1893 on tree, -95803743 best solution, best possible -96112430 (559.42 seconds)
# Cbc0038I Full problem 21967 rows 16918 columns, reduced to 2025 rows 1695 columns
# Cbc0010I After 4800 nodes, 1943 on tree, -95803743 best solutionodes, 1465 on tree, -98159447 best solution, best possible -98524096 (345.76 seconds)
# Cbc0010I After 4500 nodes, 1515 on tree, -98159447 best solution, best possible -98524096 (353.14 seconds)
# Cbc0010I After 4600 nodes, 1564 on tree, -98159447 best solution, best possible -98524096 (363.36 seconds)
# Cbc0010I After 4700 nodes, 1613 on tree, -98159447 best solution, best possible -98524096 (375.77 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 2090 rows 1723 columns
# Cbc0010I After 4800 nodes, 1663 on tree, -98159447 best solution, best possible -98524096 (387.89 seconds)
# Cbc0010I After 4900 nodes, 1712 on tree, -98159447 best solution, best possible -98524096 (399.07 seconds)
# Cbc0010I After 5000 nodes, 1761 on tree, -98159447 best solution, best possible -98524096 (408.49 seconds)
# Cbc0010I After 5100 nodes, 1861 on tree, -98159447 best solution, best possible -98524096 (415.58 seconds)
# Cbc0010I After 5200 nodes, 1862 on tree, -98159447 best solution, best possible -98524096 (420.40 seconds)
# Cbc0010I After 5300 nodes, 1868 on tree, -98159447 best solution, best possible -98524096 (425.10 seconds)
# Cbc0010I After 5400 nodes, 1862 on tree, -98159447 best solution, best possible -98524096 (430.21 seconds)
# Cbc0010I After 5500 nodes, 1862 on tree, -98159447 best solution, best possible -98524096 (434.19 seconds)
# Cbc0010I After 5600 nodes, 1856 on tree, -98159447 best solution, best possible -98524096 (440.47 seconds)
# Cbc0010I After 5700 nodes, 1864 on tree, -98159447 best solution, best possible -98524096 (446.29 seconds)
# Cbc0010I After 5800 nodes, 1857 on tree, -98159447 best solution, best possible -98524096 (452.13 seconds)
# Cbc0010I After 5900 nodes, 1863 on tree, -98159447 best solution, best possible -98524096 (457.18 seconds)
# Cbc0010I After 6000 nodes, 1852 on tree, -98159447 best solution, best possible -98524096 (462.73 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1523 rows 1343 columns
# Cbc0010I After 6100 nodes, 1853 on tree, -98159447 best solution, best possible -98524096 (467.65 seconds)
# Cbc0010I After 6200 nodes, 1860 on tree, -98159447 best solution, best possible -98524096 (476.67 seconds)
# Cbc0010I After 6300 nodes, 1851 on tree, -98159447 best solution, best possible -98524096 (485.57 seconds)
# Cbc0010I After 6400 nodes, 1849 on tree, -98159447 best solution, best possible -98524096 (495.18 seconds)
# Cbc0010I After 6500 nodes, 1853 on tree, -98159447 best solution, best possible -98524096 (503.12 seconds)
# Cbc0010I After 6600 nodes, 1852 on tree, -98159447 best solution, best possible -98524096 (509.51 seconds)
# Cbc0010I After 6700 nodes, 1853 on tree, -98159447 best solution, best possible -98524096 (517.24 seconds)
# Cbc0010I After 6800 nodes, 1848 on tree, -98159447 best solution, best possible -98524096 (525.15 seconds)
# Cbc0010I After 6900 nodes, 1851 on tree, -98159447 best solution, best possible -98524096 (532.72 seconds)
# Cbc0010I After 7000 nodes, 1844 on tree, -98159447 best solution, best possible -98524096 (540.04 seconds)
# Cbc0010I After 7100 nodes, 1844 on tree, -98159447 best solution, best possible -98524096 (546.26 seconds)
# Cbc0010I After 7200 nodes, 1844 on tree, -98159447 best solution, best possible -98524096 (555.27 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1471 rows 1302 columns
# Cbc0010I After 7300 nodes, 1840 on tree, -98159447 best solution, best possible -98524096 (563.96 seconds)
# Cbc0010I After 7400 nodes, 1839 on tree, -98159447 best solution, best possible -98524096 (571.03 seconds)
# Cbc0010I After 7500 nodes, 1848 on tree, -98159447 best solution, best possible -98524096 (579.26 seconds)
# Cbc0010I After 7600 nodes, 1847 on tree, -98159447 best solution, best possible -98524096 (586.87 seconds)
# Cbc0010I After 7700 nodes, 1850 on tree, -98159447 best solution, best possible -98524096 (594.77 seconds)
# Cbc0038I Full problem 22017 rows 16955 columns, reduced to 1561 rows 1372 columns
# Cbc0010I After 7800 nodes, 1847 on tree, -98159447 best solution, best possible -98524096 (602.48 seconds)
# Cbc0010I After 7900 nodes, 1844 on tree, -9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 61
#      57         else:
#      58             P[j, k + 1] = P[j, k]
#      60 dfs.append(
# ---> 61     planning(
#      62         fields_id,
#      63         crops_id,
#      64         seasons_id,
#      65         years,
#      66         t_i,
#      67         T_hat_i_s,
#      68         grains_A,
#      69         grains_B,
#      70         vege_A,
#      71         vege_B,
#      72         mush,
#      73         beans,
#      74         stats_2023,
#      75         S,
#      76         Y,
#      77         P,
#      78         C,
#      79     )
#      80 )
#
# File ~/CUMCM_2024/src/prob-2/planning.py:216, in planning(fields_id, crops_id, seasons_id, years, t_i, T_hat_i_s, grains_A, grains_B, vege_A, vege_B, mush, beans, stats_2023, *consts)
#     212                 prob += (
#     213                     A_ijks[(i, j, k, s)] >= M2 * A_star[i] * B_ijks[(i, j, k, s)]
#     214                 )
#     215 # # 模型求解
# --> 216 prob.solve()
#     218 A_ijks_output = {}
#     220 for v in prob.variables():
#
# File ~/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/pulp.py:1867, in LpProblem.solve(self, solver, **kwargs)
#    1865 # time it
#    1866 self.startClock()
# -> 1867 status = solver.actualSolve(self, **kwargs)
#    1868 self.stopClock()
#    1869 self.restoreObjective(wasNone, dummyVar)
#
# File ~/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/apis/coin_api.py:112, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     110 def actualSolve(self, lp, **kwargs):
#     111     """Solve a well formulated lp problem"""
# --> 112     return self.solve_CBC(lp, **kwargs)
#
# File ~/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/apis/coin_api.py:178, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     176 else:
#     177     cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 178 if cbc.wait() != 0:
#     179     if pipe:
#     180         pipe.close()
#
# File /usr/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /usr/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /usr/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
# 根据实验得到的 dataframes 计算平均值
df = pd.concat(dfs)
df = df.groupby(["Field ID", "Crop ID", "Season ID", "Year"]).agg("mean")


years = df['Year'].unique()
years = [year for year in years if year != 2023]

# 创建一个 Excel writer 对象
with pd.ExcelWriter(f'test-{times}.xlsx') as writer:
    for year in years:
        # 过滤特定年份的数据
        df_year = df[df['Year'] == year]
        
        # 透视表，Field 作为行，Crop 作为列
        pivot_table = df_year.pivot_table(
            index='Field',
            columns='Crop',
            values='Planting',
            aggfunc='sum'
        )
        
        # 将透视表写入 Excel 的 sheet
        pivot_table.to_excel(writer, sheet_name=str(year))

print(f"Exported to test-{times}.xlsx.xlsx")
