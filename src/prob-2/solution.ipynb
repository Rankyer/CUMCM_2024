# %%
import pandas as pd
import numpy as np
import datetime
from planning import planning

stats_2023 = pd.read_csv("../../data/preprocess/pre-processed.csv")
stats_2023.dtypes
# Out:
# Field ID           int64
# Field Name        object
# Crop ID            int64
# Crop Name         object
# Crop Type         object
# Planting Area    float64
# Season ID          int64
# Season            object
# Field Type        object
# Field Area       float64
# Per Yield        float64
# Per Cost         float64
# Per Price        float64
# Yield            float64
# Cost             float64
# Selling          float64
# Revenue          float64
# Profit           float64
# dtype: object

# %%
fields_id = list(map(int, stats_2023["Field ID"].unique()))  # 所有的地块
crops_id = list(map(int, stats_2023["Crop ID"].unique()))  # 所有的作物
seasons_id = list(map(int, stats_2023["Season ID"].unique()))  # 所有的时节
fields_id.sort()
crops_id.sort()
seasons_id.sort()
years = range(2023, 2031)  # 要优化的年份

def pop_ndarray(arr, element_to_pop):
    index = np.where(arr == element_to_pop)[0]
    if index.size > 0:
        arr = np.delete(arr, index)
    return arr

# A类粮食作物的集合
grains_A = stats_2023[
    (stats_2023["Crop Type"] == "粮食")
    | (stats_2023["Crop Type"] == "粮食（豆类）")
]["Crop ID"].unique()
grains_A = pop_ndarray(grains_A, 16)
grains_A.sort()

# B类粮食作物的集合
grains_B = np.array([16])

# A类蔬菜作物的集合
vege_A = stats_2023[
    (stats_2023["Crop Type"] == "蔬菜")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
for i in range(3):
    vege_A = pop_ndarray(vege_A, 35 + i)
vege_A.sort()

# B类蔬菜作物的集合
vege_B = np.array([35, 36, 37])

# 食用菌作物的集合
mush = stats_2023[stats_2023["Crop Type"] == "食用菌"]["Crop ID"].unique()
mush.sort()

# 豆类作物的集合
beans = stats_2023[
    (stats_2023["Crop Type"] == "粮食（豆类）")
    | (stats_2023["Crop Type"] == "蔬菜（豆类）")
]["Crop ID"].unique()
beans.sort()

# 第 i 个地块的类型（如平旱地、梯田、山坡地、智能大棚、普通大棚、水浇地）
t_i = {
    i: stats_2023[stats_2023["Field ID"] == i]["Field Type"].values[0]
    for i in fields_id
}

# 第 i 个地块在第 s 季可种植的作物集合
T_hat_i_s: dict[tuple : np.ndarray] = {}


for i in fields_id:
    if t_i[i] in ["平旱地", "梯田", "山坡地"]:
        T_hat_i_s[(i, 1)] = grains_A
        T_hat_i_s[(i, 2)] = np.array([])
    elif t_i[i] in ["水浇地"]:
        T_hat_i_s[(i, 1)] = np.concatenate([grains_B, vege_A])
        T_hat_i_s[(i, 2)] = vege_B
    elif t_i[i] in ["普通大棚"]:
        T_hat_i_s[(i, 1)] = vege_A
        T_hat_i_s[(i, 2)] = mush
    elif t_i[i] in ["智慧大棚"]:
        T_hat_i_s[(i, 1)] = vege_A
        T_hat_i_s[(i, 2)] = vege_A

# %%
dfs = []
times = 500  # 重复次数
for i in range(times):
    # 使用当前时间作为随机数种子
    np.random.seed(datetime.datetime.now().second)

    S = {}  # 期望产量
    Y = {}  # 单位面积产量
    P = {}  # 售价
    C = {}  # 单位面积成本

    for j in crops_id:
        # 所有参数与 2023 年的保持一致
        S[j, 2023] = stats_2023.groupby(["Crop ID"])["Selling"].agg("sum").values[j - 1]
        Y[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Yield"].values[0]
        P[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Price"].values[0]
        C[j, 2023] = stats_2023[stats_2023["Crop ID"] == j]["Per Cost"].values[0]

    for j in crops_id:
        # 小麦和玉米的预期销售量有平均5%-10%的年增长
        for k in years:
            if j in [6, 7]:
                increment = np.random.uniform(0.05, 0.1)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 其他作物的预期销售量变化约±5%。
            else:
                increment = np.random.uniform(-0.05, 0.05)
                S[j, k + 1] = S[j, k] * np.random.normal(1 + increment, 0.01)

            # 农作物亩产量可能有±10%的变化.
            increment = np.random.uniform(-0.1, 0.1)
            Y[j, k + 1] = Y[j, k] * np.random.normal(1 + increment, 0.01)

            # 种植成本每年增长约5%。
            increment = 0.05
            C[j, k + 1] = C[j, k] * np.random.normal(1 + increment, 0.01)

            # 蔬菜类作物价格每年增长约5%。
            if j in vege_A or j in vege_B:
                increment = 0.05
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 食用菌价格每年下降1%-5%。
            if j in mush:
                increment = np.random.uniform(-0.05, -0.01)
                P[j, k + 1] = P[j, k] * np.random.normal(1 + increment, 0.01)
            else:
                P[j, k + 1] = P[j, k]

            # 羊肚菌的销售价格每年下降幅5%
            if j == 41:
                increment = -0.05
                P[j, k + 1] = P[j, k] * (1 + increment)
            else:
                P[j, k + 1] = P[j, k]

    dfs.append(
        planning(
            fields_id,
            crops_id,
            seasons_id,
            years,
            t_i,
            T_hat_i_s,
            grains_A,
            grains_B,
            vege_A,
            vege_B,
            mush,
            beans,
            stats_2023,
            [
                S,
                Y,
                P,
                C,
            ],
        )
    )
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3acfbbcdbfc24e6fb0886f0f79ed9871-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/3acfbbcdbfc24e6fb0886f0f79ed9871-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.43372e+08 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 108 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 51 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 53 integers unsatisfied sum - 18.75
# Cbc0038I Pass   1: (0.61 seconds) suminf.    1.20000 (4) obj. -1.31837e+08 iterations 1174
# Cbc0038I Pass   2: (0.62 seconds) suminf.    0.60000 (2) obj. -1.31838e+08 iterations 2
# Cbc0038I Solution found of -1.31839e+08
# Cbc0038I Relaxing continuous gives -1.31863e+08
# Cbc0038I Before mini branch and bound, 7213 integers at bound fixed and 5800 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 158 rows 139 columns
# Cbc0038I Mini branch and bound improved solution from -1.31863e+08 to -1.32086e+08 (0.67 seconds)
# Cbc0038I Round again with cutoff of -1.32088e+08
# Cbc0038I Reduced cost fixing fixed 524 variables on major pass 2
# Cbc0038I Pass   3: (0.82 seconds) suminf.    0.79225 (4) obj. -1.32088e+08 iterations 1092
# Cbc0038I Pass   4: (0.84 seconds) suminf.    0.79225 (4) obj. -1.32088e+08 iterations 15
# Cbc0038I Pass   5: (0.86 seconds) suminf.    1.51699 (5) obj. -1.32088e+08 iterations 193
# Cbc0038I Pass   6: (0.88 seconds) suminf.    0.20132 (2) obj. -1.32088e+08 iterations 260
# Cbc0038I Pass   7: (0.90 seconds) suminf.    0.55710 (2) obj. -1.32088e+08 iterations 192
# Cbc0038I Pass   8: (0.93 seconds) suminf.    2.41858 (9) obj. -1.32088e+08 iterations 591
# Cbc0038I Pass   9: (0.94 seconds) suminf.    1.80854 (7) obj. -1.32088e+08 iterations 307
# Cbc0038I Pass  10: (0.96 seconds) suminf.    1.43714 (6) obj. -1.32088e+08 iterations 145
# Cbc0038I Pass  11: (0.97 seconds) suminf.    1.43714 (6) obj. -1.32088e+08 iterations 7
# Cbc0038I Pass  12: (0.98 seconds) suminf.    2.55142 (6) obj. -1.32088e+08 iterations 55
# Cbc0038I Pass  13: (1.00 seconds) suminf.    1.43714 (4) obj. -1.32088e+08 iterations 8
# Cbc0038I Pass  14: (1.01 seconds) suminf.    1.92138 (8) obj. -1.32088e+08 iterations 300
# Cbc0038I Pass  15: (1.03 seconds) suminf.    1.59386 (5) obj. -1.32088e+08 iterations 403
# Cbc0038I Pass  16: (1.05 seconds) suminf.    1.73709 (6) obj. -1.32088e+08 iterations 171
# Cbc0038I Pass  17: (1.07 seconds) suminf.    0.59482 (2) obj. -1.32088e+08 iterations 194
# Cbc0038I Pass  18: (1.09 seconds) suminf.    0.61228 (2) obj. -1.32088e+08 iterations 214
# Cbc0038I Pass  19: (1.11 seconds) suminf.    2.19456 (8) obj. -1.32088e+08 iterations 401
# Cbc0038I Pass  20: (1.13 seconds) suminf.    1.49654 (5) obj. -1.32088e+08 iterations 440
# Cbc0038I Pass  21: (1.15 seconds) suminf.    1.92447 (6) obj. -1.32088e+08 iterations 240
# Cbc0038I Pass  22: (1.17 seconds) suminf.    1.17734 (4) obj. -1.32088e+08 iterations 304
# Cbc0038I Pass  23: (1.19 seconds) suminf.    1.33873 (4) obj. -1.32088e+08 iterations 186
# Cbc0038I Pass  24: (1.21 seconds) suminf.    1.14145 (4) obj. -1.32088e+08 iterations 209
# Cbc0038I Pass  25: (1.22 seconds) suminf.    1.25369 (4) obj. -1.32088e+08 iterations 202
# Cbc0038I Pass  26: (1.24 seconds) suminf.    2.01520 (8) obj. -1.32088e+08 iterations 339
# Cbc0038I Pass  27: (1.27 seconds) suminf.    1.26257 (5) obj. -1.32088e+08 iterations 448
# Cbc0038I Pass  28: (1.29 seconds) suminf.    2.22025 (6) obj. -1.32088e+08 iterations 110
# Cbc0038I Pass  29: (1.30 seconds) suminf.    1.71742 (6) obj. -1.32088e+08 iterations 244
# Cbc0038I Pass  30: (1.32 seconds) suminf.    1.43254 (5) obj. -1.32088e+08 iterations 130
# Cbc0038I Pass  31: (1.34 seconds) suminf.    0.97956 (4) obj. -1.32088e+08 iterations 81
# Cbc0038I Pass  32: (1.35 seconds) suminf.    1.39271 (4) obj. -1.32088e+08 iterations 169
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7193 integers at bound fixed and 5780 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 199 rows 177 columns
# Cbc0038I Mini branch and bound improved solution from -1.32086e+08 to -1.32097e+08 (1.39 seconds)
# Cbc0038I Round again with cutoff of -1.321e+08
# Cbc0038I Reduced cost fixing fixed 640 variables on major pass 3
# Cbc0038I Pass  32: (1.43 seconds) suminf.    1.44637 (5) obj. -1.321e+08 iterations 57
# Cbc0038I Pass  33: (1.45 seconds) suminf.    1.44637 (5) obj. -1.321e+08 iterations 8
# Cbc0038I Pass  34: (1.47 seconds) suminf.    1.30726 (4) obj. -1.321e+08 iterations 264
# Cbc0038I Pass  35: (1.49 seconds) suminf.    1.15473 (4) obj. -1.321e+08 iterations 200
# Cbc0038I Pass  36: (1.50 seconds) suminf.    1.15473 (4) obj. -1.321e+08 iterations 59
# Cbc0038I Pass  37: (1.53 seconds) suminf.    1.97179 (7) obj. -1.321e+08 iterations 480
# Cbc0038I Pass  38: (1.54 seconds) suminf.    1.97179 (7) obj. -1.321e+08 iterations 345
# Cbc0038I Pass  39: (1.56 seconds) suminf.    1.66730 (6) obj. -1.321e+08 iterations 109
# Cbc0038I Pass  40: (1.57 seconds) suminf.    1.66730 (6) obj. -1.321e+08 iterations 8
# Cbc0038I Pass  41: (1.58 seconds) suminf.    2.64699 (6) obj. -1.321e+08 iterations 49
# Cbc0038I Pass  42: (1.60 seconds) suminf.    1.05957 (4) obj. -1.321e+08 iterations 207
# Cbc0038I Pass  43: (1.62 seconds) suminf.    1.66730 (6) obj. -1.321e+08 iterations 185
# Cbc0038I Pass  44: (1.64 seconds) suminf.    1.29934 (5) obj. -1.321e+08 iterations 349
# Cbc0038I Pass  45: (1.67 seconds) suminf.    0.58093 (2) obj. -1.321e+08 iterations 532
# Cbc0038I Pass  46: (1.69 seconds) suminf.    0.64519 (2) obj. -1.321e+08 iterations 164
# Cbc0038I Pass  47: (1.70 seconds) suminf.    0.69934 (3) obj. -1.321e+08 iterations 291
# Cbc0038I Pass  48: (1.72 seconds) suminf.    1.26214 (5) obj. -1.321e+08 iterations 406
# Cbc0038I Pass  49: (1.75 seconds) suminf.    0.58807 (2) obj. -1.321e+08 iterations 524
# Cbc0038I Pass  50: (1.77 seconds) suminf.    0.62827 (2) obj. -1.321e+08 iterations 143
# Cbc0038I Pass  51: (1.79 seconds) suminf.    0.99578 (4) obj. -1.321e+08 iterations 354
# Cbc0038I Pass  52: (1.82 seconds) suminf.    0.58093 (2) obj. -1.321e+08 iterations 549
# Cbc0038I Pass  53: (1.83 seconds) suminf.    0.64519 (2) obj. -1.321e+08 iterations 165
# Cbc0038I Pass  54: (1.85 seconds) suminf.    0.98982 (5) obj. -1.321e+08 iterations 343
# Cbc0038I Pass  55: (1.87 seconds) suminf.    0.74166 (3) obj. -1.321e+08 iterations 481
# Cbc0038I Pass  56: (1.91 seconds) suminf.    0.57280 (2) obj. -1.321e+08 iterations 554
# Cbc0038I Pass  57: (1.93 seconds) suminf.    0.66445 (2) obj. -1.321e+08 iterations 161
# Cbc0038I Pass  58: (1.95 seconds) suminf.    1.57414 (6) obj. -1.321e+08 iterations 397
# Cbc0038I Pass  59: (1.98 seconds) suminf.    0.58726 (2) obj. -1.321e+08 iterations 547
# Cbc0038I Pass  60: (2.00 seconds) suminf.    0.63019 (2) obj. -1.321e+08 iterations 157
# Cbc0038I Pass  61: (2.01 seconds) suminf.    0.68406 (3) obj. -1.321e+08 iterations 291
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7196 integers at bound fixed and 5782 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 197 rows 174 columns
# Cbc0038I Mini branch and bound improved solution from -1.32097e+08 to -1.32098e+08 (2.06 seconds)
# Cbc0038I Round again with cutoff of -1.32104e+08
# Cbc0038I Reduced cost fixing fixed 674 variables on major pass 4
# Cbc0038I Pass  61: (2.08 seconds) suminf.    1.68489 (5) obj. -1.32104e+08 iterations 0
# Cbc0038I Pass  62: (2.10 seconds) suminf.    1.68489 (5) obj. -1.32104e+08 iterations 8
# Cbc0038I Pass  63: (2.12 seconds) suminf.    1.56977 (6) obj. -1.32104e+08 iterations 268
# Cbc0038I Pass  64: (2.13 seconds) suminf.    1.56977 (6) obj. -1.32104e+08 iterations 5
# Cbc0038I Pass  65: (2.14 seconds) suminf.    2.68406 (6) obj. -1.32104e+08 iterations 64
# Cbc0038I Pass  66: (2.15 seconds) suminf.    1.56977 (4) obj. -1.32104e+08 iterations 9
# Cbc0038I Pass  67: (2.17 seconds) suminf.    1.58232 (5) obj. -1.32104e+08 iterations 325
# Cbc0038I Pass  68: (2.19 seconds) suminf.    1.12659 (4) obj. -1.32104e+08 iterations 548
# Cbc0038I Pass  69: (2.21 seconds) suminf.    1.82607 (6) obj. -1.32104e+08 iterations 191
# Cbc0038I Pass  70: (2.22 seconds) suminf.    1.82607 (6) obj. -1.32104e+08 iterations 7
# Cbc0038I Pass  71: (2.23 seconds) suminf.    2.48821 (6) obj. -1.32104e+08 iterations 62
# Cbc0038I Pass  72: (2.25 seconds) suminf.    0.94816 (6) obj. -1.32104e+08 iterations 349
# Cbc0038I Pass  73: (2.27 seconds) suminf.    0.10492 (1) obj. -1.32104e+08 iterations 302
# Cbc0038I Pass  74: (2.32 seconds) suminf.    0.00000 (0) obj. -1.32104e+08 iterations 795
# Cbc0038I Solution found of -1.32104e+08
# Cbc0038I Relaxing continuous gives -1.32106e+08
# Cbc0038I Before mini branch and bound, 7207 integers at bound fixed and 5794 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 170 rows 148 columns
# Cbc0038I Mini branch and bound improved solution from -1.32106e+08 to -1.32107e+08 (2.39 seconds)
# Cbc0038I Round again with cutoff of -1.32109e+08
# Cbc0038I Reduced cost fixing fixed 794 variables on major pass 5
# Cbc0038I Pass  75: (2.47 seconds) suminf.    2.81340 (18) obj. -1.32109e+08 iterations 287
# Cbc0038I Pass  76: (2.48 seconds) suminf.    2.54216 (18) obj. -1.32109e+08 iterations 213
# Cbc0038I Pass  77: (2.51 seconds) suminf.    8.16202 (20) obj. -1.32109e+08 iterations 342
# Cbc0038I Pass  78: (2.52 seconds) suminf.    3.63454 (19) obj. -1.32109e+08 iterations 181
# Cbc0038I Pass  79: (2.54 seconds) suminf.    1.94216 (16) obj. -1.32109e+08 iterations 40
# Cbc0038I Pass  80: (2.55 seconds) suminf.    5.88423 (15) obj. -1.32109e+08 iterations 221
# Cbc0038I Pass  81: (2.57 seconds) suminf.    5.88423 (15) obj. -1.32109e+08 iterations 32
# Cbc0038I Pass  82: (2.58 seconds) suminf.    2.52514 (15) obj. -1.32109e+08 iterations 149
# Cbc0038I Pass  83: (2.59 seconds) suminf.    2.52514 (15) obj. -1.32109e+08 iterations 1
# Cbc0038I Pass  84: (2.62 seconds) suminf.    4.37735 (15) obj. -1.32109e+08 iterations 302
# Cbc0038I Pass  85: (2.63 seconds) suminf.    3.11860 (14) obj. -1.32109e+08 iterations 52
# Cbc0038I Pass  86: (2.65 seconds) suminf.    5.80992 (19) obj. -1.32109e+08 iterations 146
# Cbc0038I Pass  87: (2.66 seconds) suminf.    4.39260 (17) obj. -1.32109e+08 iterations 11
# Cbc0038I Pass  88: (2.68 seconds) suminf.    1.19942 (4) obj. -1.32109e+08 iterations 311
# Cbc0038I Pass  89: (2.69 seconds) suminf.    1.19942 (4) obj. -1.32109e+08 iterations 11
# Cbc0038I Pass  90: (2.71 seconds) suminf.    1.20120 (4) obj. -1.32109e+08 iterations 140
# Cbc0038I Pass  91: (2.73 seconds) suminf.    1.50274 (6) obj. -1.32109e+08 iterations 312
# Cbc0038I Pass  92: (2.74 seconds) suminf.    1.20244 (5) obj. -1.32109e+08 iterations 424
# Cbc0038I Pass  93: (2.76 seconds) suminf.    1.50283 (6) obj. -1.32109e+08 iterations 409
# Cbc0038I Pass  94: (2.78 seconds) suminf.    1.20244 (5) obj. -1.32109e+08 iterations 402
# Cbc0038I Pass  95: (2.80 seconds) suminf.    3.08350 (10) obj. -1.32109e+08 iterations 443
# Cbc0038I Pass  96: (2.82 seconds) suminf.    4.49697 (21) obj. -1.32109e+08 iterations 472
# Cbc0038I Pass  97: (2.84 seconds) suminf.    1.94216 (16) obj. -1.32109e+08 iterations 192
# Cbc0038I Pass  98: (2.86 seconds) suminf.    3.42870 (11) obj. -1.32109e+08 iterations 339
# Cbc0038I Pass  99: (2.89 seconds) suminf.    1.09642 (16) obj. -1.32109e+08 iterations 227
# Cbc0038I Pass 100: (2.90 seconds) suminf.    1.02550 (16) obj. -1.32109e+08 iterations 23
# Cbc0038I Pass 101: (2.92 seconds) suminf.    4.24318 (15) obj. -1.32109e+08 iterations 229
# Cbc0038I Pass 102: (2.94 seconds) suminf.    4.22590 (15) obj. -1.32109e+08 iterations 110
# Cbc0038I Pass 103: (2.95 seconds) suminf.    3.09058 (16) obj. -1.32109e+08 iterations 96
# Cbc0038I Pass 104: (2.97 seconds) suminf.    5.41802 (14) obj. -1.32109e+08 iterations 283
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7206 integers at bound fixed and 5789 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 181 rows 157 columns
# Cbc0038I Mini branch and bound did not improve solution (3.00 seconds)
# Cbc0038I After 3.00 seconds - Feasibility pump exiting with objective of -1.32107e+08 - took 2.41 seconds
# Cbc0012I Integer solution of -1.3210676e+08 found by feasibility pump after 0 iterations and 0 nodes (3.01 seconds)
# Cbc0012I Integer solution of -1.3210732e+08 found by DiveCoefficient after 0 iterations and 0 nodes (3.40 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 159 rows 138 columns
# Cbc0012I Integer solution of -1.3210839e+08 found by DiveCoefficient after 51 iterations and 0 nodes (3.52 seconds)
# Cbc0031I 41 added rows had average density of 11.04878
# Cbc0013I At root node, 41 cuts changed objective from -1.3211315e+08 to -1.3210839e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 8 row cuts average 2.0 elements, 5220 column cuts (5220 active)  in 0.019 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 58 row cuts average 11.3 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 31 row cuts average 15.8 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 68 row cuts average 12.2 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -132108385.7994885, took 51 iterations and 0 nodes (3.53 seconds)
# Cbc0035I Maximum depth 0, 951 variables fixed on reduced cost
# Cuts at root node changed objective from -1.32113e+08 to -1.32108e+08
# Probing was tried 3 times and created 5228 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# Gomory was tried 3 times and created 58 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 3 times and created 68 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
#
# Result - Optimal solution found
#
# Objective value:                132108385.79948847
# Enumerated nodes:               0
# Total iterations:               51
# Time (CPU seconds):             4.90
# Time (Wallclock seconds):       4.95
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       5.06   (Wallclock seconds):       5.13
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d349503bd7d24beb98299bfbd4625e9d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/d349503bd7d24beb98299bfbd4625e9d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.44084e+08 - 0.08 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 108 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 66 integers unsatisfied sum - 21.85
# Cbc0038I Pass   1: (0.66 seconds) suminf.    0.00000 (0) obj. -1.3203e+08 iterations 1255
# Cbc0038I Solution found of -1.3203e+08
# Cbc0038I Relaxing continuous gives -1.3203e+08
# Cbc0038I Rounding solution of -1.32149e+08 is better than previous of -1.3203e+08
#
# Cbc0038I Before mini branch and bound, 7201 integers at bound fixed and 5766 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 196 rows 182 columns
# Cbc0038I Mini branch and bound improved solution from -1.32149e+08 to -1.32349e+08 (0.72 seconds)
# Cbc0038I Round again with cutoff of -1.3235e+08
# Cbc0038I Reduced cost fixing fixed 567 variables on major pass 2
# Cbc0038I Pass   2: (0.87 seconds) suminf.    5.77768 (13) obj. -1.3235e+08 iterations 1132
# Cbc0038I Pass   3: (0.89 seconds) suminf.    1.27552 (17) obj. -1.3235e+08 iterations 422
# Cbc0038I Pass   4: (0.91 seconds) suminf.    1.27371 (11) obj. -1.3235e+08 iterations 214
# Cbc0038I Pass   5: (0.92 seconds) suminf.    6.21712 (20) obj. -1.3235e+08 iterations 376
# Cbc0038I Pass   6: (0.95 seconds) suminf.    2.65378 (9) obj. -1.3235e+08 iterations 537
# Cbc0038I Pass   7: (0.96 seconds) suminf.    1.63050 (5) obj. -1.3235e+08 iterations 9
# Cbc0038I Pass   8: (0.98 seconds) suminf.    1.12080 (4) obj. -1.3235e+08 iterations 118
# Cbc0038I Pass   9: (1.01 seconds) suminf.    1.72807 (7) obj. -1.3235e+08 iterations 433
# Cbc0038I Pass  10: (1.02 seconds) suminf.    1.72807 (7) obj. -1.3235e+08 iterations 4
# Cbc0038I Pass  11: (1.04 seconds) suminf.    1.21632 (7) obj. -1.3235e+08 iterations 79
# Cbc0038I Pass  12: (1.05 seconds) suminf.    0.64490 (3) obj. -1.3235e+08 iterations 3
# Cbc0038I Pass  13: (1.09 seconds) suminf.    0.88066 (2) obj. -1.3235e+08 iterations 519
# Cbc0038I Pass  14: (1.10 seconds) suminf.    0.42612 (2) obj. -1.3235e+08 iterations 39
# Cbc0038I Pass  15: (1.12 seconds) suminf.    1.38174 (5) obj. -1.3235e+08 iterations 505
# Cbc0038I Pass  16: (1.15 seconds) suminf.    0.95058 (3) obj. -1.3235e+08 iterations 412
# Cbc0038I Pass  17: (1.16 seconds) suminf.    0.64333 (2) obj. -1.3235e+08 iterations 38
# Cbc0038I Pass  18: (1.18 seconds) suminf.    0.58561 (2) obj. -1.3235e+08 iterations 258
# Cbc0038I Pass  19: (1.20 seconds) suminf.    1.01738 (4) obj. -1.3235e+08 iterations 445
# Cbc0038I Pass  20: (1.30 seconds) suminf.    0.00000 (0) obj. -1.3235e+08 iterations 1559
# Cbc0038I Solution found of -1.3235e+08
# Cbc0038I Relaxing continuous gives -1.32351e+08
# Cbc0038I Before mini branch and bound, 7186 integers at bound fixed and 5750 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 231 rows 213 columns
# Cbc0038I Mini branch and bound improved solution from -1.32351e+08 to -1.32365e+08 (1.42 seconds)
# Cbc0038I Round again with cutoff of -1.32365e+08
# Cbc0038I Reduced cost fixing fixed 862 variables on major pass 3
# Cbc0038I Pass  21: (1.45 seconds) suminf.    6.59391 (15) obj. -1.32365e+08 iterations 20
# Cbc0038I Pass  22: (1.48 seconds) suminf.    5.78626 (17) obj. -1.32365e+08 iterations 388
# Cbc0038I Pass  23: (1.49 seconds) suminf.    2.79618 (10) obj. -1.32365e+08 iterations 135
# Cbc0038I Pass  24: (1.51 seconds) suminf.    1.18872 (4) obj. -1.32365e+08 iterations 145
# Cbc0038I Pass  25: (1.53 seconds) suminf.    1.89682 (7) obj. -1.32365e+08 iterations 261
# Cbc0038I Pass  26: (1.55 seconds) suminf.    0.58872 (2) obj. -1.32365e+08 iterations 313
# Cbc0038I Pass  27: (1.57 seconds) suminf.    0.71616 (3) obj. -1.32365e+08 iterations 218
# Cbc0038I Pass  28: (1.60 seconds) suminf.    1.02906 (4) obj. -1.32365e+08 iterations 464
# Cbc0038I Pass  29: (1.63 seconds) suminf.    0.58872 (2) obj. -1.32365e+08 iterations 676
# Cbc0038I Pass  30: (1.65 seconds) suminf.    0.71616 (3) obj. -1.32365e+08 iterations 197
# Cbc0038I Pass  31: (1.66 seconds) suminf.    1.31482 (5) obj. -1.32365e+08 iterations 301
# Cbc0038I Pass  32: (1.69 seconds) suminf.    0.75560 (12) obj. -1.32365e+08 iterations 359
# Cbc0038I Pass  33: (1.72 seconds) suminf.    5.58455 (12) obj. -1.32365e+08 iterations 321
# Cbc0038I Pass  34: (1.74 seconds) suminf.    3.97649 (12) obj. -1.32365e+08 iterations 143
# Cbc0038I Pass  35: (1.75 seconds) suminf.    3.97649 (12) obj. -1.32365e+08 iterations 4
# Cbc0038I Pass  36: (1.77 seconds) suminf.    3.55660 (11) obj. -1.32365e+08 iterations 209
# Cbc0038I Pass  37: (1.81 seconds) suminf.    0.79191 (12) obj. -1.32365e+08 iterations 532
# Cbc0038I Pass  38: (1.82 seconds) suminf.    0.75560 (12) obj. -1.32365e+08 iterations 20
# Cbc0038I Pass  39: (1.85 seconds) suminf.    5.58455 (12) obj. -1.32365e+08 iterations 334
# Cbc0038I Pass  40: (1.86 seconds) suminf.    3.97649 (12) obj. -1.32365e+08 iterations 126
# Cbc0038I Pass  41: (1.88 seconds) suminf.    3.97649 (12) obj. -1.32365e+08 iterations 4
# Cbc0038I Pass  42: (1.90 seconds) suminf.    3.55660 (11) obj. -1.32365e+08 iterations 276
# Cbc0038I Pass  43: (1.94 seconds) suminf.    0.79191 (12) obj. -1.32365e+08 iterations 531
# Cbc0038I Pass  44: (1.96 seconds) suminf.    0.75560 (12) obj. -1.32365e+08 iterations 21
# Cbc0038I Pass  45: (1.98 seconds) suminf.    5.58455 (12) obj. -1.32365e+08 iterations 332
# Cbc0038I Pass  46: (2.00 seconds) suminf.    3.97649 (12) obj. -1.32365e+08 iterations 126
# Cbc0038I Pass  47: (2.01 seconds) suminf.    3.97649 (12) obj. -1.32365e+08 iterations 3
# Cbc0038I Pass  48: (2.03 seconds) suminf.    3.55660 (11) obj. -1.32365e+08 iterations 258
# Cbc0038I Pass  49: (2.07 seconds) suminf.    0.79191 (12) obj. -1.32365e+08 iterations 468
# Cbc0038I Pass  50: (2.08 seconds) suminf.    0.75560 (12) obj. -1.32365e+08 iterations 18
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7190 integers at bound fixed and 5758 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 220 rows 199 columns
# Cbc0038I Mini branch and bound did not improve solution (2.11 seconds)
# Cbc0038I After 2.11 seconds - Feasibility pump exiting with objective of -1.32365e+08 - took 1.49 seconds
# Cbc0012I Integer solution of -1.3236467e+08 found by feasibility pump after 0 iterations and 0 nodes (2.12 seconds)
# Cbc0012I Integer solution of -1.3236535e+08 found by DiveCoefficient after 0 iterations and 0 nodes (2.62 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 197 rows 181 columns
# Cbc0031I 55 added rows had average density of 6.9818182
# Cbc0013I At root node, 165 cuts changed objective from -1.3236706e+08 to -1.3236535e+08 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 11 row cuts average 2.0 elements, 5145 column cuts (5145 active)  in 0.013 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 57 row cuts average 7.5 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 40 row cuts average 6.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 57 row cuts average 7.5 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -132365348.3700841, took 0 iterations and 0 nodes (2.71 seconds)
# Cbc0035I Maximum depth 0, 890 variables fixed on reduced cost
# Cuts at root node changed objective from -1.32367e+08 to -1.32365e+08
# Probing was tried 1 times and created 5156 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Gomory was tried 1 times and created 57 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 40 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 57 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
#
# Result - Optimal solution found
#
# Objective value:                132365348.37008408
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             4.10
# Time (Wallclock seconds):       4.14
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       4.29   (Wallclock seconds):       4.33
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ba56f558e8c14bfe841d33ae118f48e9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/ba56f558e8c14bfe841d33ae118f48e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.19973e+08 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 107 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 50 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 375 integers unsatisfied sum - 140.088
# Cbc0038I Pass   1: (0.61 seconds) suminf.    1.50000 (5) obj. -1.08512e+08 iterations 1299
# Cbc0038I Pass   2: (0.62 seconds) suminf.    1.50000 (5) obj. -1.08512e+08 iterations 17
# Cbc0038I Pass   3: (0.64 seconds) suminf.    0.60000 (2) obj. -1.08711e+08 iterations 4
# Cbc0038I Pass   4: (0.65 seconds) suminf.    0.60000 (2) obj. -1.08587e+08 iterations 1
# Cbc0038I Pass   5: (0.66 seconds) suminf.   23.53333 (77) obj. -9.85105e+07 iterations 540
# Cbc0038I Pass   6: (0.67 seconds) suminf.   19.50000 (66) obj. -9.84057e+07 iterations 62
# Cbc0038I Pass   7: (0.68 seconds) suminf.   18.40000 (61) obj. -9.73375e+07 iterations 20
# Cbc0038I Pass   8: (0.70 seconds) suminf.   18.00000 (61) obj. -9.74742e+07 iterations 8
# Cbc0038I Pass   9: (0.71 seconds) suminf.   18.40000 (61) obj. -9.73376e+07 iterations 17
# Cbc0038I Pass  10: (0.72 seconds) suminf.   18.00000 (61) obj. -9.74744e+07 iterations 8
# Cbc0038I Pass  11: (0.73 seconds) suminf.   18.40000 (61) obj. -9.73375e+07 iterations 12
# Cbc0038I Pass  12: (0.74 seconds) suminf.   38.43333 (123) obj. -8.96894e+07 iterations 543
# Cbc0038I Pass  13: (0.75 seconds) suminf.   26.83333 (89) obj. -8.98418e+07 iterations 89
# Cbc0038I Pass  14: (0.76 seconds) suminf.   25.70000 (84) obj. -8.98164e+07 iterations 15
# Cbc0038I Pass  15: (0.77 seconds) suminf.   25.20000 (85) obj. -9.0084e+07 iterations 8
# Cbc0038I Pass  16: (0.78 seconds) suminf.   25.50000 (85) obj. -8.99668e+07 iterations 10
# Cbc0038I Pass  17: (0.79 seconds) suminf.   25.20000 (85) obj. -8.99773e+07 iterations 3
# Cbc0038I Pass  18: (0.80 seconds) suminf.   25.10000 (83) obj. -8.95016e+07 iterations 21
# Cbc0038I Pass  19: (0.81 seconds) suminf.   24.60000 (83) obj. -8.95119e+07 iterations 9
# Cbc0038I Pass  20: (0.83 seconds) suminf.   24.90000 (83) obj. -8.95468e+07 iterations 4
# Cbc0038I Pass  21: (0.84 seconds) suminf.   24.60000 (83) obj. -8.95573e+07 iterations 3
# Cbc0038I Pass  22: (0.85 seconds) suminf.   25.10000 (83) obj. -8.94997e+07 iterations 11
# Cbc0038I Pass  23: (0.86 seconds) suminf.   24.60000 (83) obj. -8.95101e+07 iterations 8
# Cbc0038I Pass  24: (0.87 seconds) suminf.   25.50000 (83) obj. -8.94616e+07 iterations 21
# Cbc0038I Pass  25: (0.88 seconds) suminf.   24.60000 (83) obj. -8.94568e+07 iterations 15
# Cbc0038I Pass  26: (0.89 seconds) suminf.   24.60000 (83) obj. -8.94338e+07 iterations 3
# Cbc0038I Pass  27: (0.90 seconds) suminf.   24.60000 (83) obj. -8.94338e+07 iterations 2
# Cbc0038I Pass  28: (0.91 seconds) suminf.   25.50000 (83) obj. -8.94842e+07 iterations 25
# Cbc0038I Pass  29: (0.92 seconds) suminf.   24.60000 (83) obj. -8.96203e+07 iterations 17
# Cbc0038I Pass  30: (0.93 seconds) suminf.   25.10000 (83) obj. -8.95778e+07 iterations 10
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6427 integers at bound fixed and 5238 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 1759 rows 1417 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1.15189e+08 (1.29 seconds)
# Cbc0038I Round again with cutoff of -1.1521e+08
# Cbc0038I Reduced cost fixing fixed 25 variables on major pass 2
# Cbc0038I Pass  30: (1.49 seconds) suminf.   10.95094 (31) obj. -1.1521e+08 iterations 1866
# Cbc0038I Pass  31: (1.51 seconds) suminf.    2.48370 (9) obj. -1.1521e+08 iterations 379
# Cbc0038I Pass  32: (1.52 seconds) suminf.    2.48370 (9) obj. -1.1521e+08 iterations 7
# Cbc0038I Pass  33: (1.57 seconds) suminf.    1.36125 (6) obj. -1.1521e+08 iterations 687
# Cbc0038I Pass  34: (1.58 seconds) suminf.    1.36125 (6) obj. -1.1521e+08 iterations 1
# Cbc0038I Pass  35: (1.60 seconds) suminf.    1.26709 (4) obj. -1.1521e+08 iterations 372
# Cbc0038I Pass  36: (1.62 seconds) suminf.    0.70645 (4) obj. -1.1521e+08 iterations 226
# Cbc0038I Pass  37: (1.65 seconds) suminf.    3.36245 (11) obj. -1.1521e+08 iterations 545
# Cbc0038I Pass  38: (1.69 seconds) suminf.    2.63823 (10) obj. -1.1521e+08 iterations 823
# Cbc0038I Pass  39: (1.73 seconds) suminf.    3.58105 (11) obj. -1.1521e+08 iterations 639
# Cbc0038I Pass  40: (1.75 seconds) suminf.    2.68079 (10) obj. -1.1521e+08 iterations 73
# Cbc0038I Pass  41: (1.77 seconds) suminf.    6.57707 (25) obj. -1.1521e+08 iterations 329
# Cbc0038I Pass  42: (1.79 seconds) suminf.    4.84386 (21) obj. -1.1521e+08 iterations 213
# Cbc0038I Pass  43: (1.80 seconds) suminf.    4.84386 (21) obj. -1.1521e+08 iterations 1
# Cbc0038I Pass  44: (1.81 seconds) suminf.    3.47625 (11) obj. -1.1521e+08 iterations 46
# Cbc0038I Pass  45: (1.83 seconds) suminf.    3.47625 (11) obj. -1.1521e+08 iterations 10
# Cbc0038I Pass  46: (1.88 seconds) suminf.    3.52814 (11) obj. -1.1521e+08 iterations 859
# Cbc0038I Pass  47: (1.89 seconds) suminf.    2.60366 (10) obj. -1.1521e+08 iterations 62
# Cbc0038I Pass  48: (1.91 seconds) suminf.    2.55082 (10) obj. -1.1521e+08 iterations 42
# Cbc0038I Pass  49: (1.92 seconds) suminf.    9.07786 (24) obj. -1.1521e+08 iterations 243
# Cbc0038I Pass  50: (1.96 seconds) suminf.    8.79473 (22) obj. -1.1521e+08 iterations 596
# Cbc0038I Pass  51: (1.97 seconds) suminf.    7.81593 (26) obj. -1.1521e+08 iterations 31
# Cbc0038I Pass  52: (1.98 seconds) suminf.    7.81593 (26) obj. -1.1521e+08 iterations 0
# Cbc0038I Pass  53: (2.00 seconds) suminf.    5.54170 (19) obj. -1.1521e+08 iterations 91
# Cbc0038I Pass  54: (2.02 seconds) suminf.    3.89298 (13) obj. -1.1521e+08 iterations 135
# Cbc0038I Pass  55: (2.03 seconds) suminf.    3.89298 (13) obj. -1.1521e+08 iterations 4
# Cbc0038I Pass  56: (2.06 seconds) suminf.    4.46079 (14) obj. -1.1521e+08 iterations 414
# Cbc0038I Pass  57: (2.08 seconds) suminf.    2.94537 (10) obj. -1.1521e+08 iterations 80
# Cbc0038I Pass  58: (2.09 seconds) suminf.    2.93809 (10) obj. -1.1521e+08 iterations 33
# Cbc0038I Pass  59: (2.13 seconds) suminf.    3.11242 (11) obj. -1.1521e+08 iterations 508
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6849 integers at bound fixed and 5547 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 1086 rows 754 columns
# Cbc0038I Mini branch and bound improved solution from -1.15189e+08 to -1.15196e+08 (2.46 seconds)
# Cbc0038I Round again with cutoff of -1.15248e+08
# Cbc0038I Reduced cost fixing fixed 58 variables on major pass 3
# Cbc0038I Pass  59: (2.50 seconds) suminf.   13.79127 (37) obj. -1.15248e+08 iterations 102
# Cbc0038I Pass  60: (2.54 seconds) suminf.    6.42500 (20) obj. -1.15248e+08 iterations 642
# Cbc0038I Pass  61: (2.56 seconds) suminf.    6.36659 (22) obj. -1.15248e+08 iterations 199
# Cbc0038I Pass  62: (2.58 seconds) suminf.    5.58310 (21) obj. -1.15248e+08 iterations 90
# Cbc0038I Pass  63: (2.59 seconds) suminf.    3.73027 (22) obj. -1.15248e+08 iterations 125
# Cbc0038I Pass  64: (2.60 seconds) suminf.    3.73027 (22) obj. -1.15248e+08 iterations 2
# Cbc0038I Pass  65: (2.66 seconds) suminf.    5.22487 (16) obj. -1.15248e+08 iterations 962
# Cbc0038I Pass  66: (2.67 seconds) suminf.    5.22487 (16) obj. -1.15248e+08 iterations 2
# Cbc0038I Pass  67: (2.70 seconds) suminf.    1.80352 (8) obj. -1.15248e+08 iterations 388
# Cbc0038I Pass  68: (2.70 seconds) suminf.    1.80352 (8) obj. -1.15248e+08 iterations 0
# Cbc0038I Pass  69: (2.75 seconds) suminf.    2.83900 (9) obj. -1.15248e+08 iterations 748
# Cbc0038I Pass  70: (2.76 seconds) suminf.    1.90062 (8) obj. -1.15248e+08 iterations 79
# Cbc0038I Pass  71: (2.79 seconds) suminf.    5.12770 (18) obj. -1.15248e+08 iterations 505
# Cbc0038I Pass  72: (2.81 seconds) suminf.    4.52770 (16) obj. -1.15248e+08 iterations 227
# Cbc0038I Pass  73: (2.86 seconds) suminf.    5.29441 (17) obj. -1.15248e+08 iterations 950
# Cbc0038I Pass  74: (2.89 seconds) suminf.    5.24670 (18) obj. -1.15248e+08 iterations 460
# Cbc0038I Pass  75: (2.90 seconds) suminf.    4.94670 (17) obj. -1.15248e+08 iterations 198
# Cbc0038I Pass  76: (2.94 seconds) suminf.    4.50049 (15) obj. -1.15248e+08 iterations 543
# Cbc0038I Pass  77: (2.95 seconds) suminf.    4.50049 (15) obj. -1.15248e+08 iterations 12
# Cbc0038I Pass  78: (2.99 seconds) suminf.    4.60774 (16) obj. -1.15248e+08 iterations 649
# Cbc0038I Pass  79: (3.01 seconds) suminf.    3.68903 (14) obj. -1.15248e+08 iterations 130
# Cbc0038I Pass  80: (3.02 seconds) suminf.    3.54903 (12) obj. -1.15248e+08 iterations 3
# Cbc0038I Pass  81: (3.06 seconds) suminf.    3.69254 (13) obj. -1.15248e+08 iterations 617
# Cbc0038I Pass  82: (3.09 seconds) suminf.    7.38942 (24) obj. -1.15248e+08 iterations 501
# Cbc0038I Pass  83: (3.11 seconds) suminf.    4.62370 (16) obj. -1.15248e+08 iterations 268
# Cbc0038I Pass  84: (3.12 seconds) suminf.    4.62370 (16) obj. -1.15248e+08 iterations 1
# Cbc0038I Pass  85: (3.17 seconds) suminf.    5.12011 (17) obj. -1.15248e+08 iterations 720
# Cbc0038I Pass  86: (3.20 seconds) suminf.    5.65291 (18) obj. -1.15248e+08 iterations 467
# Cbc0038I Pass  87: (3.21 seconds) suminf.    5.35291 (17) obj. -1.15248e+08 iterations 189
# Cbc0038I Pass  88: (3.24 seconds) suminf.    4.49059 (15) obj. -1.15248e+08 iterations 292
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6853 integers at bound fixed and 5551 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 1059 rows 740 columns
# Cbc0038I Mini branch and bound improved solution from -1.15196e+08 to -1.15235e+08 (3.52 seconds)
# Cbc0038I Round again with cutoff of -1.15293e+08
# Cbc0038I Reduced cost fixing fixed 127 variables on major pass 4
# Cbc0038I Pass  88: (3.58 seconds) suminf.   31.18727 (73) obj. -1.15293e+08 iterations 162
# Cbc0038I Pass  89: (3.60 seconds) suminf.   19.59079 (46) obj. -1.15293e+08 iterations 390
# Cbc0038I Pass  90: (3.62 seconds) suminf.   15.82539 (40) obj. -1.15293e+08 iterations 186
# Cbc0038I Pass  91: (3.63 seconds) suminf.   15.52539 (39) obj. -1.15293e+08 iterations 9
# Cbc0038I Pass  92: (3.65 seconds) suminf.   15.52539 (39) obj. -1.15293e+08 iterations 3
# Cbc0038I Pass  93: (3.66 seconds) suminf.   15.52539 (39) obj. -1.15293e+08 iterations 2
# Cbc0038I Pass  94: (3.67 seconds) suminf.   14.85492 (39) obj. -1.15293e+08 iterations 39
# Cbc0038I Pass  95: (3.68 seconds) suminf.   12.57413 (42) obj. -1.15293e+08 iterations 20
# Cbc0038I Pass  96: (3.69 seconds) suminf.   12.57413 (42) obj. -1.15293e+08 iterations 1
# Cbc0038I Pass  97: (3.71 seconds) suminf.   12.57413 (42) obj. -1.15293e+08 iterations 1
# Cbc0038I Pass  98: (3.72 seconds) suminf.   12.58842 (43) obj. -1.15293e+08 iterations 24
# Cbc0038I Pass  99: (3.73 seconds) suminf.   11.47413 (39) obj. -1.15293e+08 iterations 13
# Cbc0038I Pass 100: (3.74 seconds) suminf.   11.47413 (39) obj. -1.15293e+08 iterations 10
# Cbc0038I Pass 101: (3.76 seconds) suminf.   15.65076 (38) obj. -1.15293e+08 iterations 327
# Cbc0038I Pass 102: (3.77 seconds) suminf.   15.15076 (37) obj. -1.15293e+08 iterations 187
# Cbc0038I Pass 103: (3.79 seconds) suminf.   13.00895 (36) obj. -1.15293e+08 iterations 20
# Cbc0038I Pass 104: (3.79 seconds) suminf.   13.00895 (36) obj. -1.15293e+08 iterations 0
# Cbc0038I Pass 105: (3.82 seconds) suminf.   12.54949 (34) obj. -1.15293e+08 iterations 383
# Cbc0038I Pass 106: (3.83 seconds) suminf.   10.51035 (30) obj. -1.15293e+08 iterations 185
# Cbc0038I Pass 107: (3.85 seconds) suminf.   10.51035 (30) obj. -1.15293e+08 iterations 2
# Cbc0038I Pass 108: (3.86 seconds) suminf.   10.51035 (30) obj. -1.15293e+08 iterations 1
# Cbc0038I Pass 109: (3.88 seconds) suminf.   13.34456 (45) obj. -1.15293e+08 iterations 407
# Cbc0038I Pass 110: (3.90 seconds) suminf.    8.43450 (32) obj. -1.15293e+08 iterations 183
# Cbc0038I Pass 111: (3.91 seconds) suminf.    8.43450 (32) obj. -1.15293e+08 iterations 6
# Cbc0038I Pass 112: (3.92 seconds) suminf.    8.43450 (32) obj. -1.15293e+08 iterations 16
# Cbc0038I Pass 113: (3.93 seconds) suminf.   10.04057 (36) obj. -1.15293e+08 iterations 213
# Cbc0038I Pass 114: (3.95 seconds) suminf.    8.51000 (41) obj. -1.15293e+08 iterations 216
# Cbc0038I Pass 115: (3.96 seconds) suminf.    8.51000 (41) obj. -1.15293e+08 iterations 24
# Cbc0038I Pass 116: (3.98 seconds) suminf.   10.42939 (43) obj. -1.15293e+08 iterations 330
# Cbc0038I Pass 117: (4.00 seconds) suminf.   10.35032 (41) obj. -1.15293e+08 iterations 207
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6880 integers at bound fixed and 5578 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 990 rows 683 columns
# Cbc0038I Mini branch and bound did not improve solution (4.16 seconds)
# Cbc0038I After 4.16 seconds - Feasibility pump exiting with objective of -1.15235e+08 - took 3.57 seconds
# Cbc0012I Integer solution of -1.1523499e+08 found by feasibility pump after 0 iterations and 0 nodes (4.17 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 960 rows 655 columns
# Cbc0012I Integer solution of -1.1523651e+08 found by DiveCoefficient after 696 iterations and 0 nodes (4.92 seconds)
# Cbc0031I 153 added rows had average density of 20.607843
# Cbc0013I At root node, 153 cuts changed objective from -1.1539885e+08 to -1.1523651e+08 in 25 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 2.0 elements, 5061 column cuts (5199 active)  in 0.085 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 494 row cuts average 24.4 elements, 0 column cuts (0 active)  in 0.076 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.065 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 126 row cuts average 25.2 elements, 0 column cuts (0 active)  in 0.038 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 10 row cuts average 14.5 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 418 row cuts average 22.5 elements, 0 column cuts (0 active)  in 0.114 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -115236506.5437634, took 710 iterations and 0 nodes (4.94 seconds)
# Cbc0032I Strong branching done 2 times (10 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 851 variables fixed on reduced cost
# Cuts at root node changed objective from -1.15399e+08 to -1.15237e+08
# Probing was tried 25 times and created 5063 cuts of which 138 were active after adding rounds of cuts (0.085 seconds)
# Gomory was tried 25 times and created 494 cuts of which 0 were active after adding rounds of cuts (0.076 seconds)
# Knapsack was tried 25 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.065 seconds)
# Clique was tried 25 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# MixedIntegerRounding2 was tried 25 times and created 126 cuts of which 0 were active after adding rounds of cuts (0.038 seconds)
# FlowCover was tried 25 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# TwoMirCuts was tried 25 times and created 418 cuts of which 0 were active after adding rounds of cuts (0.114 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
#
# Result - Optimal solution found
#
# Objective value:                115236506.54376340
# Enumerated nodes:               0
# Total iterations:               710
# Time (CPU seconds):             6.49
# Time (Wallclock seconds):       6.59
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       6.67   (Wallclock seconds):       6.78
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/zivmax/CUMCM_2024/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b1e2fc1c996f4e668bae02c1a7f81954-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/b1e2fc1c996f4e668bae02c1a7f81954-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97807 COLUMNS
# At line 400656 RHS
# At line 498459 BOUNDS
# At line 538312 ENDATA
# Problem MODEL has 97802 rows, 88560 columns and 196576 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.24009e+08 - 0.05 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 3264 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 107 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0004I processed model has 18496 rows, 13371 columns (7269 integer (7269 of which binary)) and 46224 elements
# Cbc0038I Initial state - 138 integers unsatisfied sum - 63.85
# Cbc0038I Pass   1: (0.61 seconds) suminf.    1.80000 (6) obj. -1.09795e+08 iterations 939
# Cbc0038I Pass   2: (0.62 seconds) suminf.    1.80000 (6) obj. -1.09795e+08 iterations 2
# Cbc0038I Pass   3: (0.63 seconds) suminf.    0.90000 (3) obj. -1.09663e+08 iterations 10
# Cbc0038I Pass   4: (0.63 seconds) suminf.    0.90000 (3) obj. -1.09663e+08 iterations 0
# Cbc0038I Pass   5: (0.64 seconds) suminf.    0.90000 (3) obj. -1.09848e+08 iterations 4
# Cbc0038I Pass   6: (0.65 seconds) suminf.    0.90000 (3) obj. -1.09848e+08 iterations 0
# Cbc0038I Pass   7: (0.66 seconds) suminf.   25.36667 (83) obj. -9.85737e+07 iterations 538
# Cbc0038I Pass   8: (0.67 seconds) suminf.   23.00000 (78) obj. -9.86074e+07 iterations 50
# Cbc0038I Pass   9: (0.68 seconds) suminf.   21.80000 (74) obj. -9.84337e+07 iterations 15
# Cbc0038I Pass  10: (0.69 seconds) suminf.   21.80000 (74) obj. -9.84337e+07 iterations 2
# Cbc0038I Pass  11: (0.70 seconds) suminf.   21.80000 (74) obj. -9.85005e+07 iterations 19
# Cbc0038I Pass  12: (0.71 seconds) suminf.   21.80000 (74) obj. -9.85005e+07 iterations 1
# Cbc0038I Pass  13: (0.72 seconds) suminf.   21.80000 (74) obj. -9.83151e+07 iterations 19
# Cbc0038I Pass  14: (0.73 seconds) suminf.   21.80000 (74) obj. -9.83151e+07 iterations 2
# Cbc0038I Pass  15: (0.73 seconds) suminf.   22.10000 (74) obj. -9.74529e+07 iterations 30
# Cbc0038I Pass  16: (0.74 seconds) suminf.   21.80000 (74) obj. -9.75862e+07 iterations 6
# Cbc0038I Pass  17: (0.75 seconds) suminf.   22.30000 (74) obj. -9.8179e+07 iterations 26
# Cbc0038I Pass  18: (0.76 seconds) suminf.   21.80000 (74) obj. -9.83131e+07 iterations 9
# Cbc0038I Pass  19: (0.77 seconds) suminf.   21.90000 (74) obj. -9.76627e+07 iterations 16
# Cbc0038I Pass  20: (0.78 seconds) suminf.   21.80000 (74) obj. -9.77646e+07 iterations 1
# Cbc0038I Pass  21: (0.79 seconds) suminf.   22.10000 (74) obj. -9.80968e+07 iterations 21
# Cbc0038I Pass  22: (0.80 seconds) suminf.   43.40000 (143) obj. -9.11682e+07 iterations 499
# Cbc0038I Pass  23: (0.81 seconds) suminf.   30.26667 (106) obj. -9.09539e+07 iterations 96
# Cbc0038I Pass  24: (0.82 seconds) suminf.   30.26667 (106) obj. -9.09539e+07 iterations 0
# Cbc0038I Pass  25: (0.83 seconds) suminf.   29.30000 (100) obj. -9.10233e+07 iterations 24
# Cbc0038I Pass  26: (0.84 seconds) suminf.   29.00000 (100) obj. -9.10981e+07 iterations 13
# Cbc0038I Pass  27: (0.85 seconds) suminf.   29.30000 (100) obj. -9.10498e+07 iterations 10
# Cbc0038I Pass  28: (0.86 seconds) suminf.   29.00000 (100) obj. -9.10326e+07 iterations 8
# Cbc0038I Pass  29: (0.87 seconds) suminf.   30.60000 (100) obj. -9.0897e+07 iterations 34
# Cbc0038I Pass  30: (0.88 seconds) suminf.   29.00000 (100) obj. -9.10169e+07 iterations 27
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6638 integers at bound fixed and 5361 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 1127 rows 987 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1.14579e+08 (1.11 seconds)
# Cbc0038I Round again with cutoff of -1.14611e+08
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 2
# Cbc0038I Pass  30: (1.22 seconds) suminf.   11.82176 (28) obj. -1.14611e+08 iterations 1135
# Cbc0038I Pass  31: (1.24 seconds) suminf.    6.44976 (15) obj. -1.14611e+08 iterations 69
# Cbc0038I Pass  32: (1.25 seconds) suminf.    5.96294 (14) obj. -1.14611e+08 iterations 11
# Cbc0038I Pass  33: (1.26 seconds) suminf.    5.66827 (15) obj. -1.14611e+08 iterations 120
# Cbc0038I Pass  34: (1.28 seconds) suminf.    5.66827 (15) obj. -1.14611e+08 iterations 4
# Cbc0038I Pass  35: (1.29 seconds) suminf.    4.29463 (19) obj. -1.14611e+08 iterations 2
# Cbc0038I Pass  36: (1.30 seconds) suminf.    3.72420 (13) obj. -1.14611e+08 iterations 64
# Cbc0038I Pass  37: (1.31 seconds) suminf.    1.22769 (8) obj. -1.14611e+08 iterations 24
# Cbc0038I Pass  38: (1.32 seconds) suminf.    1.04389 (5) obj. -1.14611e+08 iterations 41
# Cbc0038I Pass  39: (1.34 seconds) suminf.    1.30379 (5) obj. -1.14611e+08 iterations 140
# Cbc0038I Pass  40: (1.36 seconds) suminf.    0.00000 (0) obj. -1.14611e+08 iterations 283
# Cbc0038I Solution found of -1.14611e+08
# Cbc0038I Relaxing continuous gives -1.14671e+08
# Cbc0038I Before mini branch and bound, 7124 integers at bound fixed and 5770 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 372 rows 262 columns
# Cbc0038I Mini branch and bound improved solution from -1.14671e+08 to -1.14795e+08 (1.48 seconds)
# Cbc0038I Round again with cutoff of -1.14814e+08
# Cbc0038I Reduced cost fixing fixed 195 variables on major pass 3
# Cbc0038I Pass  41: (1.60 seconds) suminf.   14.61200 (48) obj. -1.14814e+08 iterations 605
# Cbc0038I Pass  42: (1.62 seconds) suminf.   10.71434 (31) obj. -1.14814e+08 iterations 158
# Cbc0038I Pass  43: (1.63 seconds) suminf.   10.71434 (31) obj. -1.14814e+08 iterations 1
# Cbc0038I Pass  44: (1.64 seconds) suminf.   10.71434 (31) obj. -1.14814e+08 iterations 1
# Cbc0038I Pass  45: (1.66 seconds) suminf.   20.76056 (45) obj. -1.14814e+08 iterations 271
# Cbc0038I Pass  46: (1.68 seconds) suminf.   15.71359 (35) obj. -1.14814e+08 iterations 229
# Cbc0038I Pass  47: (1.69 seconds) suminf.   15.71359 (35) obj. -1.14814e+08 iterations 1
# Cbc0038I Pass  48: (1.70 seconds) suminf.   14.69404 (37) obj. -1.14814e+08 iterations 1
# Cbc0038I Pass  49: (1.71 seconds) suminf.   12.61991 (39) obj. -1.14814e+08 iterations 4
# Cbc0038I Pass  50: (1.73 seconds) suminf.   11.06728 (38) obj. -1.14814e+08 iterations 142
# Cbc0038I Pass  51: (1.74 seconds) suminf.    8.15670 (32) obj. -1.14814e+08 iterations 147
# Cbc0038I Pass  52: (1.77 seconds) suminf.    7.81249 (31) obj. -1.14814e+08 iterations 377
# Cbc0038I Pass  53: (1.79 seconds) suminf.    7.86154 (33) obj. -1.14814e+08 iterations 247
# Cbc0038I Pass  54: (1.82 seconds) suminf.    6.36554 (29) obj. -1.14814e+08 iterations 494
# Cbc0038I Pass  55: (1.83 seconds) suminf.    7.23085 (16) obj. -1.14814e+08 iterations 141
# Cbc0038I Pass  56: (1.88 seconds) suminf.    5.70487 (15) obj. -1.14814e+08 iterations 773
# Cbc0038I Pass  57: (1.90 seconds) suminf.    5.37242 (19) obj. -1.14814e+08 iterations 203
# Cbc0038I Pass  58: (1.93 seconds) suminf.    6.91415 (17) obj. -1.14814e+08 iterations 550
# Cbc0038I Pass  59: (1.95 seconds) suminf.    6.91415 (17) obj. -1.14814e+08 iterations 9
# Cbc0038I Pass  60: (1.97 seconds) suminf.    4.85836 (20) obj. -1.14814e+08 iterations 262
# Cbc0038I Pass  61: (1.98 seconds) suminf.    2.38245 (6) obj. -1.14814e+08 iterations 70
# Cbc0038I Pass  62: (2.00 seconds) suminf.    2.38245 (6) obj. -1.14814e+08 iterations 2
# Cbc0038I Pass  63: (2.01 seconds) suminf.    2.38245 (6) obj. -1.14814e+08 iterations 15
# Cbc0038I Pass  64: (2.02 seconds) suminf.    1.20531 (4) obj. -1.14814e+08 iterations 262
# Cbc0038I Pass  65: (2.04 seconds) suminf.    1.20531 (4) obj. -1.14814e+08 iterations 195
# Cbc0038I Pass  66: (2.06 seconds) suminf.    1.44651 (3) obj. -1.14814e+08 iterations 300
# Cbc0038I Pass  67: (2.10 seconds) suminf.    0.90000 (3) obj. -1.14814e+08 iterations 660
# Cbc0038I Pass  68: (2.15 seconds) suminf.    0.95163 (3) obj. -1.14814e+08 iterations 636
# Cbc0038I Pass  69: (2.17 seconds) suminf.    5.52919 (13) obj. -1.14814e+08 iterations 348
# Cbc0038I Pass  70: (2.18 seconds) suminf.    4.02213 (13) obj. -1.14814e+08 iterations 228
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7102 integers at bound fixed and 5746 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 424 rows 310 columns
# Cbc0038I Mini branch and bound improved solution from -1.14795e+08 to -1.14838e+08 (2.24 seconds)
# Cbc0038I Round again with cutoff of -1.14854e+08
# Cbc0038I Reduced cost fixing fixed 380 variables on major pass 4
# Cbc0038I Pass  70: (2.28 seconds) suminf.   31.13733 (76) obj. -1.14854e+08 iterations 96
# Cbc0038I Pass  71: (2.30 seconds) suminf.   23.87602 (63) obj. -1.14854e+08 iterations 67
# Cbc0038I Pass  72: (2.31 seconds) suminf.   18.86931 (57) obj. -1.14854e+08 iterations 66
# Cbc0038I Pass  73: (2.33 seconds) suminf.   17.13556 (51) obj. -1.14854e+08 iterations 163
# Cbc0038I Pass  74: (2.34 seconds) suminf.   17.13556 (51) obj. -1.14854e+08 iterations 2
# Cbc0038I Pass  75: (2.35 seconds) suminf.   17.13556 (51) obj. -1.14854e+08 iterations 2
# Cbc0038I Pass  76: (2.37 seconds) suminf.   17.13556 (51) obj. -1.14854e+08 iterations 2
# Cbc0038I Pass  77: (2.37 seconds) suminf.   17.13556 (51) obj. -1.14854e+08 iterations 0
# Cbc0038I Pass  78: (2.38 seconds) suminf.   16.92228 (51) obj. -1.14854e+08 iterations 50
# Cbc0038I Pass  79: (2.40 seconds) suminf.   12.66176 (42) obj. -1.14854e+08 iterations 76
# Cbc0038I Pass  80: (2.41 seconds) suminf.   12.66176 (42) obj. -1.14854e+08 iterations 2
# Cbc0038I Pass  81: (2.42 seconds) suminf.   13.10105 (44) obj. -1.14854e+08 iterations 10
# Cbc0038I Pass  82: (2.43 seconds) suminf.   11.98676 (40) obj. -1.14854e+08 iterations 2
# Cbc0038I Pass  83: (2.44 seconds) suminf.   11.98676 (40) obj. -1.14854e+08 iterations 0
# Cbc0038I Pass  84: (2.45 seconds) suminf.   14.06548 (40) obj. -1.14854e+08 iterations 92
# Cbc0038I Pass  85: (2.46 seconds) suminf.   13.20676 (39) obj. -1.14854e+08 iterations 7
# Cbc0038I Pass  86: (2.47 seconds) suminf.   13.14811 (37) obj. -1.14854e+08 iterations 4
# Cbc0038I Pass  87: (2.48 seconds) suminf.   13.14811 (37) obj. -1.14854e+08 iterations 0
# Cbc0038I Pass  88: (2.49 seconds) suminf.   13.29811 (37) obj. -1.14854e+08 iterations 4
# Cbc0038I Pass  89: (2.50 seconds) suminf.    9.78118 (34) obj. -1.14854e+08 iterations 4
# Cbc0038I Pass  90: (2.52 seconds) suminf.    6.51792 (29) obj. -1.14854e+08 iterations 229
# Cbc0038I Pass  91: (2.54 seconds) suminf.    3.55676 (18) obj. -1.14854e+08 iterations 93
# Cbc0038I Pass  92: (2.58 seconds) suminf.    3.18217 (13) obj. -1.14854e+08 iterations 609
# Cbc0038I Pass  93: (2.60 seconds) suminf.    6.40340 (14) obj. -1.14854e+08 iterations 65
# Cbc0038I Pass  94: (2.62 seconds) suminf.    5.60691 (13) obj. -1.14854e+08 iterations 143
# Cbc0038I Pass  95: (2.65 seconds) suminf.    4.39926 (12) obj. -1.14854e+08 iterations 354
# Cbc0038I Pass  96: (2.66 seconds) suminf.    4.34495 (16) obj. -1.14854e+08 iterations 176
# Cbc0038I Pass  97: (2.70 seconds) suminf.    6.19665 (14) obj. -1.14854e+08 iterations 561
# Cbc0038I Pass  98: (2.72 seconds) suminf.    5.90774 (14) obj. -1.14854e+08 iterations 17
# Cbc0038I Pass  99: (2.74 seconds) suminf.    2.84298 (17) obj. -1.14854e+08 iterations 233
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7119 integers at bound fixed and 5769 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 380 rows 266 columns
# Cbc0038I Mini branch and bound improved solution from -1.14838e+08 to -1.14861e+08 (2.79 seconds)
# Cbc0038I Round again with cutoff of -1.1487e+08
# Cbc0038I Reduced cost fixing fixed 504 variables on major pass 5
# Cbc0038I Pass  99: (2.82 seconds) suminf.   36.59547 (90) obj. -1.1487e+08 iterations 7
# Cbc0038I Pass 100: (2.83 seconds) suminf.   28.87544 (78) obj. -1.1487e+08 iterations 73
# Cbc0038I Pass 101: (2.84 seconds) suminf.   22.87006 (71) obj. -1.1487e+08 iterations 23
# Cbc0038I Pass 102: (2.85 seconds) suminf.   19.32582 (62) obj. -1.1487e+08 iterations 40
# Cbc0038I Pass 103: (2.87 seconds) suminf.   18.93556 (57) obj. -1.1487e+08 iterations 136
# Cbc0038I Pass 104: (2.88 seconds) suminf.   18.93556 (57) obj. -1.1487e+08 iterations 5
# Cbc0038I Pass 105: (2.88 seconds) suminf.   18.93556 (57) obj. -1.1487e+08 iterations 0
# Cbc0038I Pass 106: (2.90 seconds) suminf.   15.20370 (54) obj. -1.1487e+08 iterations 82
# Cbc0038I Pass 107: (2.91 seconds) suminf.   14.93231 (43) obj. -1.1487e+08 iterations 23
# Cbc0038I Pass 108: (2.92 seconds) suminf.    8.58420 (29) obj. -1.1487e+08 iterations 23
# Cbc0038I Pass 109: (2.93 seconds) suminf.    8.58420 (29) obj. -1.1487e+08 iterations 4
# Cbc0038I Pass 110: (2.94 seconds) suminf.    8.88420 (29) obj. -1.1487e+08 iterations 1
# Cbc0038I Pass 111: (2.96 seconds) suminf.    8.73420 (29) obj. -1.1487e+08 iterations 1
# Cbc0038I Pass 112: (2.96 seconds) suminf.    8.73420 (29) obj. -1.1487e+08 iterations 0
# Cbc0038I Pass 113: (2.97 seconds) suminf.    8.58420 (29) obj. -1.1487e+08 iterations 7
# Cbc0038I Pass 114: (2.98 seconds) suminf.    8.58420 (29) obj. -1.1487e+08 iterations 5
# Cbc0038I Pass 115: (2.99 seconds) suminf.    8.58420 (29) obj. -1.1487e+08 iterations 0
# Cbc0038I Pass 116: (3.00 seconds) suminf.   11.89551 (29) obj. -1.1487e+08 iterations 158
# Cbc0038I Pass 117: (3.02 seconds) suminf.    9.07508 (26) obj. -1.1487e+08 iterations 43
# Cbc0038I Pass 118: (3.03 seconds) suminf.    9.06233 (26) obj. -1.1487e+08 iterations 40
# Cbc0038I Pass 119: (3.05 seconds) suminf.    8.87903 (28) obj. -1.1487e+08 iterations 82
# Cbc0038I Pass 120: (3.06 seconds) suminf.    6.94454 (29) obj. -1.1487e+08 iterations 124
# Cbc0038I Pass 121: (3.08 seconds) suminf.    4.65082 (19) obj. -1.1487e+08 iterations 9
# Cbc0038I Pass 122: (3.09 seconds) suminf.    4.65082 (19) obj. -1.1487e+08 iterations 3
# Cbc0038I Pass 123: (3.12 seconds) suminf.    8.04701 (18) obj. -1.1487e+08 iterations 417
# Cbc0038I Pass 124: (3.13 seconds) suminf.    7.24701 (17) obj. -1.1487e+08 iterations 2
# Cbc0038I Pass 125: (3.14 seconds) suminf.    6.21286 (18) obj. -1.1487e+08 iterations 1
# Cbc0038I Pass 126: (3.15 seconds) suminf.    4.20752 (19) obj. -1.1487e+08 iterations 1
# Cbc0038I Pass 127: (3.17 seconds) suminf.    1.46929 (5) obj. -1.1487e+08 iterations 186
# Cbc0038I Pass 128: (3.19 seconds) suminf.    1.59356 (5) obj. -1.1487e+08 iterations 258
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7117 integers at bound fixed and 5769 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 384 rows 269 columns
# Cbc0038I Mini branch and bound improved solution from -1.14861e+08 to -1.14873e+08 (3.25 seconds)
# Cbc0038I Round again with cutoff of -1.14881e+08
# Cbc0038I Reduced cost fixing fixed 613 variables on major pass 6
# Cbc0038I Pass 128: (3.29 seconds) suminf.   40.44542 (93) obj. -1.14881e+08 iterations 112
# Cbc0038I Pass 129: (3.31 seconds) suminf.   30.84956 (96) obj. -1.14881e+08 iterations 64
# Cbc0038I Pass 130: (3.32 seconds) suminf.   25.46873 (84) obj. -1.14881e+08 iterations 33
# Cbc0038I Pass 131: (3.33 seconds) suminf.   22.02364 (71) obj. -1.14881e+08 iterations 62
# Cbc0038I Pass 132: (3.35 seconds) suminf.   18.30625 (59) obj. -1.14881e+08 iterations 62
# Cbc0038I Pass 133: (3.36 seconds) suminf.   15.28144 (49) obj. -1.14881e+08 iterations 76
# Cbc0038I Pass 134: (3.38 seconds) suminf.   13.96766 (46) obj. -1.14881e+08 iterations 83
# Cbc0038I Pass 135: (3.39 seconds) suminf.   12.22881 (41) obj. -1.14881e+08 iterations 26
# Cbc0038I Pass 136: (3.40 seconds) suminf.   11.85381 (41) obj. -1.14881e+08 iterations 2
# Cbc0038I Pass 137: (3.41 seconds) suminf.   11.85381 (41) obj. -1.14881e+08 iterations 0
# Cbc0038I Pass 138: (3.42 seconds) suminf.   14.42789 (32) obj. -1.14881e+08 iterations 74
# Cbc0038I Pass 139: (3.44 seconds) suminf.    7.96352 (24) obj. -1.14881e+08 iterations 103
# Cbc0038I Pass 140: (3.45 seconds) suminf.    7.93581 (23) obj. -1.14881e+08 iterations 70
# Cbc0038I Pass 141: (3.46 seconds) suminf.    7.93581 (23) obj. -1.14881e+08 iterations 0
# Cbc0038I Pass 142: (3.47 seconds) suminf.    7.78581 (23) obj. -1.14881e+08 iterations 1
# Cbc0038I Pass 143: (3.47 seconds) suminf.    7.78581 (23) obj. -1.14881e+08 iterations 0
# Cbc0038I Pass 144: (3.49 seconds) suminf.    9.58705 (26) obj. -1.14881e+08 iterations 155
# Cbc0038I Pass 145: (3.51 seconds) suminf.    6.76987 (26) obj. -1.14881e+08 iterations 124
# Cbc0038I Pass 146: (3.52 seconds) suminf.    6.50145 (37) obj. -1.14881e+08 iterations 162
# Cbc0038I Pass 147: (3.55 seconds) suminf.   11.74170 (26) obj. -1.14881e+08 iterations 359
# Cbc0038I Pass 148: (3.56 seconds) suminf.   10.59170 (24) obj. -1.14881e+08 iterations 34
# Cbc0038I Pass 149: (3.58 seconds) suminf.    8.69360 (24) obj. -1.14881e+08 iterations 112
# Cbc0038I Pass 150: (3.59 seconds) suminf.    7.85204 (23) obj. -1.14881e+08 iterations 18
# Cbc0038I Pass 151: (3.61 seconds) suminf.    8.00204 (23) obj. -1.14881e+08 iterations 2
# Cbc0038I Pass 152: (3.62 seconds) suminf.    7.75400 (24) obj. -1.14881e+08 iterations 119
# Cbc0038I Pass 153: (3.63 seconds) suminf.    6.99718 (24) obj. -1.14881e+08 iterations 81
# Cbc0038I Pass 154: (3.65 seconds) suminf.    6.78718 (24) obj. -1.14881e+08 iterations 2
# Cbc0038I Pass 155: (3.67 seconds) suminf.    8.00045 (23) obj. -1.14881e+08 iterations 177
# Cbc0038I Pass 156: (3.68 seconds) suminf.    7.70045 (23) obj. -1.14881e+08 iterations 2
# Cbc0038I Pass 157: (3.68 seconds) suminf.    7.70045 (23) obj. -1.14881e+08 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7116 integers at bound fixed and 5767 continuous
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 395 rows 274 columns
# Cbc0038I Mini branch and bound did not improve solution (3.72 seconds)
# Cbc0038I After 3.72 seconds - Feasibility pump exiting with objective of -1.14873e+08 - took 3.14 seconds
# Cbc0012I Integer solution of -1.1487262e+08 found by feasibility pump after 0 iterations and 0 nodes (3.73 seconds)
# Cbc0038I Full problem 18496 rows 13371 columns, reduced to 365 rows 259 columns
# Cbc0012I Integer solution of -1.1487292e+08 found by DiveCoefficient after 72 iterations and 0 nodes (3.90 seconds)
# Cbc0031I 55 added rows had average density of 14.509091
# Cbc0013I At root node, 55 cuts changed objective from -1.1489258e+08 to -1.1487292e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 5137 column cuts (5137 active)  in 0.024 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 109 row cuts average 10.1 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 27 row cuts average 25.1 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 103 row cuts average 11.9 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -114872922.0697837, took 72 iterations and 0 nodes (3.90 seconds)
# Cbc0035I Maximum depth 0, 964 variables fixed on reduced cost
# Cuts at root node changed objective from -1.14893e+08 to -1.14873e+08
# Probing was tried 3 times and created 5138 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# Gomory was tried 3 times and created 109 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 27 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 3 times and created 103 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
#
# Result - Optimal solution found
#
# Objective value:                114872922.06978370
# Enumerated nodes:               0
# Total iterations:               72
# Time (CPU seconds):             5.27
# Time (Wallclock seconds):       5.34
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       5.44   (Wallclock seconds):       5.52

# %%
# 修正后的代码
df = pd.concat(dfs)

# 计算平均值时需要指定哪些列进行聚合
df = df.groupby(["Field", "Crop", "Season", "Year"]).agg("mean").reset_index()

# 获取不包括 2023 年的唯一年份
years = df["Year"].unique()
years = [year for year in years if year != 2023]


# 创建一个 Excel writer 对象
with pd.ExcelWriter(f"test-{times}.xlsx") as writer:
    for year in years:
        # 过滤特定年份的数据
        df_year = df[df["Year"] == year]

        # 透视表，Field 作为行，Crop 作为列
        pivot_table = df_year.pivot_table(
            index="Field", columns="Crop", values="Planting", aggfunc="sum"
        )

        # 将透视表写入 Excel 的 sheet
        pivot_table.to_excel(writer, sheet_name=str(year))

print(f"Exported to test-{times}.xlsx")
# Out:
# Exported to test-example.xlsx
